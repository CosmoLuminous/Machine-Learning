# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
'''Import modules'''
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils, models
from collections import Counter
from skimage import io, transform

from torchsummary import summary

import matplotlib.pyplot as plt # for plotting
import numpy as np
from time import time
import collections
import pickle
import os
import gensim
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device =", device)
print("Using", torch.cuda.device_count(), "GPUs!")
parallel = True #enable nn.DataParallel for GPU
platform = "colab" #colab/local
restore = False #Restore Checkpoint
phase = "Train"
# Out:
# Device = cuda
# Using 1 GPUs!

# %%
VOCAB = {}
WORD2IDX = {}
IDX2WORD = {}

# %%
idx = 0
keys_found = 0
not_found = []
vocab_dump = VOCAB.copy()
for k in VOCAB.keys():
    if k in fasttext_model.vocab:
        keys_found += 1
        vocab_dump[k] = torch.FloatTensor(fasttext_model.wv.get_vector(k))
    else:
        vocab_dump[k] = torch.randn(300)
        not_found.append(k)

print("not found", len(not_found))

#with open('/content/drive/My Drive/A4/embeddings/trained_embed.pkl', 'wb') as handle:
#  pickle.dump(vocab_dump, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# not found 0

# %%
class Rescale(object):
    """Rescale the image in a sample to a given size.

    Args:
        output_size (tuple or int): Desired output size. If tuple, output is
            matched to output_size. If int, smaller of image edges is matched
            to output_size keeping aspect ratio the same.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size

    def __call__(self, image):
        h, w = image.shape[:2]
        #print("TA RESCALE INPUT", image.shape)
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)
        img = transform.resize(image, (new_h, new_w))
        #print("TA RESCALE OUTPUT", image.shape)
        return img


class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, image):
        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        #print("TA TRANSPOSE IP", image.shape)
        #image = image.transpose((2, 0, 1))
        #print("TA TRANSPOSE OP", image.shape)
        return image


IMAGE_RESIZE = (256, 256)
# Sequentially compose the transforms
img_transform = transforms.Compose([Rescale(IMAGE_RESIZE), ToTensor()])

# %%
class CaptionsPreprocessing:
    """Preprocess the captions, generate vocabulary and convert words to tensor tokens
    Args:
        captions_file_path (string): captions tsv file path
    """
    def __init__(self, captions_file_path):
        self.captions_file_path = captions_file_path

        # Read raw captions
        self.raw_captions_dict = self.read_raw_captions()

        # Preprocess captions
        self.captions_dict = self.process_captions()

        # Create vocabulary
        self.start = "<start>"
        self.end = "<end>"
        self.oov = "<unk>"
        self.pad = "<pad>"
        self.vocab = self.generate_vocabulary()
        self.word2index = self.convert_word2index()        
        self.index2word = self.convert_index2word()
        

    def read_raw_captions(self):
        """
        Returns:
            Dictionary with raw captions list keyed by image ids (integers)
        """
        captions_dict = {}
        with open(self.captions_file_path, 'r', encoding='utf-8') as f:
            for img_caption_line in f.readlines():
                img_captions = img_caption_line.strip().split('\t')
                captions_dict[int(img_captions[0])] = img_captions[1:]

        return captions_dict 

    def process_captions(self):
        """
        Use this function to generate dictionary and other preprocessing on captions
        """

        raw_captions_dict = self.raw_captions_dict 
        
        # Do the preprocessing here                
        captions_dict = raw_captions_dict

        return captions_dict

 

    def generate_vocabulary(self):
        """
        Use this function to generate dictionary and other preprocessing on captions
        """
        captions_dict = self.captions_dict

        # Generate the vocabulary
        
        all_captions = ""        
        for cap_lists in captions_dict.values():
            all_captions += " ".join(cap_lists)
        all_captions = nltk.tokenize.word_tokenize(all_captions.lower())
        
        vocab = {self.pad :1, self.oov :1, self.start :1, self.end :1}
        vocab_update = Counter(all_captions) 
        vocab_update = {k:v for k,v in vocab_update.items() if v >= freq_threshold}
        vocab.update(vocab_update)        
        vocab_size = len(vocab)
        
        if phase == "Train":
            VOCAB.clear()
            VOCAB.update(vocab)
            if platform == "colab":
                fname = '/content/drive/My Drive/A4/dict/VOCAB_own.pkl'
            else:
                fname = '../dict/VOCAB_own.pkl'
            #if not os.path.isfile(fname):
            with open(fname, 'wb') as handle:
                pickle.dump(vocab, handle, protocol=pickle.HIGHEST_PROTOCOL)
            print("VOCAB Saved")
            
        print("VOCAB SIZE =", vocab_size)
        return vocab
    
    def convert_word2index(self):
        """
        word to index converter
        """
        word2index = {}
        vocab = self.vocab
        idx = 0
        words = vocab.keys()
        for w in words:
            word2index[w] = idx
            idx +=1
        if phase == "Train":
            WORD2IDX.clear()
            WORD2IDX.update(word2index)
            if platform == "colab":
                fname = '/content/drive/My Drive/A4/dict/WORD2IDX_own.pkl'
            else:
                fname = '../dict/WORD2IDX_own.pkl'
            #if not os.path.isfile(fname):
            with open(fname, 'wb') as handle:
                pickle.dump(word2index, handle, protocol=pickle.HIGHEST_PROTOCOL)
            print("WORD2IDX Saved")
        return word2index
    
    def convert_index2word(self):
        """
        index to word converter
        """
        index2word = {}
        w2i = self.word2index
        idx = 0
        
        for k, v in w2i.items():
            index2word[v] = k
            
        if phase == "Train":
            IDX2WORD.clear()
            IDX2WORD.update(index2word)
            if platform == "colab":
                fname = '/content/drive/My Drive/A4/dict/IDX2WORD_own.pkl'
            else:
                fname = '../dict/_own.pkl'
            #if not os.path.isfile(fname):
            with open(fname, 'wb') as handle:
                pickle.dump(index2word, handle, protocol=pickle.HIGHEST_PROTOCOL)
            print("IDX2WORD Saved")
        return index2word

    def captions_transform(self, img_caption_list):
        """
        Use this function to generate tensor tokens for the text captions
        Args:
            img_caption_list: List of captions for a particular image
        """
        if phase == "Test":
            word2index = WORD2IDX
            vocab = VOCAB
        else:
            word2index = self.word2index
            vocab = self.vocab
            
        start = self.start
        end = self.end
        oov = self.oov
        
        processed_list = list(map(lambda x: start + " "+ x + " " + end, img_caption_list))
        processed_list = list(map(lambda x: nltk.tokenize.word_tokenize(x.lower()), processed_list))
        processed_list = list(map(lambda x: list(map(lambda y: word2index[y] if y in vocab else word2index[oov],x)),
                                  processed_list))
        return processed_list


if platform == "colab":
    CAPTIONS_FILE_PATH = '/content/drive/My Drive/A4/train_captions.tsv'
else:
    CAPTIONS_FILE_PATH = "D:/Padhai/IIT Delhi MS(R)/2019-20 Sem II/COL774 Machine Learning/Assignment/Assignment4/train_captions.tsv"
    
embedding_dim = 256
freq_threshold = 5
captions_preprocessing_obj = CaptionsPreprocessing(CAPTIONS_FILE_PATH)
# Out:
# VOCAB Saved
# VOCAB SIZE = 8680
# WORD2IDX Saved
# IDX2WORD Saved

# %%
class ImageCaptionsDataset(Dataset):

    def __init__(self, img_dir, captions_dict, img_transform=None, captions_transform=None):
        """
        Args:
            img_dir (string): Directory with all the images.
            captions_dict: Dictionary with captions list keyed by image ids (integers)
            img_transform (callable, optional): Optional transform to be applied
                on the image sample.

            captions_transform: (callable, optional): Optional transform to be applied
                on the caption sample (list).
        """
        self.img_dir = img_dir
        self.captions_dict = captions_dict
        self.img_transform = img_transform
        self.captions_transform = captions_transform

        self.image_ids = list(captions_dict.keys())

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        img_name = os.path.join(self.img_dir, 'image_{}.jpg'.format(self.image_ids[idx]))
        image = io.imread(img_name)
        #print("RAW IMG", image.shape)
        captions = self.captions_dict[self.image_ids[idx]]
        if self.img_transform:
            image = self.img_transform(image)
            #print("AFTER img_transform", image.shape)
            image = image.transpose((2, 0, 1))
            

        if self.captions_transform:            
            captions = self.captions_transform(captions)
            
        sample = {'image': image, 'captions': captions}

        return sample
    
    
def custom_batch(batch):
    batch_size = len(batch)
    captions = []
    normalize_img = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                         std=[0.229, 0.224, 0.225])
    
    x = list(map(lambda b: captions.extend(b['captions']),batch))    
    x = list(map(lambda b: b['image'],batch)) 
    x = list(map(lambda i: normalize_img(torch.from_numpy(i)).unsqueeze(0),x))
    #print("my after norm shape", x[0].shape)
    captions = list(map(lambda c: torch.LongTensor(c),captions))
    captions = pad_sequence(captions, batch_first=True)
    images = torch.cat(x)
    
    sample = {'image': images, 'captions': captions}    
    return sample

# %%
#ENCODER

class ResidualBlock(nn.Module):
    def __init__(self, channels, kernel_size, filters, stride=1):
        """
        Args:
            channels: Int: Number of Input channels to 1st convolutional layer
            kernel_size: integer, Symmetric Conv Window = (kernel_size, kernel_size)
            filters: python list of integers, defining the number of filters in the CONV layers of the main path
            stride: Tuple: (stride, stride)
        """
        super(ResidualBlock, self).__init__()
        F1, F2, F3 = filters
        #N, in_channels , H, W = shape
        kernel_size = (kernel_size, kernel_size)
        padding = (1,1)
        stride = (stride, stride)
        self.conv1 = nn.Conv2d(in_channels = channels, out_channels = F1, kernel_size=(1,1), stride=stride, padding=0)
        self.bn1 = nn.BatchNorm2d(F1)
        self.relu = nn.ReLU(inplace=True) 
        self.conv2 = nn.Conv2d(in_channels = F1, out_channels = F2, kernel_size=kernel_size, stride=stride, padding=padding)
        self.bn2 = nn.BatchNorm2d(F2)
        self.conv3 = nn.Conv2d(in_channels = F2, out_channels = F3, kernel_size=(1,1), stride=stride, padding=0)
        self.bn3 = nn.BatchNorm2d(F3)
        
    def forward(self, x):
        x_residual = x #backup x for residual connection
        
        #stage 1 main path
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        #print("RESI:", x.shape)
        
        #stage 2 main path
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        #print("RESI:", x.shape)
        
        #stage 3 main path
        x = self.conv3(x)
        x = self.bn3(x)
        #print("RESI:", x.shape)
        
        x += x_residual #add output with residual connection
        x = self.relu(x)
        return x
    
class ConvolutionalBlock(nn.Module):
    def __init__(self, channels, kernel_size, filters, stride=1):
        """
        Args:
            channels: Int: Number of Input channels to 1st convolutional layer
            kernel_size: integer, Symmetric Conv Window = (kernel_size, kernel_size)
            filters: python list of integers, defining the number of filters in the CONV layers of the main path
            stride: Tuple: (stride, stride)
        """
        super(ConvolutionalBlock, self).__init__()
        F1, F2, F3 = filters
        kernel_size = (kernel_size, kernel_size)
        padding = (1,1)
        stride = (stride, stride)
        
        self.conv1 = nn.Conv2d(in_channels = channels, out_channels = F1, kernel_size=(1,1), stride=stride, padding=0)
        self.bn1 = nn.BatchNorm2d(F1)
        self.relu = nn.ReLU(inplace=True) 
        self.conv2 = nn.Conv2d(in_channels = F1, out_channels = F2, kernel_size=kernel_size, stride=(1,1), padding=padding)
        self.bn2 = nn.BatchNorm2d(F2)
        self.conv3 = nn.Conv2d(in_channels = F2, out_channels = F3, kernel_size=(1,1), stride=(1,1), padding=0)
        self.bn3 = nn.BatchNorm2d(F3)
        self.conv4 = nn.Conv2d(in_channels = channels, out_channels = F3, kernel_size=(1,1), stride=stride, padding=0)
        self.bn4 = nn.BatchNorm2d(F3)
        
    def forward(self,x):
        x_residual = x #backup x for residual connection
        
        #stage 1 main path
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        #print("CONV:", x.shape)
        
        #stage 2 main path
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        #print("CONV:", x.shape)
        
        #stage 3 main path
        x = self.conv3(x)
        x = self.bn3(x)
        #print("CONV:", x.shape)
        
        #residual connection
        x_residual = self.conv4(x_residual)
        x_residual = self.bn4(x_residual)
        x += x_residual #add output with residual connection
        x = self.relu(x)
        return x
    
class ResNet50(nn.Module):
    def __init__(self, input_shape = (256, 256, 3), classes = 5):
        """
        It Implements Famous Resnet50 Architecture
        Args:
            input_shape(tuple):(callable, optional): dimensions of image sample
            classes(int):(callable, optional): Final output classes of softmax layer.
        """
        super(ResNet50, self).__init__()
        
        self.pad = nn.ZeroPad2d((1, 1, 3, 3))        
        ###STAGE1
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels=64, kernel_size=(7,7), stride = (2,2), padding=1) # convolve each of our 3-channel images with 6 different 5x5 kernels, giving us 6 feature maps
        self.batch_norm1 = nn.BatchNorm2d(64) #BatchNorm
        self.pool1 = nn.MaxPool2d((3,3), stride=(2,2), padding=1, dilation=1)
        
        ###STAGE2 channels, kernel_size=3, filters, stride=1, stage
        self.conv_block1 = ConvolutionalBlock(channels = 64, kernel_size = 3, filters = [64, 64, 256],stride = 1)
        self.residual_block1 = ResidualBlock(channels = 256, kernel_size = 3, filters = [64, 64, 256])
        
        ###STAGE3 
        self.conv_block2 = ConvolutionalBlock(channels = 256, kernel_size = 3, filters = [128, 128, 512],stride = 2)
        self.residual_block2 = ResidualBlock(channels = 512, kernel_size = 3, filters = [128, 128, 512],)
        
        ###STAGE4 
        self.conv_block3 = ConvolutionalBlock(channels = 512, kernel_size = 3, filters = [256, 256, 1024], stride = 2)
        self.residual_block3 = ResidualBlock(channels = 1024, kernel_size = 3, filters = [256, 256, 1024])
        
        ###STAGE5 
        self.conv_block4 = ConvolutionalBlock(channels = 1024, kernel_size = 3, filters = [512, 512, 2048], stride = 2)
        self.residual_block4 = ResidualBlock(channels = 2048, kernel_size = 3, filters = [512, 512, 2048])
        
        self.adaptive_pool = nn.AdaptiveAvgPool2d(output_size = (1,1))
        self.fc1 = nn.Linear(in_features=2048, out_features=classes, bias = True)
        
        
    def forward(self, x):
        #print("IP_SIZE:", x.shape)
        
        ###STAGE1        
        #print("\n STAGE1")
        x = self.conv1(x)
        x = self.batch_norm1(x)
        x = self.pool1(x)
        #print("OP_STAGE1_SIZE:", x.shape)
        
        ###STAGE2 
        #print("\n STAGE2")
        x = self.conv_block1(x)
        x = self.residual_block1(x)
        x = self.residual_block1(x)
        #print("OP_STAGE2_SIZE:", x.shape)
        
        ###STAGE3 
        #print("\n STAGE3")
        x = self.conv_block2(x)
        x = self.residual_block2(x)
        x = self.residual_block2(x)
        x = self.residual_block2(x)
        #print("OP_STAGE3_SIZE:", x.shape)
        
        ###STAGE4  
        #print("\n STAGE4")
        x = self.conv_block3(x)
        x = self.residual_block3(x)
        x = self.residual_block3(x)
        x = self.residual_block3(x)
        x = self.residual_block3(x)
        x = self.residual_block3(x)
        #print("OP_STAGE4_SIZE:", x.shape)
        
        ###STAGE5  
        #print("\n STAGE5")
        x = self.conv_block4(x)
        x = self.residual_block4(x)
        x = self.residual_block4(x)
        #print("OP_STAGE5_SIZE:", x.shape)
        
        x = self.adaptive_pool(x)
        #print("OP_ADAPTIVEPOOL_SHAPE", x.shape)
        
        x = x.view(x.size(0), -1) # Flatten Vector
        x = self.fc1(x)
        #print("OP_FC1_SIZE:", x.shape)
        return x
        
        
class Encoder(nn.Module):    
    def __init__(self, embed_dim):
        """
        CNN ENCODER
        Args:
            embed_dim(int): embedding dimension ie output dimension of last FC Layer
        Returns:
            x: Feature vector of size(BatchSize, embed_dim)
        """
        super(Encoder, self).__init__()
        self.resnet50 = ResNet50(classes = embed_dim)
        
    def forward(self, x):
        return self.resnet50(x)
    
class AttentionBlock(nn.Module):
    def __init__(self, embed_dim, units, vocab_size):
        super(AttentionBlock, self).__init__()
        self.W1 = nn.Linear(in_features = embed_dim, out_features = units)
        self.W2 = nn.Linear(in_features=units, out_features=units)
        self.V = nn.Linear(in_features=units, out_features=1)
        self.tanh = nn.Tanh()
        self.softmax = nn.Softmax(dim=1)
        
    def forward(self, img_features, hidden):
        
        hidden = hidden.unsqueeze(dim=1)
        hidden = hidden.double()
        #print("feature and hidden shape",img_features.shape, hidden.shape)
        combined_score = self.tanh(self.W1(img_features) + self.W2(hidden))
        
        attention_weights = self.softmax(self.V(combined_score))
        context_vector = attention_weights * img_features
        context_vector = torch.sum(context_vector, dim=1)
        
        return context_vector, attention_weights    



class Decoder(nn.Module):
    def __init__(self, embed_dim, lstm_hidden_size,lstm_layers=1):
        super(Decoder, self).__init__()
        self.lstm_hidden_size = lstm_hidden_size
        self.vocab_size = len(VOCAB)
        print("VOCAB SIZE = ", self.vocab_size)
        
        self.lstm = nn.LSTM(input_size = embed_dim, hidden_size = lstm_hidden_size,
                            num_layers = lstm_layers, batch_first = True)
        
        self.linear = nn.Linear(lstm_hidden_size, self.vocab_size)        
        self.embed = nn.Embedding(self.vocab_size, embed_dim)
        
        self.attention = AttentionBlock(embed_dim, lstm_hidden_size, self.vocab_size)

        
    def forward(self, image_features, image_captions):
        
        if phase == "Train":
            image_features = torch.Tensor.repeat_interleave(image_features, repeats=5 , dim=0)
        image_features = image_features.unsqueeze(1)
        
        hidden = torch.zeros((image_features.shape[0], self.lstm_hidden_size))
        if device == "cuda":
          hidden = hidden.to(torch.device("cuda:0"))
        
        context, attention = self.attention(image_features, hidden)
        
        embedded_captions = self.embed(image_captions)
        #print("EMBED SHAPE", embedded_captions.shape)
        #print("SHAPES BEFORE CONCAT",context.unsqueeze(dim=1).shape, embedded_captions[:,:-1].shape)
        input_lstm = torch.cat((context.unsqueeze(dim=1), embedded_captions[:,:-1]), dim = 1)
        
        lstm_outputs, _ = self.lstm(input_lstm)        
        lstm_outputs = self.linear(lstm_outputs)
        #print("lstm_outputs.shape", lstm_outputs.shape)
        
        
        return lstm_outputs

# %%
class ImageCaptionsNet(nn.Module):
    def __init__(self):
        super(ImageCaptionsNet, self).__init__()        
        ##CNN ENCODER RESNET-50        
        self.Encoder = Encoder(embed_dim = embedding_dim)
        ## RNN DECODER
        self.Decoder = Decoder(embedding_dim, units, 1)    
        print("units", units, "embed_dim", embedding_dim)

    def forward(self, img_batch, cap_batch):
        x = self.Encoder(img_batch)
        x = self.Decoder(x, cap_batch)
        return x
    
units = 512
if restore == False:
    net = ImageCaptionsNet()
    net = net.double()
    
    if parallel == True and device != "cpu":
        print("Parallel Processing enabled")
        net = nn.DataParallel(net)

    if device == "cpu":
        print("Device to CPU")
    else:
        print("Device to CUDA")
        net = net.to(torch.device("cuda:0"))
# Out:
# VOCAB SIZE =  8680
# units 512 embed_dim 256
# Parallel Processing enabled
# Device to CUDA

# %%
'''Save and Restore Checkpoints'''
def create_checkpoint(path,model, optim_obj, loss_obj,iteration, epoch):
    checkpoint = {'epoch': epoch,
                  'iteration': iteration,
                  'model_state_dict': model.module.state_dict()}

    if platform == "colab":
        directory = '/content/drive/My Drive/A4/comp_checkpoint/'
    else:
        directory = '../comp_checkpoint/'

    torch.save(checkpoint, directory + path)
    
def restore_checkpoint(path):
    new_state_dict = collections.OrderedDict()
    if platform == "colab":
        directory = '/content/drive/My Drive/A4/comp_checkpoint/'
        checkpoint = torch.load(directory + path, map_location=torch.device('cpu'))
    else:
        directory = '../comp_checkpoint/'
        checkpoint = torch.load(directory + path, map_location=torch.device('cpu'))    
    
    epoch = checkpoint['epoch']
    new_state_dict = checkpoint['model_state_dict']
    iteration = checkpoint['iteration']
    #optimizer_state_dict = checkpoint['optimizer_state_dict']
    #loss_obj = checkpoint['loss']
    print("Iterations = {}, Epoch = {}".format(iteration, epoch))
    return new_state_dict

# %% [markdown]
# ### TRAIN LOOP

# %%
if platform == "colab":
    IMAGE_DIR = '/content/drive/My Drive/train_images/'
else:
    IMAGE_DIR = 'D:/Padhai/IIT Delhi MS(R)/2019-20 Sem II/COL774 Machine Learning/Assignment/Assignment4/train_images/'

if restore == True:
    net = ImageCaptionsNet()
    net = net.double()
    new_state_dict = collections.OrderedDict()
    new_state_dict = restore_checkpoint("own_chkpt_finaltry.pth")    
    
    print("State Dictionary Loaded Successfully.")
    net = nn.DataParallel(net)
    net = net.to(torch.device("cuda:0"))

# Creating the Dataset
train_dataset = ImageCaptionsDataset(
    IMAGE_DIR, captions_preprocessing_obj.captions_dict, img_transform=img_transform,
    captions_transform=captions_preprocessing_obj.captions_transform
)

# Define your hyperparameters
NUMBER_OF_EPOCHS = 3
LEARNING_RATE = 2e-3
BATCH_SIZE = 24
NUM_WORKERS = 0 # Parallel threads for dataloading

'''cw = torch.ones(len(VOCAB), dtype=torch.double)
cw[WORD2IDX["<pad>"]] = 0
cw = cw.to(torch.device("cuda:0"))'''

loss_function = nn.CrossEntropyLoss(ignore_index=WORD2IDX["<pad>"])
optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)
print("TOTAL EPOCHS: {}, BATCH SIZE: {}, OPTIMIZER: {}".format(NUMBER_OF_EPOCHS, BATCH_SIZE, optimizer))
loss_list = []
# Creating the DataLoader for batching purposes
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS,
                          collate_fn=custom_batch)

if device != "cpu":
    os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
    torch.backends.cudnn.benchmark = True
    #torch.cuda.set_device(1)
t0 = time()
for epoch in range(NUMBER_OF_EPOCHS):
    print("$$$$$----EPOCH {}----$$$$$$".format(epoch+1))
    iteration = 0
    
    if (iteration+1)%100 == 0:
        LEARNING_RATE *= 0.94
        for param_group in optimizer.param_groups:
            param_group['lr'] = LEARNING_RATE
        print("\nLEARNING RATE =", LEARNING_RATE, optimizer)
    

    for batch_idx, sample in enumerate(train_loader):
        iteration +=1
        
        net.zero_grad()

        image_batch, captions_batch = sample['image'], sample['captions']
        
        #print("image_shape", image_batch.shape)
        #print("batch_shape", captions_batch.shape)
        
        #print("MY INPUT", image_batch)

        # If GPU training required
        if device != "cpu":
          #print("cuda")
          image_batch, captions_batch = image_batch.to(torch.device("cuda:0")), captions_batch.to(torch.device("cuda:0"))
        
        output_captions = net(image_batch, captions_batch)

        #print("size for loss", output_captions.shape, captions_batch.shape)
        #torch.Size([10, 26, 9934]) torch.Size([10, 26])
        loss = loss_function(output_captions.reshape(-1, output_captions.shape[2]), captions_batch.reshape(-1))
        loss_list.append(loss.item())
        
        loss.backward()
        optimizer.step()
        
        if iteration%25 == 0:
            create_checkpoint("own_chkpt_finaltry.pth", net, optimizer, loss, iteration, epoch+1)
        print("ITERATION:[{}/{}] | LOSS: {} | EPOCH = [{}/{}] | TIME ELAPSED ={}Mins".format(iteration, round(29000/BATCH_SIZE)+1,
              round(loss.item(), 6), epoch+1, NUMBER_OF_EPOCHS, round((time()-t0)/60,2)))
    print("\n$$Loss = {},EPOCH: [{}/{}]\n\n".format(round(loss.item(), 6), epoch+1, NUMBER_OF_EPOCHS))
    create_checkpoint("Epoch_own_finaltry.pth", net, optimizer, loss, iteration, epoch+1)

create_checkpoint("Full_Model_own_finaltry.pth", net, optimizer, loss, iteration, epoch+1)
# Out:
# TOTAL EPOCHS: 3, BATCH SIZE: 24, OPTIMIZER: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.002
#     weight_decay: 0
# )
# $$$$$----EPOCH 1----$$$$$$
# ITERATION:[1/1209] | LOSS: 9.064826 | EPOCH = [1/3] | TIME ELAPSED =0.35Mins
# ITERATION:[2/1209] | LOSS: 8.629498 | EPOCH = [1/3] | TIME ELAPSED =0.63Mins
# ITERATION:[3/1209] | LOSS: 7.915487 | EPOCH = [1/3] | TIME ELAPSED =0.94Mins
# ITERATION:[4/1209] | LOSS: 6.714126 | EPOCH = [1/3] | TIME ELAPSED =1.22Mins
# ITERATION:[5/1209] | LOSS: 5.663617 | EPOCH = [1/3] | TIME ELAPSED =1.5Mins
# ITERATION:[6/1209] | LOSS: 5.21491 | EPOCH = [1/3] | TIME ELAPSED =1.77Mins
# ITERATION:[7/1209] | LOSS: 4.546738 | EPOCH = [1/3] | TIME ELAPSED =2.26Mins
# ITERATION:[8/1209] | LOSS: 4.415124 | EPOCH = [1/3] | TIME ELAPSED =2.54Mins
# ITERATION:[9/1209] | LOSS: 4.484773 | EPOCH = [1/3] | TIME ELAPSED =2.84Mins
# ITERATION:[10/1209] | LOSS: 4.474193 | EPOCH = [1/3] | TIME ELAPSED =3.12Mins
# ITERATION:[11/1209] | LOSS: 4.411329 | EPOCH = [1/3] | TIME ELAPSED =3.4Mins
# ITERATION:[12/1209] | LOSS: 4.358378 | EPOCH = [1/3] | TIME ELAPSED =3.68Mins
# ITERATION:[13/1209] | LOSS: 4.203488 | EPOCH = [1/3] | TIME ELAPSED =4.0Mins
# ITERATION:[14/1209] | LOSS: 4.162419 | EPOCH = [1/3] | TIME ELAPSED =4.26Mins
# ITERATION:[15/1209] | LOSS: 4.108731 | EPOCH = [1/3] | TIME ELAPSED =4.54Mins
# ITERATION:[16/1209] | LOSS: 3.98841 | EPOCH = [1/3] | TIME ELAPSED =4.81Mins
# ITERATION:[17/1209] | LOSS: 3.973508 | EPOCH = [1/3] | TIME ELAPSED =5.1Mins
# ITERATION:[18/1209] | LOSS: 4.105652 | EPOCH = [1/3] | TIME ELAPSED =5.39Mins
# ITERATION:[19/1209] | LOSS: 3.926647 | EPOCH = [1/3] | TIME ELAPSED =5.67Mins
# ITERATION:[20/1209] | LOSS: 3.811195 | EPOCH = [1/3] | TIME ELAPSED =5.95Mins
# ITERATION:[21/1209] | LOSS: 3.852889 | EPOCH = [1/3] | TIME ELAPSED =6.23Mins
# ITERATION:[22/1209] | LOSS: 3.83262 | EPOCH = [1/3] | TIME ELAPSED =6.53Mins
# ITERATION:[23/1209] | LOSS: 3.707747 | EPOCH = [1/3] | TIME ELAPSED =6.81Mins
# ITERATION:[24/1209] | LOSS: 3.90541 | EPOCH = [1/3] | TIME ELAPSED =7.09Mins
# ITERATION:[25/1209] | LOSS: 3.883058 | EPOCH = [1/3] | TIME ELAPSED =7.39Mins
# ITERATION:[26/1209] | LOSS: 3.874119 | EPOCH = [1/3] | TIME ELAPSED =7.66Mins
# ITERATION:[27/1209] | LOSS: 3.780061 | EPOCH = [1/3] | TIME ELAPSED =7.93Mins
# ITERATION:[28/1209] | LOSS: 3.730007 | EPOCH = [1/3] | TIME ELAPSED =8.2Mins
# ITERATION:[29/1209] | LOSS: 3.713527 | EPOCH = [1/3] | TIME ELAPSED =8.49Mins
# ITERATION:[30/1209] | LOSS: 3.668073 | EPOCH = [1/3] | TIME ELAPSED =8.74Mins
# ITERATION:[31/1209] | LOSS: 3.64775 | EPOCH = [1/3] | TIME ELAPSED =9.03Mins
# ITERATION:[32/1209] | LOSS: 3.603326 | EPOCH = [1/3] | TIME ELAPSED =9.32Mins
# ITERATION:[33/1209] | LOSS: 3.557973 | EPOCH = [1/3] | TIME ELAPSED =9.59Mins
# ITERATION:[34/1209] | LOSS: 3.680319 | EPOCH = [1/3] | TIME ELAPSED =9.88Mins
# ITERATION:[35/1209] | LOSS: 3.666857 | EPOCH = [1/3] | TIME ELAPSED =10.16Mins
# ITERATION:[36/1209] | LOSS: 3.550451 | EPOCH = [1/3] | TIME ELAPSED =10.45Mins
# ITERATION:[37/1209] | LOSS: 3.325012 | EPOCH = [1/3] | TIME ELAPSED =10.72Mins
# ITERATION:[38/1209] | LOSS: 3.516775 | EPOCH = [1/3] | TIME ELAPSED =11.0Mins
# ITERATION:[39/1209] | LOSS: 3.523615 | EPOCH = [1/3] | TIME ELAPSED =11.28Mins
# ITERATION:[40/1209] | LOSS: 3.520955 | EPOCH = [1/3] | TIME ELAPSED =11.56Mins
# ITERATION:[41/1209] | LOSS: 3.597735 | EPOCH = [1/3] | TIME ELAPSED =11.81Mins
# ITERATION:[42/1209] | LOSS: 3.470979 | EPOCH = [1/3] | TIME ELAPSED =12.09Mins
# ITERATION:[43/1209] | LOSS: 3.531645 | EPOCH = [1/3] | TIME ELAPSED =12.35Mins
# ITERATION:[44/1209] | LOSS: 3.492512 | EPOCH = [1/3] | TIME ELAPSED =12.62Mins
# ITERATION:[45/1209] | LOSS: 3.563963 | EPOCH = [1/3] | TIME ELAPSED =12.9Mins
# ITERATION:[46/1209] | LOSS: 3.383076 | EPOCH = [1/3] | TIME ELAPSED =13.17Mins
# ITERATION:[47/1209] | LOSS: 3.367474 | EPOCH = [1/3] | TIME ELAPSED =13.44Mins
# ITERATION:[48/1209] | LOSS: 3.500974 | EPOCH = [1/3] | TIME ELAPSED =13.74Mins
# ITERATION:[49/1209] | LOSS: 3.434371 | EPOCH = [1/3] | TIME ELAPSED =14.02Mins
# ITERATION:[50/1209] | LOSS: 3.415845 | EPOCH = [1/3] | TIME ELAPSED =14.31Mins
# ITERATION:[51/1209] | LOSS: 3.264216 | EPOCH = [1/3] | TIME ELAPSED =14.6Mins
# ITERATION:[52/1209] | LOSS: 3.280003 | EPOCH = [1/3] | TIME ELAPSED =14.88Mins
# ITERATION:[53/1209] | LOSS: 3.204477 | EPOCH = [1/3] | TIME ELAPSED =15.14Mins
# ITERATION:[54/1209] | LOSS: 3.289585 | EPOCH = [1/3] | TIME ELAPSED =15.41Mins
# ITERATION:[55/1209] | LOSS: 3.33618 | EPOCH = [1/3] | TIME ELAPSED =15.67Mins
# ITERATION:[56/1209] | LOSS: 3.277017 | EPOCH = [1/3] | TIME ELAPSED =15.95Mins
# ITERATION:[57/1209] | LOSS: 3.259414 | EPOCH = [1/3] | TIME ELAPSED =16.23Mins
# ITERATION:[58/1209] | LOSS: 3.320518 | EPOCH = [1/3] | TIME ELAPSED =16.48Mins
# ITERATION:[59/1209] | LOSS: 3.354869 | EPOCH = [1/3] | TIME ELAPSED =16.76Mins
# ITERATION:[60/1209] | LOSS: 3.18089 | EPOCH = [1/3] | TIME ELAPSED =17.05Mins
# ITERATION:[61/1209] | LOSS: 3.213771 | EPOCH = [1/3] | TIME ELAPSED =17.32Mins
# ITERATION:[62/1209] | LOSS: 3.147387 | EPOCH = [1/3] | TIME ELAPSED =17.58Mins
# ITERATION:[63/1209] | LOSS: 3.103387 | EPOCH = [1/3] | TIME ELAPSED =17.85Mins
# ITERATION:[64/1209] | LOSS: 3.167436 | EPOCH = [1/3] | TIME ELAPSED =18.13Mins
# ITERATION:[65/1209] | LOSS: 3.103532 | EPOCH = [1/3] | TIME ELAPSED =18.4Mins
# ITERATION:[66/1209] | LOSS: 3.254043 | EPOCH = [1/3] | TIME ELAPSED =18.69Mins
# ITERATION:[67/1209] | LOSS: 2.975871 | EPOCH = [1/3] | TIME ELAPSED =18.98Mins
# ITERATION:[68/1209] | LOSS: 2.997712 | EPOCH = [1/3] | TIME ELAPSED =19.25Mins
# ITERATION:[69/1209] | LOSS: 3.143218 | EPOCH = [1/3] | TIME ELAPSED =19.52Mins
# ITERATION:[70/1209] | LOSS: 3.100038 | EPOCH = [1/3] | TIME ELAPSED =19.8Mins
# ITERATION:[71/1209] | LOSS: 3.042991 | EPOCH = [1/3] | TIME ELAPSED =20.07Mins
# ITERATION:[72/1209] | LOSS: 3.139929 | EPOCH = [1/3] | TIME ELAPSED =20.36Mins
# ITERATION:[73/1209] | LOSS: 3.144967 | EPOCH = [1/3] | TIME ELAPSED =20.64Mins
# ITERATION:[74/1209] | LOSS: 2.822094 | EPOCH = [1/3] | TIME ELAPSED =20.9Mins
# ITERATION:[75/1209] | LOSS: 3.066979 | EPOCH = [1/3] | TIME ELAPSED =21.2Mins
# ITERATION:[76/1209] | LOSS: 3.007638 | EPOCH = [1/3] | TIME ELAPSED =21.51Mins
# ITERATION:[77/1209] | LOSS: 3.119823 | EPOCH = [1/3] | TIME ELAPSED =21.79Mins
# ITERATION:[78/1209] | LOSS: 2.860333 | EPOCH = [1/3] | TIME ELAPSED =22.08Mins
# ITERATION:[79/1209] | LOSS: 3.037855 | EPOCH = [1/3] | TIME ELAPSED =22.35Mins
# ITERATION:[80/1209] | LOSS: 3.037039 | EPOCH = [1/3] | TIME ELAPSED =22.61Mins
# ITERATION:[81/1209] | LOSS: 3.194607 | EPOCH = [1/3] | TIME ELAPSED =22.88Mins
# ITERATION:[82/1209] | LOSS: 3.053373 | EPOCH = [1/3] | TIME ELAPSED =23.15Mins
# ITERATION:[83/1209] | LOSS: 2.998112 | EPOCH = [1/3] | TIME ELAPSED =23.42Mins
# ITERATION:[84/1209] | LOSS: 3.023664 | EPOCH = [1/3] | TIME ELAPSED =23.69Mins
# ITERATION:[85/1209] | LOSS: 2.976542 | EPOCH = [1/3] | TIME ELAPSED =23.98Mins
# ITERATION:[86/1209] | LOSS: 2.864943 | EPOCH = [1/3] | TIME ELAPSED =24.27Mins
# ITERATION:[87/1209] | LOSS: 3.000301 | EPOCH = [1/3] | TIME ELAPSED =24.56Mins
# ITERATION:[88/1209] | LOSS: 3.11407 | EPOCH = [1/3] | TIME ELAPSED =24.83Mins
# ITERATION:[89/1209] | LOSS: 3.089967 | EPOCH = [1/3] | TIME ELAPSED =25.13Mins
# ITERATION:[90/1209] | LOSS: 2.939243 | EPOCH = [1/3] | TIME ELAPSED =25.4Mins
# ITERATION:[91/1209] | LOSS: 3.213422 | EPOCH = [1/3] | TIME ELAPSED =25.68Mins
# ITERATION:[92/1209] | LOSS: 3.039334 | EPOCH = [1/3] | TIME ELAPSED =25.98Mins
# ITERATION:[93/1209] | LOSS: 2.961313 | EPOCH = [1/3] | TIME ELAPSED =26.24Mins
# ITERATION:[94/1209] | LOSS: 2.875022 | EPOCH = [1/3] | TIME ELAPSED =26.53Mins
# ITERATION:[95/1209] | LOSS: 2.95863 | EPOCH = [1/3] | TIME ELAPSED =26.77Mins
# ITERATION:[96/1209] | LOSS: 2.979194 | EPOCH = [1/3] | TIME ELAPSED =27.06Mins
# ITERATION:[97/1209] | LOSS: 3.095479 | EPOCH = [1/3] | TIME ELAPSED =27.34Mins
# ITERATION:[98/1209] | LOSS: 2.987028 | EPOCH = [1/3] | TIME ELAPSED =27.64Mins
# ITERATION:[99/1209] | LOSS: 2.579644 | EPOCH = [1/3] | TIME ELAPSED =27.91Mins
# ITERATION:[100/1209] | LOSS: 2.940896 | EPOCH = [1/3] | TIME ELAPSED =28.21Mins
# ITERATION:[101/1209] | LOSS: 2.823844 | EPOCH = [1/3] | TIME ELAPSED =28.47Mins
# ITERATION:[102/1209] | LOSS: 3.071434 | EPOCH = [1/3] | TIME ELAPSED =28.78Mins
# ITERATION:[103/1209] | LOSS: 2.951709 | EPOCH = [1/3] | TIME ELAPSED =29.04Mins
# ITERATION:[104/1209] | LOSS: 2.940259 | EPOCH = [1/3] | TIME ELAPSED =29.32Mins
# ITERATION:[105/1209] | LOSS: 2.931199 | EPOCH = [1/3] | TIME ELAPSED =29.6Mins
# ITERATION:[106/1209] | LOSS: 2.958542 | EPOCH = [1/3] | TIME ELAPSED =29.88Mins
# ITERATION:[107/1209] | LOSS: 2.884731 | EPOCH = [1/3] | TIME ELAPSED =30.15Mins
# ITERATION:[108/1209] | LOSS: 2.932549 | EPOCH = [1/3] | TIME ELAPSED =30.44Mins
# ITERATION:[109/1209] | LOSS: 2.882089 | EPOCH = [1/3] | TIME ELAPSED =30.72Mins
# ITERATION:[110/1209] | LOSS: 2.95308 | EPOCH = [1/3] | TIME ELAPSED =31.01Mins
# ITERATION:[111/1209] | LOSS: 2.983966 | EPOCH = [1/3] | TIME ELAPSED =31.29Mins
# ITERATION:[112/1209] | LOSS: 2.935968 | EPOCH = [1/3] | TIME ELAPSED =31.56Mins
# ITERATION:[113/1209] | LOSS: 2.825239 | EPOCH = [1/3] | TIME ELAPSED =31.84Mins
# ITERATION:[114/1209] | LOSS: 2.732524 | EPOCH = [1/3] | TIME ELAPSED =32.1Mins
# ITERATION:[115/1209] | LOSS: 2.893244 | EPOCH = [1/3] | TIME ELAPSED =32.37Mins
# ITERATION:[116/1209] | LOSS: 2.770189 | EPOCH = [1/3] | TIME ELAPSED =32.64Mins
# ITERATION:[117/1209] | LOSS: 2.808087 | EPOCH = [1/3] | TIME ELAPSED =32.92Mins
# ITERATION:[118/1209] | LOSS: 2.816517 | EPOCH = [1/3] | TIME ELAPSED =33.18Mins
# ITERATION:[119/1209] | LOSS: 2.993592 | EPOCH = [1/3] | TIME ELAPSED =33.43Mins
# ITERATION:[120/1209] | LOSS: 2.893416 | EPOCH = [1/3] | TIME ELAPSED =33.69Mins
# ITERATION:[121/1209] | LOSS: 2.846547 | EPOCH = [1/3] | TIME ELAPSED =33.97Mins
# ITERATION:[122/1209] | LOSS: 3.039636 | EPOCH = [1/3] | TIME ELAPSED =34.24Mins
# ITERATION:[123/1209] | LOSS: 2.929814 | EPOCH = [1/3] | TIME ELAPSED =34.51Mins
# ITERATION:[124/1209] | LOSS: 2.798576 | EPOCH = [1/3] | TIME ELAPSED =34.79Mins
# ITERATION:[125/1209] | LOSS: 2.772671 | EPOCH = [1/3] | TIME ELAPSED =35.08Mins
# ITERATION:[126/1209] | LOSS: 2.925154 | EPOCH = [1/3] | TIME ELAPSED =35.35Mins
# ITERATION:[127/1209] | LOSS: 2.882924 | EPOCH = [1/3] | TIME ELAPSED =35.62Mins
# ITERATION:[128/1209] | LOSS: 2.838961 | EPOCH = [1/3] | TIME ELAPSED =35.9Mins
# ITERATION:[129/1209] | LOSS: 2.961052 | EPOCH = [1/3] | TIME ELAPSED =36.17Mins
# ITERATION:[130/1209] | LOSS: 2.824803 | EPOCH = [1/3] | TIME ELAPSED =36.43Mins
# ITERATION:[131/1209] | LOSS: 2.801997 | EPOCH = [1/3] | TIME ELAPSED =36.69Mins
# ITERATION:[132/1209] | LOSS: 2.685639 | EPOCH = [1/3] | TIME ELAPSED =36.96Mins
# ITERATION:[133/1209] | LOSS: 2.864254 | EPOCH = [1/3] | TIME ELAPSED =37.24Mins
# ITERATION:[134/1209] | LOSS: 2.809348 | EPOCH = [1/3] | TIME ELAPSED =37.48Mins
# ITERATION:[135/1209] | LOSS: 2.882946 | EPOCH = [1/3] | TIME ELAPSED =37.76Mins
# ITERATION:[136/1209] | LOSS: 2.811011 | EPOCH = [1/3] | TIME ELAPSED =38.05Mins
# ITERATION:[137/1209] | LOSS: 2.882698 | EPOCH = [1/3] | TIME ELAPSED =38.33Mins
# ITERATION:[138/1209] | LOSS: 2.942825 | EPOCH = [1/3] | TIME ELAPSED =38.61Mins
# ITERATION:[139/1209] | LOSS: 2.729574 | EPOCH = [1/3] | TIME ELAPSED =38.91Mins
# ITERATION:[140/1209] | LOSS: 2.903605 | EPOCH = [1/3] | TIME ELAPSED =39.18Mins
# ITERATION:[141/1209] | LOSS: 2.711058 | EPOCH = [1/3] | TIME ELAPSED =39.45Mins
# ITERATION:[142/1209] | LOSS: 2.795049 | EPOCH = [1/3] | TIME ELAPSED =39.73Mins
# ITERATION:[143/1209] | LOSS: 2.920265 | EPOCH = [1/3] | TIME ELAPSED =39.97Mins
# ITERATION:[144/1209] | LOSS: 2.893376 | EPOCH = [1/3] | TIME ELAPSED =40.24Mins
# ITERATION:[145/1209] | LOSS: 3.007221 | EPOCH = [1/3] | TIME ELAPSED =40.52Mins
# ITERATION:[146/1209] | LOSS: 3.009794 | EPOCH = [1/3] | TIME ELAPSED =40.79Mins
# ITERATION:[147/1209] | LOSS: 2.662574 | EPOCH = [1/3] | TIME ELAPSED =41.07Mins
# ITERATION:[148/1209] | LOSS: 2.697053 | EPOCH = [1/3] | TIME ELAPSED =41.33Mins
# ITERATION:[149/1209] | LOSS: 2.728802 | EPOCH = [1/3] | TIME ELAPSED =41.6Mins
# ITERATION:[150/1209] | LOSS: 2.898355 | EPOCH = [1/3] | TIME ELAPSED =41.89Mins
# ITERATION:[151/1209] | LOSS: 2.708707 | EPOCH = [1/3] | TIME ELAPSED =42.18Mins
# ITERATION:[152/1209] | LOSS: 2.64332 | EPOCH = [1/3] | TIME ELAPSED =42.46Mins
# ITERATION:[153/1209] | LOSS: 2.895359 | EPOCH = [1/3] | TIME ELAPSED =42.74Mins
# ITERATION:[154/1209] | LOSS: 2.746723 | EPOCH = [1/3] | TIME ELAPSED =43.0Mins
# ITERATION:[155/1209] | LOSS: 2.707189 | EPOCH = [1/3] | TIME ELAPSED =43.27Mins
# ITERATION:[156/1209] | LOSS: 2.679316 | EPOCH = [1/3] | TIME ELAPSED =43.53Mins
# ITERATION:[157/1209] | LOSS: 2.785635 | EPOCH = [1/3] | TIME ELAPSED =43.85Mins
# ITERATION:[158/1209] | LOSS: 2.735279 | EPOCH = [1/3] | TIME ELAPSED =44.11Mins
# ITERATION:[159/1209] | LOSS: 2.919741 | EPOCH = [1/3] | TIME ELAPSED =44.37Mins
# ITERATION:[160/1209] | LOSS: 2.790939 | EPOCH = [1/3] | TIME ELAPSED =44.63Mins
# ITERATION:[161/1209] | LOSS: 2.726729 | EPOCH = [1/3] | TIME ELAPSED =44.89Mins
# ITERATION:[162/1209] | LOSS: 2.609166 | EPOCH = [1/3] | TIME ELAPSED =45.17Mins
# ITERATION:[163/1209] | LOSS: 2.708846 | EPOCH = [1/3] | TIME ELAPSED =45.44Mins
# ITERATION:[164/1209] | LOSS: 2.706214 | EPOCH = [1/3] | TIME ELAPSED =45.73Mins
# ITERATION:[165/1209] | LOSS: 2.579519 | EPOCH = [1/3] | TIME ELAPSED =46.32Mins
# ITERATION:[166/1209] | LOSS: 2.850483 | EPOCH = [1/3] | TIME ELAPSED =46.59Mins
# ITERATION:[167/1209] | LOSS: 2.909712 | EPOCH = [1/3] | TIME ELAPSED =46.88Mins
# ITERATION:[168/1209] | LOSS: 2.775972 | EPOCH = [1/3] | TIME ELAPSED =47.15Mins
# ITERATION:[169/1209] | LOSS: 2.660056 | EPOCH = [1/3] | TIME ELAPSED =47.43Mins
# ITERATION:[170/1209] | LOSS: 2.59715 | EPOCH = [1/3] | TIME ELAPSED =47.72Mins
# ITERATION:[171/1209] | LOSS: 2.629131 | EPOCH = [1/3] | TIME ELAPSED =47.98Mins
# ITERATION:[172/1209] | LOSS: 2.787063 | EPOCH = [1/3] | TIME ELAPSED =48.25Mins
# ITERATION:[173/1209] | LOSS: 2.670301 | EPOCH = [1/3] | TIME ELAPSED =48.53Mins
# ITERATION:[174/1209] | LOSS: 2.832953 | EPOCH = [1/3] | TIME ELAPSED =48.8Mins
# ITERATION:[175/1209] | LOSS: 2.717319 | EPOCH = [1/3] | TIME ELAPSED =49.1Mins
# ITERATION:[176/1209] | LOSS: 2.706498 | EPOCH = [1/3] | TIME ELAPSED =49.37Mins
# ITERATION:[177/1209] | LOSS: 2.665084 | EPOCH = [1/3] | TIME ELAPSED =49.6Mins
# ITERATION:[178/1209] | LOSS: 2.648266 | EPOCH = [1/3] | TIME ELAPSED =49.87Mins
# ITERATION:[179/1209] | LOSS: 2.519289 | EPOCH = [1/3] | TIME ELAPSED =50.15Mins
# ITERATION:[180/1209] | LOSS: 2.936915 | EPOCH = [1/3] | TIME ELAPSED =50.43Mins
# ITERATION:[181/1209] | LOSS: 2.680097 | EPOCH = [1/3] | TIME ELAPSED =50.71Mins
# ITERATION:[182/1209] | LOSS: 2.705704 | EPOCH = [1/3] | TIME ELAPSED =50.98Mins
# ITERATION:[183/1209] | LOSS: 2.789708 | EPOCH = [1/3] | TIME ELAPSED =51.24Mins
# ITERATION:[184/1209] | LOSS: 2.706495 | EPOCH = [1/3] | TIME ELAPSED =51.52Mins
# ITERATION:[185/1209] | LOSS: 2.595328 | EPOCH = [1/3] | TIME ELAPSED =51.79Mins
# ITERATION:[186/1209] | LOSS: 2.60737 | EPOCH = [1/3] | TIME ELAPSED =52.07Mins
# ITERATION:[187/1209] | LOSS: 2.729888 | EPOCH = [1/3] | TIME ELAPSED =52.33Mins
# ITERATION:[188/1209] | LOSS: 2.668482 | EPOCH = [1/3] | TIME ELAPSED =52.6Mins
# ITERATION:[189/1209] | LOSS: 2.66488 | EPOCH = [1/3] | TIME ELAPSED =52.87Mins
# ITERATION:[190/1209] | LOSS: 2.755402 | EPOCH = [1/3] | TIME ELAPSED =53.15Mins
# ITERATION:[191/1209] | LOSS: 2.632497 | EPOCH = [1/3] | TIME ELAPSED =53.43Mins
# ITERATION:[192/1209] | LOSS: 2.812119 | EPOCH = [1/3] | TIME ELAPSED =53.7Mins
# ITERATION:[193/1209] | LOSS: 2.525432 | EPOCH = [1/3] | TIME ELAPSED =53.98Mins
# ITERATION:[194/1209] | LOSS: 2.670937 | EPOCH = [1/3] | TIME ELAPSED =54.27Mins
# ITERATION:[195/1209] | LOSS: 2.869604 | EPOCH = [1/3] | TIME ELAPSED =54.53Mins
# ITERATION:[196/1209] | LOSS: 2.512084 | EPOCH = [1/3] | TIME ELAPSED =54.81Mins
# ITERATION:[197/1209] | LOSS: 2.725464 | EPOCH = [1/3] | TIME ELAPSED =55.09Mins
# ITERATION:[198/1209] | LOSS: 2.557597 | EPOCH = [1/3] | TIME ELAPSED =55.36Mins
# ITERATION:[199/1209] | LOSS: 2.709849 | EPOCH = [1/3] | TIME ELAPSED =55.61Mins
# ITERATION:[200/1209] | LOSS: 2.648872 | EPOCH = [1/3] | TIME ELAPSED =55.92Mins
# ITERATION:[201/1209] | LOSS: 2.774348 | EPOCH = [1/3] | TIME ELAPSED =56.2Mins
# ITERATION:[202/1209] | LOSS: 2.480689 | EPOCH = [1/3] | TIME ELAPSED =56.46Mins
# ITERATION:[203/1209] | LOSS: 2.797017 | EPOCH = [1/3] | TIME ELAPSED =56.73Mins
# ITERATION:[204/1209] | LOSS: 2.637854 | EPOCH = [1/3] | TIME ELAPSED =56.99Mins
# ITERATION:[205/1209] | LOSS: 2.717771 | EPOCH = [1/3] | TIME ELAPSED =57.26Mins
# ITERATION:[206/1209] | LOSS: 2.700688 | EPOCH = [1/3] | TIME ELAPSED =57.53Mins
# ITERATION:[207/1209] | LOSS: 2.60311 | EPOCH = [1/3] | TIME ELAPSED =57.81Mins
# ITERATION:[208/1209] | LOSS: 2.701494 | EPOCH = [1/3] | TIME ELAPSED =58.09Mins
# ITERATION:[209/1209] | LOSS: 2.542501 | EPOCH = [1/3] | TIME ELAPSED =58.35Mins
# ITERATION:[210/1209] | LOSS: 2.650691 | EPOCH = [1/3] | TIME ELAPSED =58.62Mins
# ITERATION:[211/1209] | LOSS: 2.572806 | EPOCH = [1/3] | TIME ELAPSED =58.89Mins
# ITERATION:[212/1209] | LOSS: 2.676222 | EPOCH = [1/3] | TIME ELAPSED =59.18Mins
# ITERATION:[213/1209] | LOSS: 2.600272 | EPOCH = [1/3] | TIME ELAPSED =59.46Mins
# ITERATION:[214/1209] | LOSS: 2.63153 | EPOCH = [1/3] | TIME ELAPSED =59.75Mins
# ITERATION:[215/1209] | LOSS: 2.746808 | EPOCH = [1/3] | TIME ELAPSED =60.02Mins
# ITERATION:[216/1209] | LOSS: 2.572404 | EPOCH = [1/3] | TIME ELAPSED =60.28Mins
# ITERATION:[217/1209] | LOSS: 2.563675 | EPOCH = [1/3] | TIME ELAPSED =60.57Mins
# ITERATION:[218/1209] | LOSS: 2.678011 | EPOCH = [1/3] | TIME ELAPSED =60.85Mins
# ITERATION:[219/1209] | LOSS: 2.716701 | EPOCH = [1/3] | TIME ELAPSED =61.11Mins
# ITERATION:[220/1209] | LOSS: 2.502039 | EPOCH = [1/3] | TIME ELAPSED =61.39Mins
# ITERATION:[221/1209] | LOSS: 2.71597 | EPOCH = [1/3] | TIME ELAPSED =61.65Mins
# ITERATION:[222/1209] | LOSS: 2.584542 | EPOCH = [1/3] | TIME ELAPSED =61.91Mins
# ITERATION:[223/1209] | LOSS: 2.630781 | EPOCH = [1/3] | TIME ELAPSED =62.19Mins
# ITERATION:[224/1209] | LOSS: 2.670204 | EPOCH = [1/3] | TIME ELAPSED =62.47Mins
# ITERATION:[225/1209] | LOSS: 2.685058 | EPOCH = [1/3] | TIME ELAPSED =62.76Mins
# ITERATION:[226/1209] | LOSS: 2.695384 | EPOCH = [1/3] | TIME ELAPSED =63.05Mins
# ITERATION:[227/1209] | LOSS: 2.826347 | EPOCH = [1/3] | TIME ELAPSED =63.3Mins
# ITERATION:[228/1209] | LOSS: 2.552051 | EPOCH = [1/3] | TIME ELAPSED =63.56Mins
# ITERATION:[229/1209] | LOSS: 2.564368 | EPOCH = [1/3] | TIME ELAPSED =63.84Mins
# ITERATION:[230/1209] | LOSS: 2.740264 | EPOCH = [1/3] | TIME ELAPSED =64.12Mins
# ITERATION:[231/1209] | LOSS: 2.458874 | EPOCH = [1/3] | TIME ELAPSED =64.4Mins
# ITERATION:[232/1209] | LOSS: 2.494419 | EPOCH = [1/3] | TIME ELAPSED =64.67Mins
# ITERATION:[233/1209] | LOSS: 2.70883 | EPOCH = [1/3] | TIME ELAPSED =64.96Mins
# ITERATION:[234/1209] | LOSS: 2.503119 | EPOCH = [1/3] | TIME ELAPSED =65.24Mins
# ITERATION:[235/1209] | LOSS: 2.567727 | EPOCH = [1/3] | TIME ELAPSED =65.52Mins
# ITERATION:[236/1209] | LOSS: 2.529085 | EPOCH = [1/3] | TIME ELAPSED =65.78Mins
# ITERATION:[237/1209] | LOSS: 2.882248 | EPOCH = [1/3] | TIME ELAPSED =66.05Mins
# ITERATION:[238/1209] | LOSS: 2.591015 | EPOCH = [1/3] | TIME ELAPSED =66.31Mins
# ITERATION:[239/1209] | LOSS: 2.556554 | EPOCH = [1/3] | TIME ELAPSED =66.57Mins
# ITERATION:[240/1209] | LOSS: 2.66692 | EPOCH = [1/3] | TIME ELAPSED =66.85Mins
# ITERATION:[241/1209] | LOSS: 2.472642 | EPOCH = [1/3] | TIME ELAPSED =67.11Mins
# ITERATION:[242/1209] | LOSS: 2.395099 | EPOCH = [1/3] | TIME ELAPSED =67.38Mins
# ITERATION:[243/1209] | LOSS: 2.680053 | EPOCH = [1/3] | TIME ELAPSED =67.66Mins
# ITERATION:[244/1209] | LOSS: 2.617519 | EPOCH = [1/3] | TIME ELAPSED =67.93Mins
# ITERATION:[245/1209] | LOSS: 2.473309 | EPOCH = [1/3] | TIME ELAPSED =68.21Mins
# ITERATION:[246/1209] | LOSS: 2.5921 | EPOCH = [1/3] | TIME ELAPSED =68.48Mins
# ITERATION:[247/1209] | LOSS: 2.474096 | EPOCH = [1/3] | TIME ELAPSED =68.74Mins
# ITERATION:[248/1209] | LOSS: 2.665018 | EPOCH = [1/3] | TIME ELAPSED =69.0Mins
# ITERATION:[249/1209] | LOSS: 2.361502 | EPOCH = [1/3] | TIME ELAPSED =69.29Mins
# ITERATION:[250/1209] | LOSS: 2.664144 | EPOCH = [1/3] | TIME ELAPSED =69.55Mins
# ITERATION:[251/1209] | LOSS: 2.644352 | EPOCH = [1/3] | TIME ELAPSED =69.81Mins
# ITERATION:[252/1209] | LOSS: 2.544484 | EPOCH = [1/3] | TIME ELAPSED =70.09Mins
# ITERATION:[253/1209] | LOSS: 2.696676 | EPOCH = [1/3] | TIME ELAPSED =70.37Mins
# ITERATION:[254/1209] | LOSS: 2.552519 | EPOCH = [1/3] | TIME ELAPSED =70.66Mins
# ITERATION:[255/1209] | LOSS: 2.499155 | EPOCH = [1/3] | TIME ELAPSED =70.94Mins
# ITERATION:[256/1209] | LOSS: 2.461038 | EPOCH = [1/3] | TIME ELAPSED =71.23Mins
# ITERATION:[257/1209] | LOSS: 2.689334 | EPOCH = [1/3] | TIME ELAPSED =71.52Mins
# ITERATION:[258/1209] | LOSS: 2.505079 | EPOCH = [1/3] | TIME ELAPSED =71.77Mins
# ITERATION:[259/1209] | LOSS: 2.669738 | EPOCH = [1/3] | TIME ELAPSED =72.06Mins
# ITERATION:[260/1209] | LOSS: 2.644398 | EPOCH = [1/3] | TIME ELAPSED =72.33Mins
# ITERATION:[261/1209] | LOSS: 2.726479 | EPOCH = [1/3] | TIME ELAPSED =72.61Mins
# ITERATION:[262/1209] | LOSS: 2.469691 | EPOCH = [1/3] | TIME ELAPSED =72.86Mins
# ITERATION:[263/1209] | LOSS: 2.511878 | EPOCH = [1/3] | TIME ELAPSED =73.12Mins
# ITERATION:[264/1209] | LOSS: 2.85773 | EPOCH = [1/3] | TIME ELAPSED =73.41Mins
# ITERATION:[265/1209] | LOSS: 2.617876 | EPOCH = [1/3] | TIME ELAPSED =73.67Mins
# ITERATION:[266/1209] | LOSS: 2.57557 | EPOCH = [1/3] | TIME ELAPSED =73.91Mins
# ITERATION:[267/1209] | LOSS: 2.581813 | EPOCH = [1/3] | TIME ELAPSED =74.18Mins
# ITERATION:[268/1209] | LOSS: 2.578539 | EPOCH = [1/3] | TIME ELAPSED =74.44Mins
# ITERATION:[269/1209] | LOSS: 2.537405 | EPOCH = [1/3] | TIME ELAPSED =74.72Mins
# ITERATION:[270/1209] | LOSS: 2.51621 | EPOCH = [1/3] | TIME ELAPSED =74.98Mins
# ITERATION:[271/1209] | LOSS: 2.567436 | EPOCH = [1/3] | TIME ELAPSED =75.25Mins
# ITERATION:[272/1209] | LOSS: 2.655805 | EPOCH = [1/3] | TIME ELAPSED =75.53Mins
# ITERATION:[273/1209] | LOSS: 2.740177 | EPOCH = [1/3] | TIME ELAPSED =75.8Mins
# ITERATION:[274/1209] | LOSS: 2.552907 | EPOCH = [1/3] | TIME ELAPSED =76.06Mins
# ITERATION:[275/1209] | LOSS: 2.77942 | EPOCH = [1/3] | TIME ELAPSED =76.33Mins
# ITERATION:[276/1209] | LOSS: 2.555463 | EPOCH = [1/3] | TIME ELAPSED =76.61Mins
# ITERATION:[277/1209] | LOSS: 2.614537 | EPOCH = [1/3] | TIME ELAPSED =76.88Mins
# ITERATION:[278/1209] | LOSS: 2.492144 | EPOCH = [1/3] | TIME ELAPSED =77.15Mins
# ITERATION:[279/1209] | LOSS: 2.45251 | EPOCH = [1/3] | TIME ELAPSED =77.42Mins
# ITERATION:[280/1209] | LOSS: 2.632768 | EPOCH = [1/3] | TIME ELAPSED =77.68Mins
# ITERATION:[281/1209] | LOSS: 2.475148 | EPOCH = [1/3] | TIME ELAPSED =77.95Mins
# ITERATION:[282/1209] | LOSS: 2.498223 | EPOCH = [1/3] | TIME ELAPSED =78.24Mins
# ITERATION:[283/1209] | LOSS: 2.465878 | EPOCH = [1/3] | TIME ELAPSED =78.53Mins
# ITERATION:[284/1209] | LOSS: 2.701254 | EPOCH = [1/3] | TIME ELAPSED =78.81Mins
# ITERATION:[285/1209] | LOSS: 2.657088 | EPOCH = [1/3] | TIME ELAPSED =79.07Mins
# ITERATION:[286/1209] | LOSS: 2.554315 | EPOCH = [1/3] | TIME ELAPSED =79.35Mins
# ITERATION:[287/1209] | LOSS: 2.496624 | EPOCH = [1/3] | TIME ELAPSED =79.62Mins
# ITERATION:[288/1209] | LOSS: 2.730695 | EPOCH = [1/3] | TIME ELAPSED =79.89Mins
# ITERATION:[289/1209] | LOSS: 2.577211 | EPOCH = [1/3] | TIME ELAPSED =80.15Mins
# ITERATION:[290/1209] | LOSS: 2.714592 | EPOCH = [1/3] | TIME ELAPSED =80.43Mins
# ITERATION:[291/1209] | LOSS: 2.640337 | EPOCH = [1/3] | TIME ELAPSED =80.71Mins
# ITERATION:[292/1209] | LOSS: 2.476885 | EPOCH = [1/3] | TIME ELAPSED =80.98Mins
# ITERATION:[293/1209] | LOSS: 2.788156 | EPOCH = [1/3] | TIME ELAPSED =81.25Mins
# ITERATION:[294/1209] | LOSS: 2.660245 | EPOCH = [1/3] | TIME ELAPSED =81.52Mins
# ITERATION:[295/1209] | LOSS: 2.58669 | EPOCH = [1/3] | TIME ELAPSED =81.8Mins
# ITERATION:[296/1209] | LOSS: 2.461189 | EPOCH = [1/3] | TIME ELAPSED =82.07Mins
# ITERATION:[297/1209] | LOSS: 2.554657 | EPOCH = [1/3] | TIME ELAPSED =82.38Mins
# ITERATION:[298/1209] | LOSS: 2.504087 | EPOCH = [1/3] | TIME ELAPSED =82.64Mins
# ITERATION:[299/1209] | LOSS: 2.634535 | EPOCH = [1/3] | TIME ELAPSED =82.93Mins
# ITERATION:[300/1209] | LOSS: 2.581815 | EPOCH = [1/3] | TIME ELAPSED =83.23Mins
# ITERATION:[301/1209] | LOSS: 2.502255 | EPOCH = [1/3] | TIME ELAPSED =83.51Mins
# ITERATION:[302/1209] | LOSS: 2.605214 | EPOCH = [1/3] | TIME ELAPSED =83.78Mins
# ITERATION:[303/1209] | LOSS: 2.675592 | EPOCH = [1/3] | TIME ELAPSED =84.06Mins
# ITERATION:[304/1209] | LOSS: 2.512007 | EPOCH = [1/3] | TIME ELAPSED =84.34Mins
# ITERATION:[305/1209] | LOSS: 2.411303 | EPOCH = [1/3] | TIME ELAPSED =84.59Mins
# ITERATION:[306/1209] | LOSS: 2.328546 | EPOCH = [1/3] | TIME ELAPSED =84.87Mins
# ITERATION:[307/1209] | LOSS: 2.543748 | EPOCH = [1/3] | TIME ELAPSED =85.12Mins
# ITERATION:[308/1209] | LOSS: 2.532207 | EPOCH = [1/3] | TIME ELAPSED =85.4Mins
# ITERATION:[309/1209] | LOSS: 2.634118 | EPOCH = [1/3] | TIME ELAPSED =85.67Mins
# ITERATION:[310/1209] | LOSS: 2.516958 | EPOCH = [1/3] | TIME ELAPSED =85.95Mins
# ITERATION:[311/1209] | LOSS: 2.48488 | EPOCH = [1/3] | TIME ELAPSED =86.21Mins
# ITERATION:[312/1209] | LOSS: 2.44348 | EPOCH = [1/3] | TIME ELAPSED =86.46Mins
# ITERATION:[313/1209] | LOSS: 2.662686 | EPOCH = [1/3] | TIME ELAPSED =86.72Mins
# ITERATION:[314/1209] | LOSS: 2.430531 | EPOCH = [1/3] | TIME ELAPSED =87.01Mins
# ITERATION:[315/1209] | LOSS: 2.503115 | EPOCH = [1/3] | TIME ELAPSED =87.26Mins
# ITERATION:[316/1209] | LOSS: 2.489348 | EPOCH = [1/3] | TIME ELAPSED =87.54Mins
# ITERATION:[317/1209] | LOSS: 2.726598 | EPOCH = [1/3] | TIME ELAPSED =87.85Mins
# ITERATION:[318/1209] | LOSS: 2.492582 | EPOCH = [1/3] | TIME ELAPSED =88.12Mins
# ITERATION:[319/1209] | LOSS: 2.439857 | EPOCH = [1/3] | TIME ELAPSED =88.4Mins
# ITERATION:[320/1209] | LOSS: 2.559495 | EPOCH = [1/3] | TIME ELAPSED =88.67Mins
# ITERATION:[321/1209] | LOSS: 2.532036 | EPOCH = [1/3] | TIME ELAPSED =88.95Mins
# ITERATION:[322/1209] | LOSS: 2.603138 | EPOCH = [1/3] | TIME ELAPSED =89.21Mins
# ITERATION:[323/1209] | LOSS: 2.550839 | EPOCH = [1/3] | TIME ELAPSED =89.47Mins
# ITERATION:[324/1209] | LOSS: 2.469887 | EPOCH = [1/3] | TIME ELAPSED =89.74Mins
# ITERATION:[325/1209] | LOSS: 2.511399 | EPOCH = [1/3] | TIME ELAPSED =90.03Mins
# ITERATION:[326/1209] | LOSS: 2.507936 | EPOCH = [1/3] | TIME ELAPSED =90.31Mins
# ITERATION:[327/1209] | LOSS: 2.410978 | EPOCH = [1/3] | TIME ELAPSED =90.59Mins
# ITERATION:[328/1209] | LOSS: 2.551627 | EPOCH = [1/3] | TIME ELAPSED =90.85Mins
# ITERATION:[329/1209] | LOSS: 2.448143 | EPOCH = [1/3] | TIME ELAPSED =91.13Mins
# ITERATION:[330/1209] | LOSS: 2.633176 | EPOCH = [1/3] | TIME ELAPSED =91.4Mins
# ITERATION:[331/1209] | LOSS: 2.553759 | EPOCH = [1/3] | TIME ELAPSED =91.66Mins
# ITERATION:[332/1209] | LOSS: 2.527024 | EPOCH = [1/3] | TIME ELAPSED =91.93Mins
# ITERATION:[333/1209] | LOSS: 2.487181 | EPOCH = [1/3] | TIME ELAPSED =92.19Mins
# ITERATION:[334/1209] | LOSS: 2.486187 | EPOCH = [1/3] | TIME ELAPSED =92.46Mins
# ITERATION:[335/1209] | LOSS: 2.509533 | EPOCH = [1/3] | TIME ELAPSED =92.74Mins
# ITERATION:[336/1209] | LOSS: 2.665036 | EPOCH = [1/3] | TIME ELAPSED =93.03Mins
# ITERATION:[337/1209] | LOSS: 2.531168 | EPOCH = [1/3] | TIME ELAPSED =93.31Mins
# ITERATION:[338/1209] | LOSS: 2.512822 | EPOCH = [1/3] | TIME ELAPSED =93.59Mins
# ITERATION:[339/1209] | LOSS: 2.434464 | EPOCH = [1/3] | TIME ELAPSED =93.86Mins
# ITERATION:[340/1209] | LOSS: 2.542032 | EPOCH = [1/3] | TIME ELAPSED =94.13Mins
# ITERATION:[341/1209] | LOSS: 2.510116 | EPOCH = [1/3] | TIME ELAPSED =94.4Mins
# ITERATION:[342/1209] | LOSS: 2.468592 | EPOCH = [1/3] | TIME ELAPSED =94.68Mins
# ITERATION:[343/1209] | LOSS: 2.508281 | EPOCH = [1/3] | TIME ELAPSED =94.94Mins
# ITERATION:[344/1209] | LOSS: 2.503292 | EPOCH = [1/3] | TIME ELAPSED =95.21Mins
# ITERATION:[345/1209] | LOSS: 2.419547 | EPOCH = [1/3] | TIME ELAPSED =95.46Mins
# ITERATION:[346/1209] | LOSS: 2.553269 | EPOCH = [1/3] | TIME ELAPSED =95.73Mins
# ITERATION:[347/1209] | LOSS: 2.527636 | EPOCH = [1/3] | TIME ELAPSED =96.0Mins
# ITERATION:[348/1209] | LOSS: 2.447204 | EPOCH = [1/3] | TIME ELAPSED =96.28Mins
# ITERATION:[349/1209] | LOSS: 2.538529 | EPOCH = [1/3] | TIME ELAPSED =96.54Mins
# ITERATION:[350/1209] | LOSS: 2.481024 | EPOCH = [1/3] | TIME ELAPSED =96.84Mins
# ITERATION:[351/1209] | LOSS: 2.318389 | EPOCH = [1/3] | TIME ELAPSED =97.13Mins
# ITERATION:[352/1209] | LOSS: 2.607021 | EPOCH = [1/3] | TIME ELAPSED =97.38Mins
# ITERATION:[353/1209] | LOSS: 2.438484 | EPOCH = [1/3] | TIME ELAPSED =97.65Mins
# ITERATION:[354/1209] | LOSS: 2.501529 | EPOCH = [1/3] | TIME ELAPSED =97.9Mins
# ITERATION:[355/1209] | LOSS: 2.306174 | EPOCH = [1/3] | TIME ELAPSED =98.16Mins
# ITERATION:[356/1209] | LOSS: 2.43414 | EPOCH = [1/3] | TIME ELAPSED =98.44Mins
# ITERATION:[357/1209] | LOSS: 2.647767 | EPOCH = [1/3] | TIME ELAPSED =98.74Mins
# ITERATION:[358/1209] | LOSS: 2.700381 | EPOCH = [1/3] | TIME ELAPSED =99.02Mins
# ITERATION:[359/1209] | LOSS: 2.597455 | EPOCH = [1/3] | TIME ELAPSED =99.29Mins
# ITERATION:[360/1209] | LOSS: 2.554628 | EPOCH = [1/3] | TIME ELAPSED =99.54Mins
# ITERATION:[361/1209] | LOSS: 2.453493 | EPOCH = [1/3] | TIME ELAPSED =99.8Mins
# ITERATION:[362/1209] | LOSS: 2.61253 | EPOCH = [1/3] | TIME ELAPSED =100.07Mins
# ITERATION:[363/1209] | LOSS: 2.52207 | EPOCH = [1/3] | TIME ELAPSED =100.36Mins
# ITERATION:[364/1209] | LOSS: 2.489343 | EPOCH = [1/3] | TIME ELAPSED =100.61Mins
# ITERATION:[365/1209] | LOSS: 2.367564 | EPOCH = [1/3] | TIME ELAPSED =100.89Mins
# ITERATION:[366/1209] | LOSS: 2.487244 | EPOCH = [1/3] | TIME ELAPSED =101.17Mins
# ITERATION:[367/1209] | LOSS: 2.351977 | EPOCH = [1/3] | TIME ELAPSED =101.46Mins
# ITERATION:[368/1209] | LOSS: 2.400729 | EPOCH = [1/3] | TIME ELAPSED =101.73Mins
# ITERATION:[369/1209] | LOSS: 2.327723 | EPOCH = [1/3] | TIME ELAPSED =102.0Mins
# ITERATION:[370/1209] | LOSS: 2.437188 | EPOCH = [1/3] | TIME ELAPSED =102.26Mins
# ITERATION:[371/1209] | LOSS: 2.588478 | EPOCH = [1/3] | TIME ELAPSED =102.53Mins
# ITERATION:[372/1209] | LOSS: 2.578908 | EPOCH = [1/3] | TIME ELAPSED =102.8Mins
# ITERATION:[373/1209] | LOSS: 2.648758 | EPOCH = [1/3] | TIME ELAPSED =103.06Mins
# ITERATION:[374/1209] | LOSS: 2.516774 | EPOCH = [1/3] | TIME ELAPSED =103.34Mins
# ITERATION:[375/1209] | LOSS: 2.382084 | EPOCH = [1/3] | TIME ELAPSED =103.62Mins
# ITERATION:[376/1209] | LOSS: 2.510907 | EPOCH = [1/3] | TIME ELAPSED =103.9Mins
# ITERATION:[377/1209] | LOSS: 2.4988 | EPOCH = [1/3] | TIME ELAPSED =104.15Mins
# ITERATION:[378/1209] | LOSS: 2.50741 | EPOCH = [1/3] | TIME ELAPSED =104.44Mins
# ITERATION:[379/1209] | LOSS: 2.431222 | EPOCH = [1/3] | TIME ELAPSED =104.72Mins
# ITERATION:[380/1209] | LOSS: 2.498593 | EPOCH = [1/3] | TIME ELAPSED =105.02Mins
# ITERATION:[381/1209] | LOSS: 2.596852 | EPOCH = [1/3] | TIME ELAPSED =105.28Mins
# ITERATION:[382/1209] | LOSS: 2.59961 | EPOCH = [1/3] | TIME ELAPSED =105.56Mins
# ITERATION:[383/1209] | LOSS: 2.493177 | EPOCH = [1/3] | TIME ELAPSED =105.86Mins
# ITERATION:[384/1209] | LOSS: 2.524031 | EPOCH = [1/3] | TIME ELAPSED =106.13Mins
# ITERATION:[385/1209] | LOSS: 2.474858 | EPOCH = [1/3] | TIME ELAPSED =106.42Mins
# ITERATION:[386/1209] | LOSS: 2.47449 | EPOCH = [1/3] | TIME ELAPSED =106.69Mins
# ITERATION:[387/1209] | LOSS: 2.252788 | EPOCH = [1/3] | TIME ELAPSED =106.97Mins
# ITERATION:[388/1209] | LOSS: 2.427894 | EPOCH = [1/3] | TIME ELAPSED =107.25Mins
# ITERATION:[389/1209] | LOSS: 2.42504 | EPOCH = [1/3] | TIME ELAPSED =107.51Mins
# ITERATION:[390/1209] | LOSS: 2.408809 | EPOCH = [1/3] | TIME ELAPSED =107.8Mins
# ITERATION:[391/1209] | LOSS: 2.443768 | EPOCH = [1/3] | TIME ELAPSED =108.12Mins
# ITERATION:[392/1209] | LOSS: 2.561949 | EPOCH = [1/3] | TIME ELAPSED =108.4Mins
# ITERATION:[393/1209] | LOSS: 2.492972 | EPOCH = [1/3] | TIME ELAPSED =108.69Mins
# ITERATION:[394/1209] | LOSS: 2.353641 | EPOCH = [1/3] | TIME ELAPSED =108.98Mins
# ITERATION:[395/1209] | LOSS: 2.629289 | EPOCH = [1/3] | TIME ELAPSED =109.25Mins
# ITERATION:[396/1209] | LOSS: 2.365448 | EPOCH = [1/3] | TIME ELAPSED =109.52Mins
# ITERATION:[397/1209] | LOSS: 2.54092 | EPOCH = [1/3] | TIME ELAPSED =109.83Mins
# ITERATION:[398/1209] | LOSS: 2.508335 | EPOCH = [1/3] | TIME ELAPSED =110.1Mins
# ITERATION:[399/1209] | LOSS: 2.4597 | EPOCH = [1/3] | TIME ELAPSED =110.38Mins
# ITERATION:[400/1209] | LOSS: 2.504048 | EPOCH = [1/3] | TIME ELAPSED =110.66Mins
# ITERATION:[401/1209] | LOSS: 2.434271 | EPOCH = [1/3] | TIME ELAPSED =110.95Mins
# ITERATION:[402/1209] | LOSS: 2.382277 | EPOCH = [1/3] | TIME ELAPSED =111.24Mins
# ITERATION:[403/1209] | LOSS: 2.429006 | EPOCH = [1/3] | TIME ELAPSED =111.51Mins
# ITERATION:[404/1209] | LOSS: 2.46983 | EPOCH = [1/3] | TIME ELAPSED =111.78Mins
# ITERATION:[405/1209] | LOSS: 2.394436 | EPOCH = [1/3] | TIME ELAPSED =112.05Mins
# ITERATION:[406/1209] | LOSS: 2.495792 | EPOCH = [1/3] | TIME ELAPSED =112.3Mins
# ITERATION:[407/1209] | LOSS: 2.138341 | EPOCH = [1/3] | TIME ELAPSED =112.58Mins
# ITERATION:[408/1209] | LOSS: 2.646704 | EPOCH = [1/3] | TIME ELAPSED =112.86Mins
# ITERATION:[409/1209] | LOSS: 2.452353 | EPOCH = [1/3] | TIME ELAPSED =113.13Mins
# ITERATION:[410/1209] | LOSS: 2.553757 | EPOCH = [1/3] | TIME ELAPSED =113.39Mins
# ITERATION:[411/1209] | LOSS: 2.4555 | EPOCH = [1/3] | TIME ELAPSED =113.65Mins
# ITERATION:[412/1209] | LOSS: 2.438995 | EPOCH = [1/3] | TIME ELAPSED =113.92Mins
# ITERATION:[413/1209] | LOSS: 2.435053 | EPOCH = [1/3] | TIME ELAPSED =114.2Mins
# ITERATION:[414/1209] | LOSS: 2.381977 | EPOCH = [1/3] | TIME ELAPSED =114.48Mins
# ITERATION:[415/1209] | LOSS: 2.539892 | EPOCH = [1/3] | TIME ELAPSED =114.76Mins
# ITERATION:[416/1209] | LOSS: 2.449358 | EPOCH = [1/3] | TIME ELAPSED =115.03Mins
# ITERATION:[417/1209] | LOSS: 2.459011 | EPOCH = [1/3] | TIME ELAPSED =115.3Mins
# ITERATION:[418/1209] | LOSS: 2.455257 | EPOCH = [1/3] | TIME ELAPSED =115.57Mins
# ITERATION:[419/1209] | LOSS: 2.373114 | EPOCH = [1/3] | TIME ELAPSED =115.85Mins
# ITERATION:[420/1209] | LOSS: 2.485128 | EPOCH = [1/3] | TIME ELAPSED =116.13Mins
# ITERATION:[421/1209] | LOSS: 2.342678 | EPOCH = [1/3] | TIME ELAPSED =116.41Mins
# ITERATION:[422/1209] | LOSS: 2.328281 | EPOCH = [1/3] | TIME ELAPSED =116.68Mins
# ITERATION:[423/1209] | LOSS: 2.410587 | EPOCH = [1/3] | TIME ELAPSED =116.95Mins
# ITERATION:[424/1209] | LOSS: 2.45371 | EPOCH = [1/3] | TIME ELAPSED =117.25Mins
# ITERATION:[425/1209] | LOSS: 2.454764 | EPOCH = [1/3] | TIME ELAPSED =117.54Mins
# ITERATION:[426/1209] | LOSS: 2.488306 | EPOCH = [1/3] | TIME ELAPSED =117.79Mins
# ITERATION:[427/1209] | LOSS: 2.61662 | EPOCH = [1/3] | TIME ELAPSED =118.07Mins
# ITERATION:[428/1209] | LOSS: 2.387286 | EPOCH = [1/3] | TIME ELAPSED =118.34Mins
# ITERATION:[429/1209] | LOSS: 2.478285 | EPOCH = [1/3] | TIME ELAPSED =118.62Mins
# ITERATION:[430/1209] | LOSS: 2.592009 | EPOCH = [1/3] | TIME ELAPSED =118.88Mins
# ITERATION:[431/1209] | LOSS: 2.505388 | EPOCH = [1/3] | TIME ELAPSED =119.15Mins
# ITERATION:[432/1209] | LOSS: 2.598697 | EPOCH = [1/3] | TIME ELAPSED =119.42Mins
# ITERATION:[433/1209] | LOSS: 2.438317 | EPOCH = [1/3] | TIME ELAPSED =119.68Mins
# ITERATION:[434/1209] | LOSS: 2.253328 | EPOCH = [1/3] | TIME ELAPSED =119.94Mins
# ITERATION:[435/1209] | LOSS: 2.448013 | EPOCH = [1/3] | TIME ELAPSED =120.22Mins
# ITERATION:[436/1209] | LOSS: 2.51707 | EPOCH = [1/3] | TIME ELAPSED =120.54Mins
# ITERATION:[437/1209] | LOSS: 2.3726 | EPOCH = [1/3] | TIME ELAPSED =120.84Mins
# ITERATION:[438/1209] | LOSS: 2.46584 | EPOCH = [1/3] | TIME ELAPSED =121.13Mins
# ITERATION:[439/1209] | LOSS: 2.466714 | EPOCH = [1/3] | TIME ELAPSED =121.38Mins
# ITERATION:[440/1209] | LOSS: 2.385106 | EPOCH = [1/3] | TIME ELAPSED =121.65Mins
# ITERATION:[441/1209] | LOSS: 2.462373 | EPOCH = [1/3] | TIME ELAPSED =121.94Mins
# ITERATION:[442/1209] | LOSS: 2.413322 | EPOCH = [1/3] | TIME ELAPSED =122.23Mins
# ITERATION:[443/1209] | LOSS: 2.345941 | EPOCH = [1/3] | TIME ELAPSED =122.51Mins
# ITERATION:[444/1209] | LOSS: 2.42649 | EPOCH = [1/3] | TIME ELAPSED =122.78Mins
# ITERATION:[445/1209] | LOSS: 2.372115 | EPOCH = [1/3] | TIME ELAPSED =123.05Mins
# ITERATION:[446/1209] | LOSS: 2.416001 | EPOCH = [1/3] | TIME ELAPSED =123.3Mins
# ITERATION:[447/1209] | LOSS: 2.545755 | EPOCH = [1/3] | TIME ELAPSED =123.59Mins
# ITERATION:[448/1209] | LOSS: 2.382158 | EPOCH = [1/3] | TIME ELAPSED =123.86Mins
# ITERATION:[449/1209] | LOSS: 2.340165 | EPOCH = [1/3] | TIME ELAPSED =124.13Mins
# ITERATION:[450/1209] | LOSS: 2.418389 | EPOCH = [1/3] | TIME ELAPSED =124.42Mins
# ITERATION:[451/1209] | LOSS: 2.323347 | EPOCH = [1/3] | TIME ELAPSED =124.71Mins
# ITERATION:[452/1209] | LOSS: 2.513736 | EPOCH = [1/3] | TIME ELAPSED =124.99Mins
# ITERATION:[453/1209] | LOSS: 2.433493 | EPOCH = [1/3] | TIME ELAPSED =125.26Mins
# ITERATION:[454/1209] | LOSS: 2.394724 | EPOCH = [1/3] | TIME ELAPSED =125.53Mins
# ITERATION:[455/1209] | LOSS: 2.391147 | EPOCH = [1/3] | TIME ELAPSED =125.82Mins
# ITERATION:[456/1209] | LOSS: 2.484572 | EPOCH = [1/3] | TIME ELAPSED =126.08Mins
# ITERATION:[457/1209] | LOSS: 2.302185 | EPOCH = [1/3] | TIME ELAPSED =126.36Mins
# ITERATION:[458/1209] | LOSS: 2.290492 | EPOCH = [1/3] | TIME ELAPSED =126.63Mins
# ITERATION:[459/1209] | LOSS: 2.529797 | EPOCH = [1/3] | TIME ELAPSED =126.92Mins
# ITERATION:[460/1209] | LOSS: 2.466484 | EPOCH = [1/3] | TIME ELAPSED =127.22Mins
# ITERATION:[461/1209] | LOSS: 2.391785 | EPOCH = [1/3] | TIME ELAPSED =127.49Mins
# ITERATION:[462/1209] | LOSS: 2.745251 | EPOCH = [1/3] | TIME ELAPSED =127.76Mins
# ITERATION:[463/1209] | LOSS: 2.426829 | EPOCH = [1/3] | TIME ELAPSED =128.02Mins
# ITERATION:[464/1209] | LOSS: 2.407627 | EPOCH = [1/3] | TIME ELAPSED =128.3Mins
# ITERATION:[465/1209] | LOSS: 2.278024 | EPOCH = [1/3] | TIME ELAPSED =128.59Mins
# ITERATION:[466/1209] | LOSS: 2.323205 | EPOCH = [1/3] | TIME ELAPSED =128.87Mins
# ITERATION:[467/1209] | LOSS: 2.308903 | EPOCH = [1/3] | TIME ELAPSED =129.14Mins
# ITERATION:[468/1209] | LOSS: 2.403103 | EPOCH = [1/3] | TIME ELAPSED =129.41Mins
# ITERATION:[469/1209] | LOSS: 2.450327 | EPOCH = [1/3] | TIME ELAPSED =129.69Mins
# ITERATION:[470/1209] | LOSS: 2.50587 | EPOCH = [1/3] | TIME ELAPSED =129.96Mins
# ITERATION:[471/1209] | LOSS: 2.382248 | EPOCH = [1/3] | TIME ELAPSED =130.24Mins
# ITERATION:[472/1209] | LOSS: 2.399734 | EPOCH = [1/3] | TIME ELAPSED =130.51Mins
# ITERATION:[473/1209] | LOSS: 2.188435 | EPOCH = [1/3] | TIME ELAPSED =130.78Mins
# ITERATION:[474/1209] | LOSS: 2.20919 | EPOCH = [1/3] | TIME ELAPSED =131.06Mins
# ITERATION:[475/1209] | LOSS: 2.370354 | EPOCH = [1/3] | TIME ELAPSED =131.35Mins
# ITERATION:[476/1209] | LOSS: 2.360461 | EPOCH = [1/3] | TIME ELAPSED =131.6Mins
# ITERATION:[477/1209] | LOSS: 2.413376 | EPOCH = [1/3] | TIME ELAPSED =131.89Mins
# ITERATION:[478/1209] | LOSS: 2.367074 | EPOCH = [1/3] | TIME ELAPSED =132.17Mins
# ITERATION:[479/1209] | LOSS: 2.440108 | EPOCH = [1/3] | TIME ELAPSED =132.44Mins
# ITERATION:[480/1209] | LOSS: 2.365604 | EPOCH = [1/3] | TIME ELAPSED =132.71Mins
# ITERATION:[481/1209] | LOSS: 2.48033 | EPOCH = [1/3] | TIME ELAPSED =132.99Mins
# ITERATION:[482/1209] | LOSS: 2.219998 | EPOCH = [1/3] | TIME ELAPSED =133.28Mins
# ITERATION:[483/1209] | LOSS: 2.235763 | EPOCH = [1/3] | TIME ELAPSED =133.55Mins
# ITERATION:[484/1209] | LOSS: 2.410471 | EPOCH = [1/3] | TIME ELAPSED =133.82Mins
# ITERATION:[485/1209] | LOSS: 2.38288 | EPOCH = [1/3] | TIME ELAPSED =134.08Mins
# ITERATION:[486/1209] | LOSS: 2.550732 | EPOCH = [1/3] | TIME ELAPSED =134.35Mins
# ITERATION:[487/1209] | LOSS: 2.470151 | EPOCH = [1/3] | TIME ELAPSED =134.64Mins
# ITERATION:[488/1209] | LOSS: 2.588788 | EPOCH = [1/3] | TIME ELAPSED =134.91Mins
# ITERATION:[489/1209] | LOSS: 2.418616 | EPOCH = [1/3] | TIME ELAPSED =135.19Mins
# ITERATION:[490/1209] | LOSS: 2.43966 | EPOCH = [1/3] | TIME ELAPSED =135.47Mins
# ITERATION:[491/1209] | LOSS: 2.397995 | EPOCH = [1/3] | TIME ELAPSED =135.74Mins
# ITERATION:[492/1209] | LOSS: 2.432482 | EPOCH = [1/3] | TIME ELAPSED =135.99Mins
# ITERATION:[493/1209] | LOSS: 2.508449 | EPOCH = [1/3] | TIME ELAPSED =136.26Mins
# ITERATION:[494/1209] | LOSS: 2.331792 | EPOCH = [1/3] | TIME ELAPSED =136.53Mins
# ITERATION:[495/1209] | LOSS: 2.518651 | EPOCH = [1/3] | TIME ELAPSED =136.81Mins
# ITERATION:[496/1209] | LOSS: 2.32642 | EPOCH = [1/3] | TIME ELAPSED =137.09Mins
# ITERATION:[497/1209] | LOSS: 2.314842 | EPOCH = [1/3] | TIME ELAPSED =137.37Mins
# ITERATION:[498/1209] | LOSS: 2.300122 | EPOCH = [1/3] | TIME ELAPSED =137.64Mins
# ITERATION:[499/1209] | LOSS: 2.315755 | EPOCH = [1/3] | TIME ELAPSED =137.92Mins
# ITERATION:[500/1209] | LOSS: 2.465224 | EPOCH = [1/3] | TIME ELAPSED =138.22Mins
# ITERATION:[501/1209] | LOSS: 2.517467 | EPOCH = [1/3] | TIME ELAPSED =138.5Mins
# ITERATION:[502/1209] | LOSS: 2.436119 | EPOCH = [1/3] | TIME ELAPSED =138.76Mins
# ITERATION:[503/1209] | LOSS: 2.327164 | EPOCH = [1/3] | TIME ELAPSED =139.01Mins
# ITERATION:[504/1209] | LOSS: 2.337873 | EPOCH = [1/3] | TIME ELAPSED =139.3Mins
# ITERATION:[505/1209] | LOSS: 2.499774 | EPOCH = [1/3] | TIME ELAPSED =139.54Mins
# ITERATION:[506/1209] | LOSS: 2.482078 | EPOCH = [1/3] | TIME ELAPSED =139.83Mins
# ITERATION:[507/1209] | LOSS: 2.408029 | EPOCH = [1/3] | TIME ELAPSED =140.1Mins
# ITERATION:[508/1209] | LOSS: 2.328935 | EPOCH = [1/3] | TIME ELAPSED =140.37Mins
# ITERATION:[509/1209] | LOSS: 2.274454 | EPOCH = [1/3] | TIME ELAPSED =140.66Mins
# ITERATION:[510/1209] | LOSS: 2.444982 | EPOCH = [1/3] | TIME ELAPSED =140.93Mins
# ITERATION:[511/1209] | LOSS: 2.292355 | EPOCH = [1/3] | TIME ELAPSED =141.2Mins
# ITERATION:[512/1209] | LOSS: 2.496387 | EPOCH = [1/3] | TIME ELAPSED =141.49Mins
# ITERATION:[513/1209] | LOSS: 2.325277 | EPOCH = [1/3] | TIME ELAPSED =141.76Mins
# ITERATION:[514/1209] | LOSS: 2.378116 | EPOCH = [1/3] | TIME ELAPSED =142.05Mins
# ITERATION:[515/1209] | LOSS: 2.304611 | EPOCH = [1/3] | TIME ELAPSED =142.32Mins
# ITERATION:[516/1209] | LOSS: 2.382953 | EPOCH = [1/3] | TIME ELAPSED =142.61Mins
# ITERATION:[517/1209] | LOSS: 2.364348 | EPOCH = [1/3] | TIME ELAPSED =142.88Mins
# ITERATION:[518/1209] | LOSS: 2.300365 | EPOCH = [1/3] | TIME ELAPSED =143.17Mins
# ITERATION:[519/1209] | LOSS: 2.499193 | EPOCH = [1/3] | TIME ELAPSED =143.45Mins
# ITERATION:[520/1209] | LOSS: 2.422824 | EPOCH = [1/3] | TIME ELAPSED =143.73Mins
# ITERATION:[521/1209] | LOSS: 2.36712 | EPOCH = [1/3] | TIME ELAPSED =144.02Mins
# ITERATION:[522/1209] | LOSS: 2.333581 | EPOCH = [1/3] | TIME ELAPSED =144.37Mins
# ITERATION:[523/1209] | LOSS: 2.519326 | EPOCH = [1/3] | TIME ELAPSED =144.64Mins
# ITERATION:[524/1209] | LOSS: 2.429117 | EPOCH = [1/3] | TIME ELAPSED =144.91Mins
# ITERATION:[525/1209] | LOSS: 2.347258 | EPOCH = [1/3] | TIME ELAPSED =145.19Mins
# ITERATION:[526/1209] | LOSS: 2.322148 | EPOCH = [1/3] | TIME ELAPSED =145.47Mins
# ITERATION:[527/1209] | LOSS: 2.535041 | EPOCH = [1/3] | TIME ELAPSED =145.75Mins
# ITERATION:[528/1209] | LOSS: 2.453762 | EPOCH = [1/3] | TIME ELAPSED =146.03Mins
# ITERATION:[529/1209] | LOSS: 2.391418 | EPOCH = [1/3] | TIME ELAPSED =146.3Mins
# ITERATION:[530/1209] | LOSS: 2.331381 | EPOCH = [1/3] | TIME ELAPSED =146.57Mins
# ITERATION:[531/1209] | LOSS: 2.369323 | EPOCH = [1/3] | TIME ELAPSED =146.82Mins
# ITERATION:[532/1209] | LOSS: 2.24595 | EPOCH = [1/3] | TIME ELAPSED =147.09Mins
# ITERATION:[533/1209] | LOSS: 2.51196 | EPOCH = [1/3] | TIME ELAPSED =147.38Mins
# ITERATION:[534/1209] | LOSS: 2.450348 | EPOCH = [1/3] | TIME ELAPSED =147.64Mins
# ITERATION:[535/1209] | LOSS: 2.410778 | EPOCH = [1/3] | TIME ELAPSED =147.9Mins
# ITERATION:[536/1209] | LOSS: 2.382791 | EPOCH = [1/3] | TIME ELAPSED =148.18Mins
# ITERATION:[537/1209] | LOSS: 2.167671 | EPOCH = [1/3] | TIME ELAPSED =148.45Mins
# ITERATION:[538/1209] | LOSS: 2.52071 | EPOCH = [1/3] | TIME ELAPSED =148.71Mins
# ITERATION:[539/1209] | LOSS: 2.443068 | EPOCH = [1/3] | TIME ELAPSED =148.98Mins
# ITERATION:[540/1209] | LOSS: 2.503598 | EPOCH = [1/3] | TIME ELAPSED =149.26Mins
# ITERATION:[541/1209] | LOSS: 2.328844 | EPOCH = [1/3] | TIME ELAPSED =149.53Mins
# ITERATION:[542/1209] | LOSS: 2.452149 | EPOCH = [1/3] | TIME ELAPSED =149.81Mins
# ITERATION:[543/1209] | LOSS: 2.3588 | EPOCH = [1/3] | TIME ELAPSED =150.1Mins
# ITERATION:[544/1209] | LOSS: 2.263841 | EPOCH = [1/3] | TIME ELAPSED =150.35Mins
# ITERATION:[545/1209] | LOSS: 2.352825 | EPOCH = [1/3] | TIME ELAPSED =150.62Mins
# ITERATION:[546/1209] | LOSS: 2.510177 | EPOCH = [1/3] | TIME ELAPSED =150.91Mins
# ITERATION:[547/1209] | LOSS: 2.40568 | EPOCH = [1/3] | TIME ELAPSED =151.19Mins
# ITERATION:[548/1209] | LOSS: 2.394129 | EPOCH = [1/3] | TIME ELAPSED =151.46Mins
# ITERATION:[549/1209] | LOSS: 2.441995 | EPOCH = [1/3] | TIME ELAPSED =151.74Mins
# ITERATION:[550/1209] | LOSS: 2.253345 | EPOCH = [1/3] | TIME ELAPSED =152.04Mins
# ITERATION:[551/1209] | LOSS: 2.353591 | EPOCH = [1/3] | TIME ELAPSED =152.31Mins
# ITERATION:[552/1209] | LOSS: 2.522413 | EPOCH = [1/3] | TIME ELAPSED =152.57Mins
# ITERATION:[553/1209] | LOSS: 2.32108 | EPOCH = [1/3] | TIME ELAPSED =152.84Mins
# ITERATION:[554/1209] | LOSS: 2.44439 | EPOCH = [1/3] | TIME ELAPSED =153.1Mins
# ITERATION:[555/1209] | LOSS: 2.451309 | EPOCH = [1/3] | TIME ELAPSED =153.41Mins
# ITERATION:[556/1209] | LOSS: 2.357735 | EPOCH = [1/3] | TIME ELAPSED =153.66Mins
# ITERATION:[557/1209] | LOSS: 2.410476 | EPOCH = [1/3] | TIME ELAPSED =153.94Mins
# ITERATION:[558/1209] | LOSS: 2.329154 | EPOCH = [1/3] | TIME ELAPSED =154.2Mins
# ITERATION:[559/1209] | LOSS: 2.216654 | EPOCH = [1/3] | TIME ELAPSED =154.48Mins
# ITERATION:[560/1209] | LOSS: 2.370614 | EPOCH = [1/3] | TIME ELAPSED =154.74Mins
# ITERATION:[561/1209] | LOSS: 2.419262 | EPOCH = [1/3] | TIME ELAPSED =155.03Mins
# ITERATION:[562/1209] | LOSS: 2.573622 | EPOCH = [1/3] | TIME ELAPSED =155.31Mins
# ITERATION:[563/1209] | LOSS: 2.311546 | EPOCH = [1/3] | TIME ELAPSED =155.59Mins
# ITERATION:[564/1209] | LOSS: 2.373663 | EPOCH = [1/3] | TIME ELAPSED =155.88Mins
# ITERATION:[565/1209] | LOSS: 2.218451 | EPOCH = [1/3] | TIME ELAPSED =156.24Mins
# ITERATION:[566/1209] | LOSS: 2.357455 | EPOCH = [1/3] | TIME ELAPSED =156.52Mins
# ITERATION:[567/1209] | LOSS: 2.465302 | EPOCH = [1/3] | TIME ELAPSED =156.76Mins
# ITERATION:[568/1209] | LOSS: 2.364948 | EPOCH = [1/3] | TIME ELAPSED =157.04Mins
# ITERATION:[569/1209] | LOSS: 2.333559 | EPOCH = [1/3] | TIME ELAPSED =157.32Mins
# ITERATION:[570/1209] | LOSS: 2.449313 | EPOCH = [1/3] | TIME ELAPSED =157.58Mins
# ITERATION:[571/1209] | LOSS: 2.449051 | EPOCH = [1/3] | TIME ELAPSED =157.85Mins
# ITERATION:[572/1209] | LOSS: 2.29707 | EPOCH = [1/3] | TIME ELAPSED =158.12Mins
# ITERATION:[573/1209] | LOSS: 2.303305 | EPOCH = [1/3] | TIME ELAPSED =158.41Mins
# ITERATION:[574/1209] | LOSS: 2.512208 | EPOCH = [1/3] | TIME ELAPSED =158.69Mins
# ITERATION:[575/1209] | LOSS: 2.514738 | EPOCH = [1/3] | TIME ELAPSED =158.97Mins
# ITERATION:[576/1209] | LOSS: 2.421851 | EPOCH = [1/3] | TIME ELAPSED =159.24Mins
# ITERATION:[577/1209] | LOSS: 2.448813 | EPOCH = [1/3] | TIME ELAPSED =159.5Mins
# ITERATION:[578/1209] | LOSS: 2.39768 | EPOCH = [1/3] | TIME ELAPSED =159.77Mins
# ITERATION:[579/1209] | LOSS: 2.375343 | EPOCH = [1/3] | TIME ELAPSED =160.05Mins
# ITERATION:[580/1209] | LOSS: 2.327259 | EPOCH = [1/3] | TIME ELAPSED =160.33Mins
# ITERATION:[581/1209] | LOSS: 2.389646 | EPOCH = [1/3] | TIME ELAPSED =160.59Mins
# ITERATION:[582/1209] | LOSS: 2.487974 | EPOCH = [1/3] | TIME ELAPSED =160.86Mins
# ITERATION:[583/1209] | LOSS: 2.421495 | EPOCH = [1/3] | TIME ELAPSED =161.13Mins
# ITERATION:[584/1209] | LOSS: 2.428083 | EPOCH = [1/3] | TIME ELAPSED =161.4Mins
# ITERATION:[585/1209] | LOSS: 2.321174 | EPOCH = [1/3] | TIME ELAPSED =161.69Mins
# ITERATION:[586/1209] | LOSS: 2.188623 | EPOCH = [1/3] | TIME ELAPSED =161.97Mins
# ITERATION:[587/1209] | LOSS: 2.182969 | EPOCH = [1/3] | TIME ELAPSED =162.22Mins
# ITERATION:[588/1209] | LOSS: 2.425536 | EPOCH = [1/3] | TIME ELAPSED =162.48Mins
# ITERATION:[589/1209] | LOSS: 2.307502 | EPOCH = [1/3] | TIME ELAPSED =162.75Mins
# ITERATION:[590/1209] | LOSS: 2.288916 | EPOCH = [1/3] | TIME ELAPSED =163.0Mins
# ITERATION:[591/1209] | LOSS: 2.354857 | EPOCH = [1/3] | TIME ELAPSED =163.28Mins
# ITERATION:[592/1209] | LOSS: 2.404318 | EPOCH = [1/3] | TIME ELAPSED =163.57Mins
# ITERATION:[593/1209] | LOSS: 2.352479 | EPOCH = [1/3] | TIME ELAPSED =163.83Mins
# ITERATION:[594/1209] | LOSS: 2.307615 | EPOCH = [1/3] | TIME ELAPSED =164.09Mins
# ITERATION:[595/1209] | LOSS: 2.234559 | EPOCH = [1/3] | TIME ELAPSED =164.34Mins
# ITERATION:[596/1209] | LOSS: 2.337733 | EPOCH = [1/3] | TIME ELAPSED =164.6Mins
# ITERATION:[597/1209] | LOSS: 2.310192 | EPOCH = [1/3] | TIME ELAPSED =164.87Mins
# ITERATION:[598/1209] | LOSS: 2.320983 | EPOCH = [1/3] | TIME ELAPSED =165.12Mins
# ...
# ITERATION:[1015/1209] | LOSS: 2.08075 | EPOCH = [3/3] | TIME ELAPSED =438.34Mins
# ITERATION:[1016/1209] | LOSS: 2.056068 | EPOCH = [3/3] | TIME ELAPSED =438.39Mins
# ITERATION:[1017/1209] | LOSS: 2.002915 | EPOCH = [3/3] | TIME ELAPSED =438.43Mins
# ITERATION:[1018/1209] | LOSS: 1.974557 | EPOCH = [3/3] | TIME ELAPSED =438.48Mins
# ITERATION:[1019/1209] | LOSS: 2.148715 | EPOCH = [3/3] | TIME ELAPSED =438.53Mins
# ITERATION:[1020/1209] | LOSS: 1.969034 | EPOCH = [3/3] | TIME ELAPSED =438.57Mins
# ITERATION:[1021/1209] | LOSS: 2.003582 | EPOCH = [3/3] | TIME ELAPSED =438.62Mins
# ITERATION:[1022/1209] | LOSS: 1.929615 | EPOCH = [3/3] | TIME ELAPSED =438.67Mins
# ITERATION:[1023/1209] | LOSS: 1.922662 | EPOCH = [3/3] | TIME ELAPSED =438.71Mins
# ITERATION:[1024/1209] | LOSS: 2.082119 | EPOCH = [3/3] | TIME ELAPSED =438.76Mins
# ITERATION:[1025/1209] | LOSS: 2.022287 | EPOCH = [3/3] | TIME ELAPSED =438.82Mins
# ITERATION:[1026/1209] | LOSS: 2.020609 | EPOCH = [3/3] | TIME ELAPSED =438.87Mins
# ITERATION:[1027/1209] | LOSS: 1.923687 | EPOCH = [3/3] | TIME ELAPSED =438.91Mins
# ITERATION:[1028/1209] | LOSS: 1.947113 | EPOCH = [3/3] | TIME ELAPSED =438.96Mins
# ITERATION:[1029/1209] | LOSS: 1.938459 | EPOCH = [3/3] | TIME ELAPSED =439.01Mins
# ITERATION:[1030/1209] | LOSS: 2.132055 | EPOCH = [3/3] | TIME ELAPSED =439.05Mins
# ITERATION:[1031/1209] | LOSS: 2.010475 | EPOCH = [3/3] | TIME ELAPSED =439.1Mins
# ITERATION:[1032/1209] | LOSS: 2.019976 | EPOCH = [3/3] | TIME ELAPSED =439.15Mins
# ITERATION:[1033/1209] | LOSS: 1.941441 | EPOCH = [3/3] | TIME ELAPSED =439.19Mins
# ITERATION:[1034/1209] | LOSS: 2.156296 | EPOCH = [3/3] | TIME ELAPSED =439.24Mins
# ITERATION:[1035/1209] | LOSS: 2.010025 | EPOCH = [3/3] | TIME ELAPSED =439.29Mins
# ITERATION:[1036/1209] | LOSS: 2.054917 | EPOCH = [3/3] | TIME ELAPSED =439.33Mins
# ITERATION:[1037/1209] | LOSS: 1.954072 | EPOCH = [3/3] | TIME ELAPSED =439.38Mins
# ITERATION:[1038/1209] | LOSS: 1.953897 | EPOCH = [3/3] | TIME ELAPSED =439.43Mins
# ITERATION:[1039/1209] | LOSS: 1.95959 | EPOCH = [3/3] | TIME ELAPSED =439.47Mins
# ITERATION:[1040/1209] | LOSS: 2.082317 | EPOCH = [3/3] | TIME ELAPSED =439.52Mins
# ITERATION:[1041/1209] | LOSS: 1.941865 | EPOCH = [3/3] | TIME ELAPSED =439.57Mins
# ITERATION:[1042/1209] | LOSS: 2.003304 | EPOCH = [3/3] | TIME ELAPSED =439.61Mins
# ITERATION:[1043/1209] | LOSS: 1.947728 | EPOCH = [3/3] | TIME ELAPSED =439.66Mins
# ITERATION:[1044/1209] | LOSS: 1.958352 | EPOCH = [3/3] | TIME ELAPSED =439.71Mins
# ITERATION:[1045/1209] | LOSS: 2.042884 | EPOCH = [3/3] | TIME ELAPSED =439.75Mins
# ITERATION:[1046/1209] | LOSS: 2.016295 | EPOCH = [3/3] | TIME ELAPSED =439.8Mins
# ITERATION:[1047/1209] | LOSS: 2.026835 | EPOCH = [3/3] | TIME ELAPSED =439.85Mins
# ITERATION:[1048/1209] | LOSS: 2.062092 | EPOCH = [3/3] | TIME ELAPSED =439.9Mins
# ITERATION:[1049/1209] | LOSS: 2.053279 | EPOCH = [3/3] | TIME ELAPSED =439.94Mins
# ITERATION:[1050/1209] | LOSS: 1.974347 | EPOCH = [3/3] | TIME ELAPSED =440.01Mins
# ITERATION:[1051/1209] | LOSS: 1.853633 | EPOCH = [3/3] | TIME ELAPSED =440.06Mins
# ITERATION:[1052/1209] | LOSS: 2.093538 | EPOCH = [3/3] | TIME ELAPSED =440.1Mins
# ITERATION:[1053/1209] | LOSS: 2.057847 | EPOCH = [3/3] | TIME ELAPSED =440.15Mins
# ITERATION:[1054/1209] | LOSS: 1.967573 | EPOCH = [3/3] | TIME ELAPSED =440.2Mins
# ITERATION:[1055/1209] | LOSS: 2.050903 | EPOCH = [3/3] | TIME ELAPSED =440.24Mins
# ITERATION:[1056/1209] | LOSS: 2.037303 | EPOCH = [3/3] | TIME ELAPSED =440.29Mins
# ITERATION:[1057/1209] | LOSS: 1.996783 | EPOCH = [3/3] | TIME ELAPSED =440.34Mins
# ITERATION:[1058/1209] | LOSS: 1.965317 | EPOCH = [3/3] | TIME ELAPSED =440.38Mins
# ITERATION:[1059/1209] | LOSS: 2.059729 | EPOCH = [3/3] | TIME ELAPSED =440.43Mins
# ITERATION:[1060/1209] | LOSS: 1.802862 | EPOCH = [3/3] | TIME ELAPSED =440.48Mins
# ITERATION:[1061/1209] | LOSS: 1.960226 | EPOCH = [3/3] | TIME ELAPSED =440.52Mins
# ITERATION:[1062/1209] | LOSS: 2.01936 | EPOCH = [3/3] | TIME ELAPSED =440.57Mins
# ITERATION:[1063/1209] | LOSS: 1.991562 | EPOCH = [3/3] | TIME ELAPSED =440.62Mins
# ITERATION:[1064/1209] | LOSS: 1.934668 | EPOCH = [3/3] | TIME ELAPSED =440.66Mins
# ITERATION:[1065/1209] | LOSS: 2.051412 | EPOCH = [3/3] | TIME ELAPSED =440.71Mins
# ITERATION:[1066/1209] | LOSS: 2.066412 | EPOCH = [3/3] | TIME ELAPSED =440.76Mins
# ITERATION:[1067/1209] | LOSS: 2.032157 | EPOCH = [3/3] | TIME ELAPSED =440.8Mins
# ITERATION:[1068/1209] | LOSS: 2.064698 | EPOCH = [3/3] | TIME ELAPSED =440.85Mins
# ITERATION:[1069/1209] | LOSS: 2.055488 | EPOCH = [3/3] | TIME ELAPSED =440.9Mins
# ITERATION:[1070/1209] | LOSS: 1.980871 | EPOCH = [3/3] | TIME ELAPSED =440.94Mins
# ITERATION:[1071/1209] | LOSS: 2.015879 | EPOCH = [3/3] | TIME ELAPSED =440.99Mins
# ITERATION:[1072/1209] | LOSS: 1.886654 | EPOCH = [3/3] | TIME ELAPSED =441.04Mins
# ITERATION:[1073/1209] | LOSS: 1.957403 | EPOCH = [3/3] | TIME ELAPSED =441.08Mins
# ITERATION:[1074/1209] | LOSS: 1.942225 | EPOCH = [3/3] | TIME ELAPSED =441.13Mins
# ITERATION:[1075/1209] | LOSS: 1.932981 | EPOCH = [3/3] | TIME ELAPSED =441.19Mins
# ITERATION:[1076/1209] | LOSS: 1.999843 | EPOCH = [3/3] | TIME ELAPSED =441.24Mins
# ITERATION:[1077/1209] | LOSS: 2.058333 | EPOCH = [3/3] | TIME ELAPSED =441.29Mins
# ITERATION:[1078/1209] | LOSS: 2.0238 | EPOCH = [3/3] | TIME ELAPSED =441.33Mins
# ITERATION:[1079/1209] | LOSS: 1.921422 | EPOCH = [3/3] | TIME ELAPSED =441.39Mins
# ITERATION:[1080/1209] | LOSS: 1.939531 | EPOCH = [3/3] | TIME ELAPSED =441.43Mins
# ITERATION:[1081/1209] | LOSS: 2.137897 | EPOCH = [3/3] | TIME ELAPSED =441.48Mins
# ITERATION:[1082/1209] | LOSS: 2.054801 | EPOCH = [3/3] | TIME ELAPSED =441.53Mins
# ITERATION:[1083/1209] | LOSS: 2.02213 | EPOCH = [3/3] | TIME ELAPSED =441.57Mins
# ITERATION:[1084/1209] | LOSS: 1.992713 | EPOCH = [3/3] | TIME ELAPSED =441.62Mins
# ITERATION:[1085/1209] | LOSS: 1.925675 | EPOCH = [3/3] | TIME ELAPSED =441.67Mins
# ITERATION:[1086/1209] | LOSS: 1.889703 | EPOCH = [3/3] | TIME ELAPSED =441.71Mins
# ITERATION:[1087/1209] | LOSS: 2.051883 | EPOCH = [3/3] | TIME ELAPSED =441.76Mins
# ITERATION:[1088/1209] | LOSS: 2.205675 | EPOCH = [3/3] | TIME ELAPSED =441.81Mins
# ITERATION:[1089/1209] | LOSS: 1.907229 | EPOCH = [3/3] | TIME ELAPSED =441.85Mins
# ITERATION:[1090/1209] | LOSS: 2.032484 | EPOCH = [3/3] | TIME ELAPSED =441.9Mins
# ITERATION:[1091/1209] | LOSS: 2.016186 | EPOCH = [3/3] | TIME ELAPSED =441.94Mins
# ITERATION:[1092/1209] | LOSS: 2.14951 | EPOCH = [3/3] | TIME ELAPSED =441.99Mins
# ITERATION:[1093/1209] | LOSS: 2.042128 | EPOCH = [3/3] | TIME ELAPSED =442.04Mins
# ITERATION:[1094/1209] | LOSS: 1.957812 | EPOCH = [3/3] | TIME ELAPSED =442.08Mins
# ITERATION:[1095/1209] | LOSS: 1.937576 | EPOCH = [3/3] | TIME ELAPSED =442.13Mins
# ITERATION:[1096/1209] | LOSS: 2.101709 | EPOCH = [3/3] | TIME ELAPSED =442.18Mins
# ITERATION:[1097/1209] | LOSS: 2.067677 | EPOCH = [3/3] | TIME ELAPSED =442.22Mins
# ITERATION:[1098/1209] | LOSS: 2.044973 | EPOCH = [3/3] | TIME ELAPSED =442.27Mins
# ITERATION:[1099/1209] | LOSS: 2.129057 | EPOCH = [3/3] | TIME ELAPSED =442.32Mins
# ITERATION:[1100/1209] | LOSS: 1.986892 | EPOCH = [3/3] | TIME ELAPSED =442.38Mins
# ITERATION:[1101/1209] | LOSS: 2.037671 | EPOCH = [3/3] | TIME ELAPSED =442.43Mins
# ITERATION:[1102/1209] | LOSS: 1.8899 | EPOCH = [3/3] | TIME ELAPSED =442.47Mins
# ITERATION:[1103/1209] | LOSS: 2.110974 | EPOCH = [3/3] | TIME ELAPSED =442.52Mins
# ITERATION:[1104/1209] | LOSS: 2.036607 | EPOCH = [3/3] | TIME ELAPSED =442.57Mins
# ITERATION:[1105/1209] | LOSS: 1.835748 | EPOCH = [3/3] | TIME ELAPSED =442.61Mins
# ITERATION:[1106/1209] | LOSS: 1.917299 | EPOCH = [3/3] | TIME ELAPSED =442.66Mins
# ITERATION:[1107/1209] | LOSS: 1.96222 | EPOCH = [3/3] | TIME ELAPSED =442.7Mins
# ITERATION:[1108/1209] | LOSS: 1.782184 | EPOCH = [3/3] | TIME ELAPSED =442.75Mins
# ITERATION:[1109/1209] | LOSS: 2.123115 | EPOCH = [3/3] | TIME ELAPSED =442.8Mins
# ITERATION:[1110/1209] | LOSS: 2.11084 | EPOCH = [3/3] | TIME ELAPSED =442.84Mins
# ITERATION:[1111/1209] | LOSS: 1.867313 | EPOCH = [3/3] | TIME ELAPSED =442.89Mins
# ITERATION:[1112/1209] | LOSS: 1.98599 | EPOCH = [3/3] | TIME ELAPSED =442.94Mins
# ITERATION:[1113/1209] | LOSS: 1.987346 | EPOCH = [3/3] | TIME ELAPSED =442.98Mins
# ITERATION:[1114/1209] | LOSS: 2.050695 | EPOCH = [3/3] | TIME ELAPSED =443.03Mins
# ITERATION:[1115/1209] | LOSS: 2.00069 | EPOCH = [3/3] | TIME ELAPSED =443.08Mins
# ITERATION:[1116/1209] | LOSS: 2.026533 | EPOCH = [3/3] | TIME ELAPSED =443.12Mins
# ITERATION:[1117/1209] | LOSS: 2.052406 | EPOCH = [3/3] | TIME ELAPSED =443.17Mins
# ITERATION:[1118/1209] | LOSS: 1.845996 | EPOCH = [3/3] | TIME ELAPSED =443.21Mins
# ITERATION:[1119/1209] | LOSS: 1.931293 | EPOCH = [3/3] | TIME ELAPSED =443.26Mins
# ITERATION:[1120/1209] | LOSS: 2.117947 | EPOCH = [3/3] | TIME ELAPSED =443.31Mins
# ITERATION:[1121/1209] | LOSS: 2.11617 | EPOCH = [3/3] | TIME ELAPSED =443.35Mins
# ITERATION:[1122/1209] | LOSS: 2.065011 | EPOCH = [3/3] | TIME ELAPSED =443.4Mins
# ITERATION:[1123/1209] | LOSS: 1.994407 | EPOCH = [3/3] | TIME ELAPSED =443.44Mins
# ITERATION:[1124/1209] | LOSS: 2.073692 | EPOCH = [3/3] | TIME ELAPSED =443.49Mins
# ITERATION:[1125/1209] | LOSS: 1.919315 | EPOCH = [3/3] | TIME ELAPSED =443.55Mins
# ITERATION:[1126/1209] | LOSS: 2.057709 | EPOCH = [3/3] | TIME ELAPSED =443.6Mins
# ITERATION:[1127/1209] | LOSS: 2.028801 | EPOCH = [3/3] | TIME ELAPSED =443.65Mins
# ITERATION:[1128/1209] | LOSS: 2.056103 | EPOCH = [3/3] | TIME ELAPSED =443.69Mins
# ITERATION:[1129/1209] | LOSS: 1.964959 | EPOCH = [3/3] | TIME ELAPSED =443.74Mins
# ITERATION:[1130/1209] | LOSS: 1.981231 | EPOCH = [3/3] | TIME ELAPSED =443.79Mins
# ITERATION:[1131/1209] | LOSS: 2.169792 | EPOCH = [3/3] | TIME ELAPSED =443.83Mins
# ITERATION:[1132/1209] | LOSS: 2.061205 | EPOCH = [3/3] | TIME ELAPSED =443.88Mins
# ITERATION:[1133/1209] | LOSS: 1.951498 | EPOCH = [3/3] | TIME ELAPSED =443.93Mins
# ITERATION:[1134/1209] | LOSS: 1.980382 | EPOCH = [3/3] | TIME ELAPSED =443.97Mins
# ITERATION:[1135/1209] | LOSS: 2.025218 | EPOCH = [3/3] | TIME ELAPSED =444.02Mins
# ITERATION:[1136/1209] | LOSS: 2.100542 | EPOCH = [3/3] | TIME ELAPSED =444.07Mins
# ITERATION:[1137/1209] | LOSS: 2.014005 | EPOCH = [3/3] | TIME ELAPSED =444.11Mins
# ITERATION:[1138/1209] | LOSS: 2.049785 | EPOCH = [3/3] | TIME ELAPSED =444.16Mins
# ITERATION:[1139/1209] | LOSS: 2.105901 | EPOCH = [3/3] | TIME ELAPSED =444.21Mins
# ITERATION:[1140/1209] | LOSS: 1.984188 | EPOCH = [3/3] | TIME ELAPSED =444.25Mins
# ITERATION:[1141/1209] | LOSS: 2.061282 | EPOCH = [3/3] | TIME ELAPSED =444.3Mins
# ITERATION:[1142/1209] | LOSS: 1.997636 | EPOCH = [3/3] | TIME ELAPSED =444.34Mins
# ITERATION:[1143/1209] | LOSS: 2.033594 | EPOCH = [3/3] | TIME ELAPSED =444.39Mins
# ITERATION:[1144/1209] | LOSS: 2.011281 | EPOCH = [3/3] | TIME ELAPSED =444.44Mins
# ITERATION:[1145/1209] | LOSS: 2.035654 | EPOCH = [3/3] | TIME ELAPSED =444.48Mins
# ITERATION:[1146/1209] | LOSS: 2.083554 | EPOCH = [3/3] | TIME ELAPSED =444.53Mins
# ITERATION:[1147/1209] | LOSS: 1.991986 | EPOCH = [3/3] | TIME ELAPSED =444.58Mins
# ITERATION:[1148/1209] | LOSS: 2.048467 | EPOCH = [3/3] | TIME ELAPSED =444.62Mins
# ITERATION:[1149/1209] | LOSS: 2.110628 | EPOCH = [3/3] | TIME ELAPSED =444.67Mins
# ITERATION:[1150/1209] | LOSS: 1.868432 | EPOCH = [3/3] | TIME ELAPSED =444.73Mins
# ITERATION:[1151/1209] | LOSS: 2.129927 | EPOCH = [3/3] | TIME ELAPSED =444.78Mins
# ITERATION:[1152/1209] | LOSS: 1.938487 | EPOCH = [3/3] | TIME ELAPSED =444.83Mins
# ITERATION:[1153/1209] | LOSS: 2.022214 | EPOCH = [3/3] | TIME ELAPSED =444.88Mins
# ITERATION:[1154/1209] | LOSS: 2.006067 | EPOCH = [3/3] | TIME ELAPSED =444.93Mins
# ITERATION:[1155/1209] | LOSS: 1.916265 | EPOCH = [3/3] | TIME ELAPSED =444.97Mins
# ITERATION:[1156/1209] | LOSS: 2.171432 | EPOCH = [3/3] | TIME ELAPSED =445.02Mins
# ITERATION:[1157/1209] | LOSS: 2.057936 | EPOCH = [3/3] | TIME ELAPSED =445.07Mins
# ITERATION:[1158/1209] | LOSS: 1.957882 | EPOCH = [3/3] | TIME ELAPSED =445.11Mins
# ITERATION:[1159/1209] | LOSS: 2.024588 | EPOCH = [3/3] | TIME ELAPSED =445.16Mins
# ITERATION:[1160/1209] | LOSS: 1.9835 | EPOCH = [3/3] | TIME ELAPSED =445.21Mins
# ITERATION:[1161/1209] | LOSS: 2.017635 | EPOCH = [3/3] | TIME ELAPSED =445.26Mins
# ITERATION:[1162/1209] | LOSS: 2.10513 | EPOCH = [3/3] | TIME ELAPSED =445.3Mins
# ITERATION:[1163/1209] | LOSS: 2.056625 | EPOCH = [3/3] | TIME ELAPSED =445.35Mins
# ITERATION:[1164/1209] | LOSS: 2.007656 | EPOCH = [3/3] | TIME ELAPSED =445.39Mins
# ITERATION:[1165/1209] | LOSS: 1.967407 | EPOCH = [3/3] | TIME ELAPSED =445.44Mins
# ITERATION:[1166/1209] | LOSS: 1.951157 | EPOCH = [3/3] | TIME ELAPSED =445.49Mins
# ITERATION:[1167/1209] | LOSS: 2.039487 | EPOCH = [3/3] | TIME ELAPSED =445.53Mins
# ITERATION:[1168/1209] | LOSS: 2.022587 | EPOCH = [3/3] | TIME ELAPSED =445.58Mins
# ITERATION:[1169/1209] | LOSS: 1.988397 | EPOCH = [3/3] | TIME ELAPSED =445.62Mins
# ITERATION:[1170/1209] | LOSS: 1.966604 | EPOCH = [3/3] | TIME ELAPSED =445.67Mins
# ITERATION:[1171/1209] | LOSS: 1.844892 | EPOCH = [3/3] | TIME ELAPSED =445.72Mins
# ITERATION:[1172/1209] | LOSS: 1.975685 | EPOCH = [3/3] | TIME ELAPSED =445.76Mins
# ITERATION:[1173/1209] | LOSS: 2.029608 | EPOCH = [3/3] | TIME ELAPSED =445.81Mins
# ITERATION:[1174/1209] | LOSS: 2.083648 | EPOCH = [3/3] | TIME ELAPSED =445.86Mins
# ITERATION:[1175/1209] | LOSS: 2.065825 | EPOCH = [3/3] | TIME ELAPSED =445.92Mins
# ITERATION:[1176/1209] | LOSS: 2.003339 | EPOCH = [3/3] | TIME ELAPSED =445.97Mins
# ITERATION:[1177/1209] | LOSS: 1.926649 | EPOCH = [3/3] | TIME ELAPSED =446.02Mins
# ITERATION:[1178/1209] | LOSS: 2.01066 | EPOCH = [3/3] | TIME ELAPSED =446.06Mins
# ITERATION:[1179/1209] | LOSS: 2.136782 | EPOCH = [3/3] | TIME ELAPSED =446.11Mins
# ITERATION:[1180/1209] | LOSS: 2.027989 | EPOCH = [3/3] | TIME ELAPSED =446.16Mins
# ITERATION:[1181/1209] | LOSS: 1.90595 | EPOCH = [3/3] | TIME ELAPSED =446.2Mins
# ITERATION:[1182/1209] | LOSS: 2.0801 | EPOCH = [3/3] | TIME ELAPSED =446.25Mins
# ITERATION:[1183/1209] | LOSS: 2.115711 | EPOCH = [3/3] | TIME ELAPSED =446.3Mins
# ITERATION:[1184/1209] | LOSS: 1.953609 | EPOCH = [3/3] | TIME ELAPSED =446.34Mins
# ITERATION:[1185/1209] | LOSS: 2.092743 | EPOCH = [3/3] | TIME ELAPSED =446.39Mins
# ITERATION:[1186/1209] | LOSS: 2.026909 | EPOCH = [3/3] | TIME ELAPSED =446.43Mins
# ITERATION:[1187/1209] | LOSS: 2.01999 | EPOCH = [3/3] | TIME ELAPSED =446.48Mins
# ITERATION:[1188/1209] | LOSS: 2.08229 | EPOCH = [3/3] | TIME ELAPSED =446.53Mins
# ITERATION:[1189/1209] | LOSS: 1.982079 | EPOCH = [3/3] | TIME ELAPSED =446.57Mins
# ITERATION:[1190/1209] | LOSS: 1.955756 | EPOCH = [3/3] | TIME ELAPSED =446.62Mins
# ITERATION:[1191/1209] | LOSS: 2.031409 | EPOCH = [3/3] | TIME ELAPSED =446.67Mins
# ITERATION:[1192/1209] | LOSS: 2.065577 | EPOCH = [3/3] | TIME ELAPSED =446.71Mins
# ITERATION:[1193/1209] | LOSS: 2.010603 | EPOCH = [3/3] | TIME ELAPSED =446.76Mins
# ITERATION:[1194/1209] | LOSS: 2.037425 | EPOCH = [3/3] | TIME ELAPSED =446.81Mins
# ITERATION:[1195/1209] | LOSS: 2.030224 | EPOCH = [3/3] | TIME ELAPSED =446.85Mins
# ITERATION:[1196/1209] | LOSS: 1.946306 | EPOCH = [3/3] | TIME ELAPSED =446.9Mins
# ITERATION:[1197/1209] | LOSS: 1.958968 | EPOCH = [3/3] | TIME ELAPSED =446.95Mins
# ITERATION:[1198/1209] | LOSS: 2.05017 | EPOCH = [3/3] | TIME ELAPSED =447.0Mins
# ITERATION:[1199/1209] | LOSS: 1.952291 | EPOCH = [3/3] | TIME ELAPSED =447.04Mins
# ITERATION:[1200/1209] | LOSS: 1.871832 | EPOCH = [3/3] | TIME ELAPSED =447.1Mins
# ITERATION:[1201/1209] | LOSS: 2.119914 | EPOCH = [3/3] | TIME ELAPSED =447.15Mins
# ITERATION:[1202/1209] | LOSS: 2.046303 | EPOCH = [3/3] | TIME ELAPSED =447.2Mins
# ITERATION:[1203/1209] | LOSS: 1.969977 | EPOCH = [3/3] | TIME ELAPSED =447.24Mins
# ITERATION:[1204/1209] | LOSS: 2.001503 | EPOCH = [3/3] | TIME ELAPSED =447.29Mins
# ITERATION:[1205/1209] | LOSS: 1.920385 | EPOCH = [3/3] | TIME ELAPSED =447.34Mins
# ITERATION:[1206/1209] | LOSS: 1.825366 | EPOCH = [3/3] | TIME ELAPSED =447.39Mins
# ITERATION:[1207/1209] | LOSS: 2.019266 | EPOCH = [3/3] | TIME ELAPSED =447.43Mins
# ITERATION:[1208/1209] | LOSS: 2.037761 | EPOCH = [3/3] | TIME ELAPSED =447.48Mins
# ITERATION:[1209/1209] | LOSS: 1.958795 | EPOCH = [3/3] | TIME ELAPSED =447.49Mins
#
# $$Loss = 1.958795,EPOCH: [3/3]

# %%
sorted(VOCAB.items(), key=lambda x: x[1], reverse=True) 
#WORD2IDX

# %% [markdown]
# ### Test Model

# %%
phase = "Train"
if phase == "Test":
  if platform != 'colab':
    with open('../dict/VOCAB.pkl', 'rb') as handle:
        VOCAB = pickle.load(handle)
    with open('../dict/WORD2IDX.pkl', 'rb') as handle:
        WORD2IDX = pickle.load(handle)
    with open('../dict/IDX2WORD.pkl', 'rb') as handle:
        IDX2WORD = pickle.load(handle)
    print("Dictionary Loaded Successfully")
  else:
    with open('/content/drive/My Drive/A4/dict/VOCAB.pkl', 'rb') as handle:
        VOCAB = pickle.load(handle)
    with open('/content/drive/My Drive/A4/dict/WORD2IDX.pkl', 'rb') as handle:
        WORD2IDX = pickle.load(handle)
    with open('/content/drive/My Drive/A4/dict/IDX2WORD.pkl', 'rb') as handle:
        IDX2WORD = pickle.load(handle)
    print("Dictionary Loaded Successfully")

        
if platform == "colab":
    IMAGE_DIR = '/content/drive/My Drive/train/'
else:
    IMAGE_DIR = 'D:/Padhai/IIT Delhi MS(R)/2019-20 Sem II/COL774 Machine Learning/Assignment/Assignment4/train_images/'
if restore == True:
    net = ImageCaptionsNet()
    net = net.double()
    #net = net.to(torch.device("cuda:0"))
    #net = nn.DataParallel(net)
    state_dict = collections.OrderedDict()
    state_dict = restore_checkpoint("Final_Model_comp1.pth")
    net = ImageCaptionsNet()
    net = net.double()
    #net.load_state_dict(state_dict)
    print("State Dictionary Loaded Successfully.")

    # load params
    #if device != 'cpu':
     #   net = nn.DataParallel(net)
     #   net = net.to(torch.device("cuda:0"))


# Creating the Dataset
test_dataset = ImageCaptionsDataset(
    IMAGE_DIR, captions_preprocessing_obj.captions_dict, img_transform=img_transform,
    captions_transform=captions_preprocessing_obj.captions_transform)



def beam_search(img_feature, max_words=15, beam_k=3):
    
    #init with start token 
    init_caption = []
    init_caption = [[[WORD2IDX["<start>"]], float(0)]]
    
    
    #print(img_feature.shape)
    #img_feature = img_feature.unsqueeze(dim=1)
    while len(init_caption[0][0]) < max_words:
        temp_cap = []
        for c in init_caption:  
            #print(c[0])
            cap_pad = c[0] +  [0] * int(max_words - len(c[0]))
            cap_pad = torch.LongTensor(cap_pad).unsqueeze(dim=0)
            lstm_op = net.Decoder(img_feature, cap_pad)        
            lstm_op = lstm_op.reshape(max_words, lstm_op.shape[2])
        
            #TOP k prob
            #print(lstm_op.shape)
            #print(torch.argmax(lstm_op[0], dim=0).tolist())
            top_pred = torch.argmax(lstm_op, dim=1)
            #top_pred = torch.argsort(top_pred)[-beam_k:]
            print(top_pred)
            for i in range(beam_k): 
                word_idx = top_pred[i]
                prob = c[1] + lstm_op[0][word_idx]
                cap = c[0][:] + [word_idx]
                
                temp_cap.append([cap, prob])
                
        init_caption = temp_cap
        init_caption = sorted(init_caption, reverse=False, key=lambda x: x[1])[-beam_k:]
    #print(type(init_caption[-1][0]))
    temp_caption = list(map(lambda x: IDX2WORD[x], init_caption[-1][0]))
    
    pred_caption = list()
    for w in temp_caption:
        if w != '<end>':
            pred_caption.append(w)
        else:
            break
    
    return pred_caption

def caption_image(image_feature, max_words=20):
        results = []
        states = None
        x = image_feature.unsqueeze(0)
        
        with torch.no_grad():
            for i in range(max_words):
                
                hiddens, states = net.Decoder.lstm(x, states)
                #print(hiddens.shape)
                decoder_op = net.Decoder.linear(hiddens.squeeze(1))
                predicted_word = decoder_op.argmax(1)
                prob = max(decoder_op[0].tolist())
                #print("{} - {}".format(IDX2WORD[predicted_word.item()], prob))
                x = net.Decoder.embed(predicted_word).unsqueeze(0)
                
                results.append(predicted_word.item())
                
                if predicted_word == WORD2IDX["<end>"]:
                    break
        
        caption = [IDX2WORD[i] for i in  results]
        return ' '.join(caption)
               
    
# Define your hyperparameters

NUM_WORKERS = 0 # Parallel threads for dataloading
MAX_WORDS = 30
# Creating the DataLoader for batching purposes
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=NUM_WORKERS, 
                         collate_fn=custom_batch)
import os
if device != "cpu":
    os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
t0 = time()
pred_caps = {}
for batch_idx, sample in enumerate(test_loader):
        #print("Image_idx", batch_idx)
        image_batch, captions_batch = sample['image'], sample['captions']
        print("AFTER", image_batch)
        #print("Original", [IDX2WORD[i] for i in captions_batch)
        #print("Cap", [IDX2WORD[int(i)] for i in captions_batch[0]])
        img_features = net.Encoder(image_batch)
        #img_features = img_features.view(-1)[torch.randperm(img_features.nelement())].view(img_features.size())
        #img_features = torch.FloatTensor(np.random.randn(1,300))
        #print(img_features[0][:4].tolist(), img_features[0][-5:].tolist())
        #print(x.shape)
        #pred_cap = beam_search(img_features)
        pred_cap = caption_image(img_features)
        
        pred_caps[batch_idx] = pred_cap
        #print("Predicted",batch_idx, pred_cap)

# %%
'''if platform == "colab":
    embed_path = '/content/drive/My Drive/A4/embeddings/trained_embed.pkl'
else:
    embed_path = '../embeddings/trained_embed.pkl'
with open(embed_path, 'rb') as handle:
    vocab_dump = pickle.load(handle)

init_weights = torch.randn(len(VOCAB), 300)
idx = 0
words = WORD2IDX.keys()
for i in range(len(words)):
    init_weights[i] = vocab_dump[IDX2WORD[i]]
init_weights.shape'''
# Out:
# 'if platform == "colab":\n    embed_path = \'/content/drive/My Drive/A4/embeddings/trained_embed.pkl\'\nelse:\n    embed_path = \'../embeddings/trained_embed.pkl\'\nwith open(embed_path, \'rb\') as handle:\n    vocab_dump = pickle.load(handle)\n\ninit_weights = torch.randn(len(VOCAB), 300)\nidx = 0\nwords = WORD2IDX.keys()\nfor i in range(len(words)):\n    init_weights[i] = vocab_dump[IDX2WORD[i]]\ninit_weights.shape'

# %%
reference = [['this', 'is', 'a', 'test'], ['this', 'is' 'test']]
candidate = ['un', 'uomo', 'in', 'camicia', 'rossa', 'e', 'un', 'gilet', 'blu', 'e', 'una', 'donna', '.']
score = sentence_bleu(reference, candidate)

# %%
models.resnet34()

# %%
class ninikarraha():
  kuch to batao
  kya haal chal
  return True

# %%
pred = '<start> un.uomo in camicia rossa e un gilet blu e una donna , <unk> <unk> <unk> . <end>'

# %%
string_in  = "somename"

# %%
del "something.zip"
