# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

import torchvision.models as models
from torch.nn.utils.rnn import pack_padded_sequence

from skimage import io, transform

import matplotlib.pyplot as plt # for plotting
import numpy as np
from collections import Counter
from nltk.tokenize import word_tokenize
import nltk
import itertools

# %% [markdown]
# ### Image Transforms

# %%
class Rescale(object):
    """Rescale the image in a sample to a given size.

    Args:
        output_size (tuple or int): Desired output size. If tuple, output is
            matched to output_size. If int, smaller of image edges is matched
            to output_size keeping aspect ratio the same.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size

    def __call__(self, image):
        h, w = image.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)
        img = transform.resize(image, (new_h, new_w))
        return img


class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, image):
        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose((2, 0, 1))
        return image


IMAGE_RESIZE = (256, 256)
# Sequentially compose the transforms
img_transform = transforms.Compose([Rescale(IMAGE_RESIZE), ToTensor()])

# %% [markdown]
# ### Captions Preprocessing

# %%
class CaptionsPreprocessing:
    """Preprocess the captions, generate vocabulary and convert words to tensor tokens

    Args:
        captions_file_path (string): captions tsv file path
    """
    def __init__(self, captions_file_path):
        self.captions_file_path = captions_file_path

        # Read raw captions
        self.raw_captions_dict = self.read_raw_captions()

        # Preprocess captions
        self.captions_dict = self.process_captions()

        # Create vocabulary
        self.vocab = self.generate_vocabulary()

    def read_raw_captions(self):
        """
        Returns:
            Dictionary with raw captions list keyed by image ids (integers)
        """

        captions_dict = {}
        with open(self.captions_file_path, 'r', encoding='utf-8') as f:
            for img_caption_line in f.readlines():
                img_captions = img_caption_line.strip().split('\t')
                captions_dict[int(img_captions[0])] = img_captions[1:]

        return captions_dict

    def process_captions(self):
        """
        Use this function to generate dictionary and other preprocessing on captions
        """

        raw_captions_dict = self.raw_captions_dict
        word_counter = Counter()

        # Do the preprocessing here
        raw_captions_dict = captions_dict
        word_counter = Counter()
        FREQUENCY_THRESHOLD = 10
        #stop_words = set(nltk.corpus.stopwords.words('english'))
        # Do the preprocessing here
        for caption_id in raw_captions_dict:
            #print(caption_id)
            caption_list = raw_captions_dict[caption_id]
            for caption in caption_list:
                #filtered_caption = ''.join(([w for w in caption if not w in stop_words]))
                words = word_tokenize(caption.lower())
                #print(words)
                # update word frequency
                word_counter.update(words)
        words_final = [word for word, wordcount in word_counter.items() if wordcount >= FREQUENCY_THRESHOLD] 
        
        #update dictionary
        """
        captions_dict_updated = {}
        for caption_id in raw_captions_dict:
            #print(caption_id)
            caption_list = raw_captions_dict[caption_id]
            new_words = []
            for caption in caption_list:
                #filtered_caption = ''.join(([w for w in caption if not w in stop_words]))
                words = word_tokenize(caption.lower())
                new_words.append('<START>') 
                new_words.extend([word for word in words if word in words_final])
                new_words.append('<END>')
            #print(new_words)
            captions_dict_updated[int(caption_id)] = new_words
        """
        captions_dict_updated = {}
        for caption_id in raw_captions_dict:
            #print(caption_id)
            caption_list = raw_captions_dict[caption_id]
            new_words_list = []
            for caption in caption_list:
                #filtered_caption = ''.join(([w for w in caption if not w in stop_words]))
                words = word_tokenize(caption.lower())
                new_words = []
                new_words.append('<START>') 
                new_words.extend([word for word in words if word in words_final])
                new_words.append('<END>')
                new_words_list.append(new_words)
            #print(new_words_list)
        captions_dict_updated[int(caption_id)] = new_words_list
        
        #create vocabulary
        '''
        self.vocab['<START>'] = 1
        i=1
        for word, wordcount in word_counter.items():
            self.vocab[word] = i
            i += 1
        self.vocab['<END>'] = i
        '''

        return captions_dict_updated

    def generate_vocabulary(self):
        """
        Use this function to generate dictionary and other preprocessing on captions
        """
        #create vocabulary
        raw_captions_dict = self.raw_captions_dict
        word_counter = Counter()
        vocab = {}
        # Do the preprocessing here
        raw_captions_dict = captions_dict
        word_counter = Counter()
        FREQUENCY_THRESHOLD = 20
        #stop_words = set(nltk.corpus.stopwords.words('english'))
        # Do the preprocessing here
        for caption_id in raw_captions_dict:
            #print(caption_id)
            caption_list = raw_captions_dict[caption_id]
            for caption in caption_list:
                #filtered_caption = ''.join(([w for w in caption if not w in stop_words]))
                words = word_tokenize(caption.lower())
                #print(words)
                # update word frequency
                word_counter.update(words)
        words_final = [word for word, wordcount in word_counter.items() if wordcount >= FREQUENCY_THRESHOLD]
        
        vocab['<START>'] = 1
        i=1
        for word, wordcount in word_counter.items():
            vocab[word] = i
            i += 1
        vocab['<END>'] = i

        return vocab

    def captions_transform(self, img_caption_list):
        """
        Use this function to generate tensor tokens for the text captions
        Args:
            img_caption_list: List of captions for a particular image
        """
        caption_tensor = torch.zeros(len(img_caption_list), 100)
        vocab = self.vocab
        for idx1, caption in enumerate(img_caption_list):
            for idx2, word in enumerate(caption):
                  caption_tensor[idx1][idx2] =  vocab[word]        
        # Generate tensors

        return caption_tensor

# Set the captions tsv file path
CAPTIONS_FILE_PATH = 'data/public_test_captions.tsv'
captions_preprocessing_obj = CaptionsPreprocessing(CAPTIONS_FILE_PATH)

# %%
print(captions_preprocessing_obj.captions_transform)
# Out:
# <bound method CaptionsPreprocessing.captions_transform of <__main__.CaptionsPreprocessing object at 0x1c3b6e7d90>>

# %% [markdown]
# ### Dataset Class

# %%
class ImageCaptionsDataset(Dataset):

    def __init__(self, img_dir, captions_dict, img_transform=None, captions_transform=None):
        """
        Args:
            img_dir (string): Directory with all the images.
            captions_dict: Dictionary with captions list keyed by image ids (integers)
            img_transform (callable, optional): Optional transform to be applied
                on the image sample.

            captions_transform: (callable, optional): Optional transform to be applied
                on the caption sample (list).
        """
        self.img_dir = img_dir
        self.captions_dict = captions_dict
        self.img_transform = img_transform
        self.captions_transform = captions_transform

        self.image_ids = list(captions_dict.keys())

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        img_name = os.path.join(self.img_dir, 'image_{}.jpg'.format(self.image_ids[idx]))
        image = io.imread(img_name)
        captions = self.captions_dict[self.image_ids[idx]]

        if self.img_transform:
            image = self.img_transform(image)

        if self.captions_transform:
            captions = self.captions_transform(captions)

        sample = {'image': image, 'captions': captions}

        return sample

# %% [markdown]
# ### Model Architecture

# %%
class ImageCaptionsNet(nn.Module):
    def __init__(self, embed_size, hidden_size, vocab_size, num_layers, max_seq_length=20):
        super(ImageCaptionsNet, self).__init__()
        resnet = models.resnet152(pretrained=True)
        modules = list(resnet.children())[:-1]      # delete the last fc layer.
        self.resnet = nn.Sequential(*modules)
        self.linear = nn.Linear(resnet.fc.in_features, embed_size)
        self.bn = nn.BatchNorm1d(embed_size, momentum=0.01)
        self.embed = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, vocab_size)
        self.max_seg_length = max_seq_length
        # Define your architecture here

    def forward(self, x):
        x = image_batch, captions_batch

        # Forward Propogation
        with torch.no_grad():
            features = self.resnet(image_batch)
        features = features.reshape(features.size(0), -1)
        features = self.bn(self.linear(features))
        embeddings = self.embed(captions_batch)
        embeddings = torch.cat((features.unsqueeze(1), embeddings), 1)
        packed = pack_padded_sequence(embeddings, lengths, batch_first=True) 
        hiddens, _ = self.lstm(packed)
        outputs_captions_batch = self.linear(hiddens[0])
        return captions_batch

net = ImageCaptionsNet(256, 512, len(captions_preprocessing_obj.vocab), 1)

# If GPU training is required
# net = net.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /Users/anjali/.cache/torch/hub/checkpoints/resnet152-b121ed2d.pth
# HBox(children=(IntProgress(value=0, max=241530880), HTML(value='')))

# %% [markdown]
# ### Training Loop

# %%
IMAGE_DIR = 'data/public_test_images/'

# Creating the Dataset
train_dataset = ImageCaptionsDataset(
    IMAGE_DIR, captions_preprocessing_obj.captions_dict, img_transform=img_transform,
    captions_transform=captions_preprocessing_obj.captions_transform
)

# Define your hyperparameters
NUMBER_OF_EPOCHS = 3
LEARNING_RATE = 1e-1
BATCH_SIZE = 32
NUM_WORKERS = 0 # Parallel threads for dataloading
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=LEARNING_RATE)

# Creating the DataLoader for batching purposes
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
import os
for epoch in range(NUMBER_OF_EPOCHS):
    for batch_idx, sample in enumerate(train_loader):
        net.zero_grad()

        image_batch, captions_batch = sample['image'], sample['captions']

        # If GPU training required
        # image_batch, captions_batch = image_batch.cuda(), captions_batch.cuda()

        output_captions = net((image_batch, captions_batch))
        loss = loss_function(output_captions, captions_batch)
        loss.backward()
        optimizer.step()
    print("Iteration: " + str(epoch + 1))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-70-fdd33ed7e0e7> in <module>
#      27         # image_batch, captions_batch = image_batch.cuda(), captions_batch.cuda()
#      28
# ---> 29         output_captions = net((image_batch, captions_batch))
#      30         loss = loss_function(output_captions, captions_batch)
#      31         loss.backward()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-54-fdd868f88238> in forward(self, x)
#      18         # Forward Propogation
#      19         with torch.no_grad():
# ---> 20             features = self.resnet(image_batch)
#      21         features = features.reshape(features.size(0), -1)
#      22         features = self.bn(self.linear(features))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     417
#     418     def forward(self, input: Tensor) -> Tensor:
# --> 419         return self._conv_forward(input, self.weight)
#     420
#     421 class Conv3d(_ConvNd):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     414                             _pair(0), self.dilation, self.groups)
#     415         return F.conv2d(input, weight, self.bias, self.stride,
# --> 416                         self.padding, self.dilation, self.groups)
#     417
#     418     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: Expected object of scalar type Double but got scalar type Float for argument #3 'mat1' in call to _th_addmm_

# %%
a=torch.zeros(len([2,3,4,5]), 30)
print(a[0][30])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-7758db9a83fb> in <module>
#       1 a=torch.zeros(len([2,3,4,5]), 30)
# ----> 2 print(a[0][30])
#
# IndexError: index 30 is out of bounds for dimension 0 with size 30

# %%
IMAGE_DIR = 'data/public_test_images/'

# Creating the Dataset
train_dataset = ImageCaptionsDataset(
    IMAGE_DIR, captions_preprocessing_obj.captions_dict, img_transform=img_transform,
    captions_transform=captions_preprocessing_obj.captions_transform
)

# %%
train_dataset

# %%
def read_raw_captions(captions_file_path):
        """
        Returns:
            Dictionary with raw captions list keyed by image ids (integers)
        """

        captions_dict = {}
        with open(captions_file_path, 'r', encoding='utf-8') as f:
            for img_caption_line in f.readlines():
                img_captions = img_caption_line.strip().split('\t')
                #print(img_captions[1])
                #print(img_captions[0],img_captions[1:])
                captions_dict[int(img_captions[0])] = img_captions[1:]

        return captions_dict

# %%
captions_file_path='data/public_test_captions.tsv'
captions_dict = read_raw_captions(captions_file_path)

# %%
raw_captions_dict = captions_dict
#captions_dict = {}
word_counter = Counter()
FREQUENCY_THRESHOLD = 0
#stop_words = set(nltk.corpus.stopwords.words('english'))
# Do the preprocessing here
for caption_id in raw_captions_dict:
    #print(caption_id)
    caption_list = raw_captions_dict[caption_id]
    for caption in caption_list:
        #filtered_caption = ''.join(([w for w in caption if not w in stop_words]))
        words = word_tokenize(caption.lower())
        #print(words)
        # update word frequency
        word_counter.update(words)
words_final = [word for word, wordcount in word_counter.items() if wordcount >= FREQUENCY_THRESHOLD]

# %%
vocab = {}
i=0
for word, wordcount in word_counter.items():
    vocab[word] = i
    i += 1
#for word in vocab:
    #print(word,vocab[word])

# %%
len(word_counter)
# Out:
# 4649

# %%
print(sorted(word_counter.items(), key = 
             lambda kv:(kv[1], kv[0])))
# Out:
# [('#', 1), ('...', 1), ('10', 1), ('11', 1), ('49ers', 1), ('6', 1), ('7', 1), ('9', 1), ('abbandonato', 1), ('abbia', 1), ('abbracciare', 1), ('abbracciata', 1), ('abbraccio', 1), ('accelerare', 1), ('accendere', 1), ('accendono', 1), ('accentati', 1), ('accenti', 1), ('accesa', 1), ('accese', 1), ('accesi', 1), ('accettare', 1), ('acciaio', 1), ('accompagnati', 1), ('accoppiati', 1), ('accovacciando', 1), ('accumulata', 1), ('acini', 1), ('acquatica', 1), ('acque', 1), ('acquirenti', 1), ('acrobat', 1), ('acrobazie', 1), ('acustiche', 1), ('addestramento', 1), ('addestrando', 1), ('addormentano', 1), ('addormentata', 1), ('addormentati', 1), ('adesivi', 1), ('adombrelli', 1), ('adoravano', 1), ('adulte', 1), ('advice', 1), ('aeree', 1), ('aerei', 1), ('affascinati', 1), ('afferra', 1), ('afferrando', 1), ('affettato', 1), ('affettuosamente', 1), ('affilata', 1), ('affilati', 1), ('affollano', 1), ('affollate', 1), ('affonda', 1), ('affronta', 1), ('africa', 1), ('afroamericana', 1), ('afroamericani', 1), ('aggira', 1), ('aggiustano', 1), ('aggrappandosi', 1), ('aggrappato', 1), ('agitando', 1), ('agitati', 1), ('agnelli', 1), ('agricoltori', 1), ('agricoltura', 1), ('aiutarlo', 1), ('aiuto', 1), ('alcol', 1), ('ali', 1), ('alice', 1), ('alieni', 1), ('alimentare', 1), ('alimentato', 1), ("all'acquario", 1), ("all'altra", 1), ("all'aria", 1), ("all'ascensore", 1), ("all'asilo", 1), ("all'attenzione", 1), ("all'autista", 1), ("all'avventura", 1), ("all'edificio", 1), ("all'esercito", 1), ("all'indietro", 1), ("all'obiettivo", 1), ("all'osservatore", 1), ("all'uscita", 1), ('allenatori', 1), ('allentando', 1), ('alleva', 1), ('allevamento', 1), ('allineata', 1), ('alpinisti', 1), ('altitudini', 1), ('altoparlanti', 1), ('amano', 1), ('amanti', 1), ('american', 1), ('americane', 1), ('amiche', 1), ('ammirano', 1), ('amore', 1), ('amputato', 1), ('andatori', 1), ('anelli', 1), ('anglo', 1), ('animati', 1), ('animato', 1), ('ann', 1), ('annaffiando', 1), ('annuale', 1), ('ansiosamente', 1), ('antica', 1), ('antichi', 1), ('antico', 1), ('antiquati', 1), ('antonio', 1), ('apertura', 1), ('apparato', 1), ('apparecchi', 1), ('apparecchiature', 1), ('apparire', 1), ('appartamenti', 1), ('appartamento', 1), ('appassionatamente', 1), ('appassionate', 1), ('appende', 1), ('applaudi', 1), ('applaudiano', 1), ('appoggiati', 1), ('appollaiato', 1), ('apprezzano', 1), ('appuntamenti', 1), ('appuntamento', 1), ('appunti', 1), ('appuntito', 1), ('aprendo', 1), ('arabo', 1), ('arance', 1), ('arcobaleni', 1), ('arena', 1), ('arenaria', 1), ('argilla', 1), ('aride', 1), ('armadio', 1), ('armate', 1), ('armi', 1), ('armonio', 1), ('army', 1), ('arrabbia', 1), ('arrabbiato', 1), ('arrampicando', 1), ('arrampicati', 1), ('arrestato', 1), ('arricciata', 1), ('arricciato', 1), ('arrivi', 1), ('arrotola', 1), ('arrotolati', 1), ('arrugginita', 1), ('art', 1), ('articolo', 1), ('artigianali', 1), ('artigianate', 1), ('arto', 1), ('asciugacapelli', 1), ('asciugando', 1), ('ascoltarne', 1), ('asino', 1), ('aspettare', 1), ('assemblano', 1), ('assistendo', 1), ('assistente', 1), ('assistenti', 1), ('assistere', 1), ('assolo', 1), ('attaccano', 1), ('attaccare', 1), ('attaccate', 1), ('attaccati', 1), ('attenzione', 1), ('atterra', 1), ('attira', 1), ('attività', 1), ('attraente', 1), ('attraversate', 1), ('attrezzato', 1), ('attrezzi', 1), ('attuale', 1), ('audio', 1), ('autista', 1), ('autografi', 1), ('aviazione', 1), ('avrebbe', 1), ('avvenendo', 1), ('avvertimento', 1), ('avvicinando', 1), ('avvisa', 1), ('avvolta', 1), ('avvolti', 1), ('aziendale', 1), ('azioni', 1), ('azzurra', 1), ('azzurro', 1), ('babbo', 1), ('baciarsi', 1), ('bacon', 1), ('baffi', 1), ('bagaglio', 1), ('bagna', 1), ('bagnano', 1), ('bagnate', 1), ('bagni', 1), ('bagpi', 1), ('balene', 1), ('bali', 1), ('ballando', 1), ('ballerino', 1), ('banchetti', 1), ('banchi', 1), ('bancomat', 1), ('bandana', 1), ('bank', 1), ('bar-b-que', 1), ('baracca', 1), ('barboncini', 1), ('barchetta',  ...

# %%
i=0
for word, wordcount in word_counter.items():
    if(i<500):
        print(wordcount);
    i+=1
# Out:
# 19833
# 2325
# 49685
# 9358
# 3629
# 120
# 2722
# 8435
# 1092
# 11709
# 5295
# 69004
# 589
# 144576
# 1727
# 401
# 1577
# 4776
# 16639
# 804
# 110
# 8281
# 530
# 791
# 145518
# 279
# 34042
# 7038
# 10284
# 365
# 47
# 56
# 15306
# 140
# 1538
# 813
# 5077
# 186
# 7100
# 50
# 22
# 41
# 61822
# 6
# 220
# 97
# 21192
# 510
# 109
# 44226
# 816
# 96807
# 1460
# 1086
# 390
# 73
# 2041
# 951
# 7194
# 368
# 277
# 5330
# 4039
# 12
# 7370
# 3401
# 2642
# 18801
# 83
# 205
# 595
# 11552
# 20
# 2283
# 80
# 213
# 1546
# 389
# 20506
# 2552
# 926
# 397
# 15133
# 374
# 2053
# 5372
# 2582
# 831
# 8140
# 41743
# 9693
# 5096
# 1393
# 420
# 824
# 911
# 652
# 29248
# 99
# 250
# 558
# 1998
# 5069
# 204
# 22126
# 6649
# 932
# 3102
# 5494
# 5827
# 70
# 73
# 6
# 1837
# 907
# 10
# 109
# 49
# 1211
# 156
# 164
# 13124
# 2633
# 2616
# 390
# 1887
# 473
# 5719
# 79
# 4021
# 3417
# 893
# 123
# 89
# 490
# 2864
# 159
# 388
# 2
# 864
# 1930
# 748
# 3245
# 1130
# 1096
# 219
# 44
# 3504
# 4620
# 319
# 22
# 6
# 9
# 88
# 2253
# 984
# 435
# 146
# 4214
# 1171
# 1314
# 821
# 298
# 42
# 430
# 22
# 2939
# 8964
# 2996
# 59
# 4626
# 25
# 32
# 940
# 1292
# 1386
# 8737
# 33
# 21509
# 26
# 734
# 447
# 1083
# 1048
# 691
# 914
# 303
# 559
# 90
# 301
# 568
# 736
# 3188
# 2214
# 5127
# 1
# 79
# 666
# 1561
# 116
# 1625
# 4
# 667
# 239
# 44
# 1073
# 86
# 623
# 238
# 804
# 99
# 2126
# 142
# 870
# 3665
# 833
# 206
# 24
# 170
# 244
# 93
# 280
# 376
# 2161
# 70
# 7
# 268
# 2
# 1956
# 13
# 311
# 459
# 29
# 117
# 72
# 377
# 2
# 1579
# 97
# 21
# 434
# 89
# 737
# 42
# 823
# 1376
# 2714
# 2057
# 683
# 424
# 113
# 3
# 193
# 615
# 1622
# 8065
# 5548
# 53
# 93
# 8
# 3311
# 2197
# 10
# 553
# 122
# 226
# 1582
# 40
# 98
# 722
# 464
# 39
# 5
# 184
# 1372
# 161
# 29
# 15
# 3
# 122
# 18
# 1
# 150
# 393
# 2331
# 108
# 911
# 691
# 88
# 217
# 104
# 2
# 35
# 148
# 628
# 5133
# 4382
# 448
# 809
# 342
# 352
# 207
# 8198
# 337
# 1814
# 511
# 3000
# 328
# 92
# 4279
# 258
# 586
# 2
# 838
# 1911
# 25
# 6
# 1
# 141
# 3479
# 74
# 54
# 64
# 1831
# 386
# 2665
# 166
# 65
# 77
# 550
# 111
# 382
# 270
# 248
# 97
# 2236
# 28
# 402
# 328
# 1668
# 1069
# 3221
# 31
# 58
# 157
# 74
# 1191
# 209
# 2922
# 632
# 411
# 2113
# 499
# 18
# 262
# 485
# 207
# 259
# 99
# 237
# 7
# 13
# 73
# 2464
# 55
# 843
# 1014
# 532
# 113
# 969
# 249
# 2378
# 13
# 2
# 1919
# 164
# 4
# 955
# 2981
# 641
# 32
# 2
# 1401
# 69
# 125
# 10
# 248
# 112
# 1460
# 3748
# 740
# 169
# 188
# 40
# 98
# 692
# 7
# 375
# 6
# 180
# 6
# 5491
# 403
# 2670
# 307
# 49
# 3569
# 42
# 4
# 18
# 785
# 512
# 402
# 13
# 602
# 149
# 166
# 35
# 3
# 504
# 5041
# 7521
# 132
# 6
# 1163
# 1495
# 7
# 1165
# 44
# 220
# 359
# 84
# 90
# 511
# 581
# 58
# 376
# 103
# 14
# 101
# 73
# 518
# 221
# 3929
# 70
# 606
# 381
# 46
# 188
# 42
# 880
# 54
# 97
# 1182
# 2965
# 423
# 19
# 313
# 148
# 693
# 265
# 88
# 3259
# 1
# 21
# 144
# 246
# 156
# 91
# 59
# 3807
# 414
# 473
# 1
# 416
# 6
# 128
# 20
# 4482
# 49
# 134
# 148
# 638
# 166
# 621
# 349
# 4
# 1936
# 8
# 210
# 49
# 217
# 133
# 485
# 28
# 50
# 935
# 95
# 2
# 1

# %%
captions_dict_updated = {}
for caption_id in raw_captions_dict:
    #print(caption_id)
    caption_list = raw_captions_dict[caption_id]
    new_words_list = []
    for caption in caption_list:
        #filtered_caption = ''.join(([w for w in caption if not w in stop_words]))
        words = word_tokenize(caption.lower())
        new_words = []
        new_words.append('<START>') 
        new_words.extend([word for word in words if word in words_final])
        new_words.append('<END>')
        new_words_list.append(new_words)
    print(new_words_list)
    captions_dict_updated[int(caption_id)] = new_words_list
# Out:
# [['<START>', 'un', 'gruppo', 'di', 'persone', 'in', 'piedi', 'sul', 'retro', 'di', 'un', 'camion', 'pieno', 'di', 'cotone', '.', '<END>'], ['<START>', 'gli', 'uomini', 'sono', 'in', 'piedi', 'su', 'un', 'camion', 'che', 'trasporta', 'una', 'sostanza', 'bianca', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'persone', 'è', 'in', 'piedi', 'su', 'un', 'mucchio', 'di', 'lana', 'in', 'un', 'camion', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'uomini', 'sta', 'caricando', 'cotone', 'su', 'un', 'camion', '.', '<END>'], ['<START>', 'i', 'lavoratori', 'caricano', 'lana', 'ricamata', 'su', 'un', 'camion', '.', '<END>']]
# [['<START>', 'un', 'adulto', 'con', 'una', 'maglietta', 'grigia', 'con', 'maniche', 'rosse', 'che', 'dormiva', 'sul', 'divano', '.', '<END>'], ['<START>', 'una', 'donna', 'in', 'pantaloni', 'neri', 'appoggiata', 'sul', 'divano', '.', '<END>'], ['<START>', 'un', 'uomo', 'che', 'dormiva', 'in', 'una', 'stanza', 'verde', 'su', 'un', 'divano', '.', '<END>'], ['<START>', 'la', 'ragazza', 'sta', 'dormendo', 'nella', 'sua', 'stanza', '.', '<END>'], ['<START>', 'un', 'uomo', 'dai', 'capelli', 'lunghi', 'che', 'dormiva', 'sul', 'divano', '.', '<END>']]
# [['<START>', 'un', 'ragazzo', 'in', 'camicia', 'marrone', 'con', 'le', 'cuffie', 'sulle', 'spalle', 'si', 'siede', 'sulle', 'spalle', 'di', 'una', 'folla', '.', '<END>'], ['<START>', 'un', 'bambino', 'con', 'le', 'cuffie', 'si', 'siede', 'sulle', 'spalle', 'della', 'madre', 'in', 'una', 'folla', '.', '<END>'], ['<START>', 'un', 'ragazzo', 'con', 'le', 'cuffie', 'seduto', 'sulle', 'spalle', 'di', 'una', 'donna', '.', '<END>'], ['<START>', 'un', 'bambino', 'con', 'le', 'cuffie', 'sulle', 'spalle', 'di', 'sua', 'madre', '.', '<END>'], ['<START>', 'un', 'ragazzo', 'con', 'le', 'cuffie', 'si', 'siede', 'sulle', 'spalle', 'di', 'una', 'donna', '.', '<END>']]
# [['<START>', 'due', 'uomini', ',', 'in', 'piedi', 'sul', 'ghiaccio', ',', 'guardano', 'in', 'qualcosa', 'coperto', 'da', 'un', 'telo', 'blu', '.', '<END>'], ['<START>', 'due', 'uomini', 'stanno', 'per', 'entrare', 'in', 'una', 'tenda', 'di', 'pesca', 'sul', 'ghiaccio', 'su', 'un', 'lago', 'coperto', 'di', 'neve', '.', '<END>'], ['<START>', 'due', 'persone', 'in', 'piedi', 'fuori', 'da', 'una', 'tenda', 'blu', 'su', 'una', 'superficie', 'neve', '.', '<END>'], ['<START>', 'due', 'uomini', 'installano', 'una', 'capanna', 'di', 'pesca', 'blu', 'su', 'un', 'lago', 'ghiacciato', 'ghiacciato', '.', '<END>'], ['<START>', 'si', 'sta', 'mettendo', 'una', 'tenda', 'sul', 'ghiaccio', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'in', 'camicia', 'verde', 'e', 'giacca', 'di', 'vita', 'rossa', 'è', 'seduto', 'su', 'una', 'canoa', 'che', 'si', 'muove', 'intorno', 'al', 'lago', '.', '<END>'], ['<START>', 'un', 'uomo', 'con', 'una', 'giacca', 'di', 'salvataggio', 'è', 'in', 'una', 'piccola', 'barca', 'su', 'un', 'lago', 'con', 'un', 'traghetto', 'in', 'vista', '.', '<END>'], ['<START>', 'un', 'uomo', 'con', 'un', 'salvagente', 'rosso', 'è', 'seduto', 'su', 'una', 'canoa', 'su', 'un', 'corpo', "d'acqua", '.', '<END>'], ['<START>', 'un', 'uomo', 'calvo', 'con', 'una', 'giacca', 'rossa', 'è', 'seduto', 'su', 'una', 'piccola', 'barca', '.', '<END>'], ['<START>', 'un', 'uomo', 'con', 'un', 'salvagente', 'rosso', 'è', 'in', 'canoa', '.', '<END>']]
# [['<START>', 'una', 'donna', 'in', 'jeans', 'e', 'camicia', 'rossa', 'e', 'con', 'una', 'borsa', 'multicolore', 'si', 'mette', 'le', 'braccia', 'mentre', 'salta', 'da', 'una', 'strada', 'di', 'calcare', '.', '<END>'], ['<START>', 'una', 'donna', 'con', 'il', 'camice', 'rosso', ',', 'con', 'una', 'borsa', 'blu', 'scuro', 'probabilmente', 'di', 'discendenza', 'asiatica', ',', 'che', 'salta', 'a', 'terra', 'per', 'un', 'istante', '.', '<END>'], ['<START>', 'una', 'donna', 'in', 'giacca', 'rossa', ',', 'con', 'una', 'borsa', 'blu', 'e', 'oro', 'sta', 'saltando', 'sorridendo', 'su', 'una', 'strada', 'di', 'calcare', '.', '<END>'], ['<START>', 'una', 'donna', 'con', 'il', 'cappotto', 'rosso', 'sta', 'saltando', "all'aperto", '.', '<END>'], ['<START>', 'ragazza', 'in', 'rosso', 'che', 'salta', 'per', 'la', 'gioia', '.', '<END>']]
# [['<START>', 'due', 'cani', 'corrono', "l'uno", 'verso', "l'altro", 'in', "un'area", 'rocciosa', 'con', "l'acqua", 'sullo', 'sfondo', '.', '<END>'], ['<START>', 'un', 'cane', 'marrone', 'sta', 'correndo', 'dietro', 'a', 'un', 'cane', 'nero', 'su', 'una', 'spiaggia', 'rocciosa', '.', '<END>'], ['<START>', 'due', 'cani', 'corrono', 'sulle', 'pietre', 'vicino', 'ad', 'un', 'corpo', "d'acqua", '.', '<END>'], ['<START>', 'un', 'cane', 'marrone', 'sta', 'correndo', 'dietro', 'al', 'cane', 'nero', '.', '<END>'], ['<START>', 'due', 'cani', 'che', 'giocano', 'in', 'spiaggia', '.', '<END>']]
# [['<START>', 'un', 'giovane', 'uomo', 'con', 'il', 'casco', ',', 'nella', 'sua', 'uniforme', 'da', 'squadra', ',', 'sta', 'sbattendo', 'la', 'mazza', 'contro', 'un', 'baseball', 'in', 'arrivo', '.', '<END>'], ['<START>', 'un', 'ragazzino', 'con', 'la', 'mazza', 'dei', 'giants', 'colpisce', 'una', 'mazza', 'da', 'baseball', 'in', 'un', 'lancio', 'in', 'arrivo', '.', '<END>'], ['<START>', 'un', 'ragazzo', 'che', 'giocava', 'a', 'baseball', 'per', 'la', 'squadra', 'dei', 'giants', 'che', 'batteva', 'contro', 'un', 'baseball', '.', '<END>'], ['<START>', 'un', 'bambino', 'lancia', 'una', 'mazza', 'da', 'baseball', 'contro', 'la', 'palla', '.', '<END>'], ['<START>', 'questo', 'bambino', 'che', 'colpisce', 'una', 'palla', '.', '<END>']]
# [['<START>', 'un', 'tizio', 'seduto', 'a', 'una', 'scrivania', 'che', 'parla', 'al', 'telefono', 'con', 'libri', 'appesi', 'ovunque', '.', '<END>'], ['<START>', 'uomo', 'che', 'parla', 'al', 'telefono', ',', 'circondato', 'da', 'libri', 'in', 'ufficio', '.', '<END>'], ['<START>', 'un', 'uomo', 'siede', 'a', 'una', 'scrivania', 'in', 'una', 'stanza', 'piena', 'di', 'libri', '.', '<END>'], ['<START>', 'un', 'uomo', 'al', 'telefono', 'circondato', 'da', 'pile', 'di', 'libri', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'un', 'ufficio', 'disordinato', 'sta', 'usando', 'il', 'telefono', '.', '<END>']]
# [['<START>', 'la', 'donna', 'si', 'sta', 'godendo', 'di', 'stare', "all'aperto", 'in', 'bicicletta', 'in', 'una', 'riserva', 'di', 'foreste', '.', '<END>'], ['<START>', 'una', 'ragazza', 'in', 'cima', 'a', 'una', 'cisterna', 'arancione', 'sta', 'camminando', 'in', 'bicicletta', 'nella', 'lotta', '.', '<END>'], ['<START>', 'una', 'donna', 'sorridente', 'in', 'cima', 'a', 'una', 'cisterna', 'di', 'pesca', 'sta', 'tenendo', 'una', 'mountain', 'bike', '.', '<END>'], ['<START>', 'una', 'felice', 'adolescente', 'che', 'si', 'prende', 'una', 'pausa', 'dal', 'suo', 'giro', 'in', 'bicicletta', '.', '<END>'], ['<START>', 'una', 'ragazza', 'sorride', 'tenendo', 'la', 'sua', 'bicicletta', 'in', 'un', 'campo', '.', '<END>']]
# [['<START>', 'un', 'ragazzo', 'vestito', 'di', 'blu', 'e', 'giallo', 'cammina', 'su', 'un', 'bordo', 'di', 'una', 'scogliera', '.', '<END>'], ['<START>', 'un', 'ragazzo', 'in', 'pantaloni', 'gialli', 'è', 'in', 'cima', 'a', 'una', 'scogliera', '.', '<END>'], ['<START>', 'un', 'bambino', 'piccolo', 'sta', 'da', 'solo', 'su', 'delle', 'rocce', 'intrecciate', '.', '<END>'], ['<START>', 'un', 'ragazzino', 'in', 'piedi', 'in', 'alto', "nell'aria", 'su', 'una', 'roccia', '.', '<END>'], ['<START>', 'bambino', 'in', 'piedi', 'vicino', 'al', 'bordo', 'della', 'scogliera', '.', '<END>']]
# [['<START>', 'un', 'guidatore', 'di', 'neve', 'vola', 'in', 'aria', 'sulla', 'sua', 'macchina', 'davanti', 'a', 'alti', 'alberi', 'di', 'pini', '.', '<END>'], ['<START>', 'rider', 'salta', 'sulla', 'nevemobile', 'in', 'alto', 'nelle', 'aree', 'rurali', '.', '<END>'], ['<START>', 'una', 'persona', 'su', 'una', 'snowmobile', 'a', 'metà', 'lancio', '.', '<END>'], ['<START>', 'un', 'snowmobiler', 'vola', 'in', 'aria', '.', '<END>'], ['<START>', "l'uomo", 'è', 'in', 'aria', '.', '<END>']]
# [['<START>', 'una', 'madre', 'e', 'tre', 'bambini', 'che', 'raccolgono', 'la', 'spazzatura', 'da', 'una', 'lattina', 'bianca', 'e', 'blu', 'per', 'strada', '.', '<END>'], ['<START>', 'una', 'donna', 'e', 'tre', 'bambini', 'stanno', 'prendendo', 'qualcosa', 'dalla', 'spazzatura', 'blu', '.', '<END>'], ['<START>', 'tre', 'bambini', 'piccoli', 'stanno', 'intorno', 'a', 'un', 'barile', 'bianco', 'e', 'blu', '.', '<END>'], ['<START>', 'quattro', 'bambini', 'stanno', 'attorno', 'a', 'un', 'barile', 'bianco', 'e', 'blu', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'bambini', 'guarda', 'in', 'un', 'barile', '.', '<END>']]
# [['<START>', 'una', 'donna', 'dai', 'capelli', 'scuri', 'in', 'un', 'apron', 'verde', 'e', 'bianco', 'siede', "all'aperto", 'davanti', 'a', 'una', 'mostra', 'di', 'fiori', 'in', 'vendita', 'su', 'una', 'strada', 'della', 'città', '.', '<END>'], ['<START>', 'una', 'donna', 'è', 'seduta', 'vicino', 'alla', 'sua', 'mostra', 'di', 'fiori', 'secchi', 'in', 'un', 'mercato', 'esterno', '.', '<END>'], ['<START>', 'una', 'donna', 'vende', 'fiori', 'e', 'incensi', 'al', 'mercato', '.', '<END>'], ['<START>', 'una', 'signora', 'si', 'siede', 'tenendo', 'la', 'sua', 'posizione', '.', '<END>'], ['<START>', 'una', 'donna', 'in', 'apron', 'a', 'comprare', 'in', 'un', 'mercato', '.', '<END>']]
# [['<START>', 'c', "'", 'è', 'una', 'donna', 'e', 'un', 'uomo', 'con', 'una', 'camicia', 'arancione', 'che', 'suonano', 'strumenti', 'di', 'carta', 'davanti', 'a', 'loro', '.', '<END>'], ['<START>', 'un', 'violoncello', 'suona', 'durante', 'un', 'concerto', '.', '<END>'], ['<START>', 'una', 'donna', 'in', 'camicia', 'rossa', 'che', 'suona', 'il', 'violoncello', '.', '<END>'], ['<START>', 'una', 'donna', 'che', 'suona', 'una', 'canzone', 'al', 'suo', 'violino', '.', '<END>'], ['<START>', 'una', 'donna', 'in', 'camicia', 'rossa', 'suona', 'il', 'violoncello', '.', '<END>']]
# [['<START>', 'le', 'persone', 'su', 'atv', 'e', 'biciclette', 'sporche', 'viaggiano', 'lungo', 'un', 'sentiero', 'sporco', 'in', 'un', 'campo', 'circondato', 'da', 'alberi', '.', '<END>'], ['<START>', 'tre', 'persone', 'su', 'due', 'biciclette', 'sterrate', 'e', 'uno', 'a', 'quattro', 'ruote', 'stanno', 'guidando', 'attraverso', "l'erba", 'marrone', '.', '<END>'], ['<START>', 'tre', 'persone', 'pedalano', 'in', 'bici', 'fuori', 'strada', 'attraverso', 'un', 'campo', 'circondato', 'da', 'alberi', '.', '<END>'], ['<START>', 'tre', 'persone', 'in', 'moto', 'seguono', 'una', 'traccia', 'attraverso', "l'erba", 'secca', '.', '<END>'], ['<START>', 'tre', 'persone', 'vanno', 'in', 'giro', 'su', 'atv', 'e', 'moto', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'anziano', 'si', 'siede', 'e', 'si', 'rilassa', 'in', 'un', 'patio', 'fuori', 'da', 'un', 'edificio', 'diadobe', 'dove', 'ci', 'sono', 'molte', 'biciclette', '.', '<END>'], ['<START>', 'un', 'anziano', 'inzuppato', 'che', 'indossa', 'sciarpe', ',', 'pantaloni', 'blu', 'marina', 'e', 'cappello', 'bianco', 'reclinato', 'su', 'una', 'sedia', "all'esterno", '.', '<END>'], ['<START>', 'un', 'uomo', 'senza', 'camicia', 'in', 'cappello', 'bianco', 'si', 'rilassa', 'su', 'una', 'sedia', 'a', 'mazzo', ',', 'vicino', 'a', 'tre', 'biciclette', 'parcheggiate', '.', '<END>'], ['<START>', 'un', 'uomo', 'mezzo', 'nudo', 'sta', 'dormendo', "all'aperto", 'sulla', 'sua', 'sedia', '.', '<END>'], ['<START>', 'uomo', 'rilassato', 'su', 'una', 'sedia', 'pieghevole', 'per', 'strada', '.', '<END>']]
# [['<START>', 'un', 'gruppo', 'di', 'persone', 'sta', 'lì', 'fuori', 'ad', 'un', 'carnevale', ',', 'vicino', 'ad', 'un', 'giro', 'chiamato', 'la', 'giungla', 'verde', '.', '<END>'], ['<START>', 'una', 'folla', 'di', 'persone', 'di', 'fianco', 'a', 'una', 'baracca', 'etichettata', '``', 'giungla', 'verde', "''", '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'persone', 'davanti', 'a', 'una', 'capanna', 'in', 'un', 'parcheggio', '.', '<END>'], ['<START>', 'pubblico', 'vicino', 'alla', 'mostra', '``', 'green', 'jungle', "''", 'al', 'festival', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'persone', 'si', 'riunisce', '.', '<END>']]
# [['<START>', 'una', 'ragazzina', 'seduta', 'su', 'una', 'piccola', 'sedia', 'circondata', 'da', 'tessuti', 'e', 'sacchetti', 'fatti', 'a', 'mano', '.', '<END>'], ['<START>', 'una', 'ragazza', 'con', 'un', 'cappello', 'colorato', 'siede', 'su', 'un', 'tappeto', 'intrecciato', '.', '<END>'], ['<START>', 'una', 'giovane', 'donna', 'fa', 'tappeti', 'nella', 'foresta', 'pluviale', '.', '<END>'], ['<START>', 'una', 'donna', 'con', 'il', 'cappello', 'rosso', 'siede', 'su', 'un', 'tappeto', '.', '<END>'], ['<START>', 'una', 'donna', 'seduta', 'in', 'una', 'capanna', '.', '<END>']]
# [['<START>', 'ci', 'sono', 'tre', 'giovani', ',', 'una', 'dai', 'capelli', 'scuri', 'che', 'tiene', 'in', 'mano', 'una', 'bottiglia', ',', 'una', 'con', 'la', 'testa', 'inclinata', 'indietro', 'e', 'un', 'dito', 'in', 'bocca', ',', 'e', 'una', 'con', 'i', 'capelli', 'picchi', '.', '<END>'], ['<START>', 'tre', 'ragazze', 'fanno', 'delle', 'facce', 'mentre', 'si', 'bevono', 'in', 'una', 'strada', 'affollata', '.', '<END>'], ['<START>', 'tre', 'giovani', 'donne', 'in', 'posa', 'per', 'la', 'telecamera', 'ad', 'una', 'parata', '.', '<END>'], ['<START>', 'tre', 'donne', 'per', 'strada', 'che', 'bevono', 'e', 'si', 'posano', '<END>'], ['<START>', 'i', 'giovani', 'fanno', 'festa', 'per', 'le', 'strade', '.', '<END>']]
# [['<START>', 'un', 'gruppo', 'di', 'persone', 'si', 'riunisce', 'in', 'un', 'bar', ',', 'e', 'un', 'uomo', 'in', 'camicia', 'nera', 'tiene', 'il', 'braccio', 'e', 'segnala', 'alla', 'telecamera', '.', '<END>'], ['<START>', 'in', 'una', 'folla', 'di', 'giovani', 'al', 'bar', ',', 'un', 'uomo', 'mostra', 'il', 'cartello', 'rock', 'and', 'roll', '.', '<END>'], ['<START>', 'un', 'uomo', 'sta', 'facendo', 'un', 'gesto', 'rock', 'stando', 'su', 'un', 'piedistallo', 'in', 'un', 'bar', 'affollato', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'maglietta', 'nera', 'in', 'piedi', 'sopra', 'la', 'folla', 'in', 'un', 'bar', 'affollato', '.', '<END>'], ['<START>', 'le', 'persone', 'che', 'bevono', 'in', 'un', 'bar', 'affollato', '.', '<END>']]
# [['<START>', 'donna', 'e', 'uomo', 'che', 'attraversano', 'un', 'ponte', 'a', 'corda', 'di', 'legno', 'con', 'accanto', 'un', 'cartello', 'di', 'avvertimento', '.', '<END>'], ['<START>', 'un', 'uomo', 'e', 'una', 'donna', 'stanno', 'attraversando', 'un', 'ponte', 'a', 'corda', 'con', 'tutto', 'il', 'verde', 'sopra', 'di', 'loro', '.', '<END>'], ['<START>', 'un', 'uomo', 'e', 'una', 'donna', 'attraversano', 'un', 'ponte', 'di', 'sospensione', 'in', 'un', 'contesto', 'tropicale', '.', '<END>'], ['<START>', 'un', 'ponte', 'attraverso', 'alte', 'piante', 'verdi', ',', 'sopra', 'ci', 'sono', 'un', 'uomo', 'e', 'una', 'donna', '.', '<END>'], ['<START>', 'un', 'uomo', 'e', 'una', 'donna', 'stanno', 'attraversando', 'un', 'ponte', 'a', 'corda', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'con', 'un', 'cappotto', 'grigio', ',', 'una', 'tank', 'top', 'rosa', 'e', 'una', 'gon', 'na', 'corta', ',', 'calze', 'a', 'strisce', 'rosa', 'e', 'nera', ',', 'e', 'stivali', 'che', 'giocano', 'con', 'i', 'coltelli', 'davanti', 'ad', 'un', 'palazzo', 'di', 'mattoni', 'il', 'cui', 'cartello', 'dice', '``', 'la', 'stanza', 'della', 'spazzatura', "''", 'mentre', 'gli', 'spettatori', 'guardano', '.', '<END>'], ['<START>', 'un', 'intrattenitore', 'maschio', 'indossa', 'vestiti', 'da', 'donna', 'che', 'consistono', 'di', 'una', 'tank', 'top', 'rosa', ',', 'gon', 'na', ',', 'calze', 'da', 'ginocchio', 'alte', ',', 'e', 'una', 'tenda', 'per', 'capelli', ',', 'e', 'si', 'esibisce', 'su', 'una', 'bicicletta', 'con', 'dei', 'coltelli', 'da', 'gioco', 'mentre', 'la', 'folla', 'guarda', '.', '<END>'], ['<START>', 'un', 'uomo', ',', 'che', 'indossa', 'una', 'gon', 'na', 'rosa', 'corta', ',', 'calze', 'lunghe', 'a', 'strisce', ',', 'una', 'giacca', 'rosa', ',', 'e', 'una', 'rete', 'per', 'capelli', ',', 'gioca', 'con', 'i', 'coltelli', 'per', 'il', 'divertimento', 'degli', 'spettatori', '.', '<END>'], ['<START>', 'un', 'giocoliere', 'di', 'strada', 'che', 'si', 'esibisce', 'indossando', 'un', 'abito', 'colorato', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'gon', 'na', 'salta', 'giocando', 'con', 'i', 'coltelli', '.', '<END>']]
# [['<START>', 'donna', 'vestita', 'di', 'cappello', 'verde', 'e', 'apron', 'con', 'in', 'mano', 'un', 'vassoio', 'pieno', 'di', 'campioni', 'da', 'bere', '.', '<END>'], ['<START>', 'una', 'ragazza', 'asiatica', 'con', 'un', 'cappello', 'verde', 'e', 'un', 'apron', 'sta', 'servendo', 'da', 'bere', 'su', 'un', 'cesto', '.', '<END>'], ['<START>', 'la', 'cameriera', 'offre', 'il', 'tè', 'complimentario', 'ai', 'clienti', '.', '<END>'], ['<START>', 'una', 'ragazza', 'distribuisce', 'campioni', 'di', 'starbucks', 'ad', 'una', 'fiera', 'di', 'strada', '.', '<END>'], ['<START>', 'un', 'barista', 'di', 'starbucks', 'che', 'offre', 'una', 'tazza', 'di', 'birra', '.', '<END>']]
# [['<START>', 'gli', 'operai', 'edili', 'in', 'cima', 'a', 'un', 'macchinario', '.', '<END>'], ['<START>', 'due', 'uomini', 'spazzatura', 'in', 'piedi', 'caricano', 'la', 'spazzatura', 'su', 'un', 'camion', '.', '<END>'], ['<START>', 'una', 'foto', 'sfocata', 'di', 'un', 'uomo', 'con', 'una', 'camicia', 'blu', 'e', 'un', 'cappello', 'rigido', '.', '<END>'], ['<START>', 'un', 'uomo', 'con', 'un', 'cappello', 'bianco', 'è', 'in', 'cima', 'a', 'un', 'camion', '.', '<END>'], ['<START>', 'due', 'persone', 'sono', 'sul', 'letto', 'di', 'un', 'camion', '.', '<END>']]
# [['<START>', 'due', 'cani', 'giocano', 'sporchi', 'in', 'un', 'campo', 'verde', '.', '<END>'], ['<START>', "sull'erba", ',', 'due', 'cani', 'marroni', 'cercano', 'un', 'giocattolo', 'arancione', '.', '<END>'], ['<START>', 'due', 'cani', 'giocano', 'con', 'un', 'giocattolo', 'arancione', "nell'erba", 'alta', '.', '<END>'], ['<START>', 'due', 'grandi', 'cani', 'marroni', 'giocano', "nell'erba", '.', '<END>'], ['<START>', 'i', 'cani', 'combattono', "sull'erba", 'contro', 'i', 'giocattoli', '.', '<END>']]
# [['<START>', 'un', 'bambino', 'sul', 'pavimento', 'che', 'ride', 'di', 'un', 'altro', 'bambino', 'più', 'grande', '.', '<END>'], ['<START>', 'un', 'fratello', 'più', 'grande', 'e', 'un', 'bambino', 'in', 'salotto', '.', '<END>'], ['<START>', 'un', 'bambino', 'carino', 'sorride', 'ad', 'un', 'altro', 'bambino', '.', '<END>'], ['<START>', 'un', 'bambino', 'guarda', 'mentre', 'un', 'bambino', 'ride', '.', '<END>'], ['<START>', 'bambino', 'che', 'gioca', 'con', 'un', 'bambino', '.', '<END>']]
# [['<START>', 'tre', 'uomini', 'in', 'abiti', 'da', 'freddo', 'che', 'camminano', 'lungo', 'la', 'strada', '.', '<END>'], ['<START>', 'tre', 'uomini', 'stanno', 'camminando', 'lungo', 'una', 'strada', 'con', 'degli', 'alberi', 'ai', 'margini', '.', '<END>'], ['<START>', 'tre', 'uomini', 'che', 'camminano', 'lungo', 'una', 'strada', 'circondati', 'da', 'una', 'foresta', '.', '<END>'], ['<START>', 'tre', 'uomini', 'stanno', 'camminando', 'su', 'una', 'strada', 'sulle', 'montagne', '.', '<END>'], ['<START>', 'tre', 'uomini', 'stanno', 'camminando', 'per', 'una', 'strada', '.', '<END>']]
# [['<START>', 'qualcuno', 'che', 'salta', 'con', 'un', 'paracadute', 'verde', 'con', 'una', 'faccia', 'in', 'cima', '.', '<END>'], ['<START>', 'una', 'persona', 'sta', 'paracadutando', 'su', 'un', 'grande', 'bacino', "d'acqua", '.', '<END>'], ['<START>', 'una', 'barca', 'sta', 'trasportando', 'una', 'persona', 'con', 'un', 'paracadute', 'verde', 'brillante', '.', '<END>'], ['<START>', 'una', 'persona', 'salta', 'sul', 'paracadute', 'vicino', 'alla', 'spiaggia', '.', '<END>'], ['<START>', 'una', 'persona', 'sta', 'paracadutando', 'vicino', 'a', 'una', 'spiaggia', '.', '<END>']]
# [['<START>', 'un', 'cantiere', 'in', 'costruzione', 'sul', 'lato', 'della', 'montagna', 'con', 'un', 'bulldozer', 'che', 'scappa', 'nel', 'terreno', 'che', 'è', 'tutto', 'sporco', '.', '<END>'], ['<START>', 'un', 'trattore', 'muove', 'la', 'sporcizia', 'per', 'costruire', 'un', 'muro', 'di', 'contenimento', '.', '<END>'], ['<START>', 'un', 'veicolo', 'di', 'costruzione', 'su', 'una', 'collina', 'di', 'sporcizia', '.', '<END>'], ['<START>', 'questa', 'macchina', 'sta', 'lavorando', 'nella', 'terra', '.', '<END>'], ['<START>', 'un', 'trattore', 'giallo', 'siede', 'su', 'una', 'collina', '.', '<END>']]
# [['<START>', 'una', 'ragazza', 'in', 'pantaloni', 'scuri', 'e', 'una', 'giacca', 'blu', 'corre', "sull'erba", 'vicino', 'a', 'un', 'cono', 'arancione', 'e', 'adesivo', '.', '<END>'], ['<START>', 'una', 'giovane', 'donna', 'vestita', 'di', 'blu', 'e', 'nero', 'corre', 'accanto', 'a', 'un', 'cono', 'arancione', '.', '<END>'], ['<START>', 'una', 'giovane', 'donna', 'che', 'corre', 'a', 'bordo', 'di', 'un', 'nastro', 'arancione', '.', '<END>'], ['<START>', 'una', 'ragazza', 'che', 'corre', 'da', 'sola', 'in', 'un', 'parco', '.', '<END>'], ['<START>', 'una', 'ragazza', 'in', 'cima', 'a', 'un', 'carro', 'armato', 'blu', 'che', 'vince', 'una', 'gara', '.', '<END>']]
# [['<START>', 'un', 'liquido', 'rosso', 'viaggia', 'lungo', 'un', 'pendio', 'mentre', 'percorre', 'una', 'strada', '.', '<END>'], ['<START>', 'una', 'persona', 'attraversa', 'la', 'strada', 'e', 'evita', 'la', 'fuoriuscita', 'di', 'vernice', '.', '<END>'], ['<START>', "un'immagine", 'di', 'una', 'persona', 'che', 'attraversa', 'la', 'strada', '.', '<END>'], ['<START>', 'un', 'marciapiede', 'colorato', 'di', 'petrolio', 'con', 'accanto', 'un', 'passeggero', '.', '<END>'], ['<START>', 'una', 'persona', 'sta', 'attraversando', 'la', 'strada', '.', '<END>']]
# [['<START>', 'un', 'ragazzo', 'con', 'una', 'maglietta', 'bianca', 'sta', 'sbattendo', 'dalle', 'sbarre', 'delle', 'scimmie', '.', '<END>'], ['<START>', 'bambino', 'che', 'gioca', 'in', 'un', 'parco', 'giochi', ',', 'appeso', 'ai', 'bar', '.', '<END>'], ['<START>', 'un', 'bambino', 'che', 'urla', 'gioca', 'sulle', 'barre', 'blu', 'delle', 'scimmie', '.', '<END>'], ['<START>', 'ragazzo', 'che', 'fa', 'ginnastica', 'nella', 'giungla', 'al', 'parco', '.', '<END>'], ['<START>', 'un', 'ragazzo', 'è', 'appeso', 'alle', 'sbarre', 'delle', 'scimmie', '.', '<END>']]
# [['<START>', 'un', 'alto', 'palo', 'grigio', 'dietro', 'a', 'cui', 'una', 'persona', 'che', 'indossa', 'una', 'maglietta', 'arancione', 'è', 'appesa', 'al', 'muro', 'e', 'nasconde', 'la', 'faccia', 'con', 'una', 'mano', '.', '<END>'], ['<START>', 'una', 'persona', 'che', 'indossa', 'una', 'camicia', 'rossa', 'a', 'maniche', 'lunghe', 'è', 'sdraiata', 'su', 'un', 'muro', 'davanti', 'ad', 'un', 'lampadario', 'in', 'un', 'modo', 'molto', 'insolito', '.', '<END>'], ['<START>', 'un', 'uomo', 'con', 'un', 'maglione', 'arancione', 'e', 'dei', 'pantaloni', 'scuri', 'giace', 'su', 'un', 'muro', 'bianco', 'vicino', 'ad', 'una', 'lampada', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'camicia', 'arancione', 'sta', 'giacendo', 'raggomitolato', 'su', 'un', 'precipizio', 'di', 'cemento', 'dietro', 'un', 'palo', '.', '<END>'], ['<START>', 'una', 'persona', 'con', 'una', 'camicia', 'rossa', 'a', 'maniche', 'lunghe', 'che', 'giace', 'su', 'un', 'bordo', '.', '<END>']]
# [['<START>', 'un', 'bambino', 'sta', 'tirando', 'un', 'uomo', 'che', 'cerca', 'di', 'fargli', 'fare', 'qualcosa', 'di', 'fronte', 'a', 'una', 'folla', 'di', 'persone', '.', '<END>'], ['<START>', 'una', 'grande', 'folla', 'di', 'persone', 'circonda', 'un', 'bambino', 'che', 'indossa', 'un', 'cappello', 'e', 'un', 'uomo', 'che', 'indossa', 'un', 'abito', '.', '<END>'], ['<START>', 'una', 'folla', 'di', 'persone', 'sta', 'guardando', 'un', 'bambino', 'e', 'un', 'uomo', 'lottare', 'per', 'un', 'caso', '.', '<END>'], ['<START>', 'un', 'uomo', 'e', 'un', 'ragazzo', 'afferrano', 'un', 'piccolo', 'sacchetto', 'nero', 'con', 'le', 'braccia', 'strette', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'persone', 'si', 'riunisce', 'intorno', 'ad', 'un', 'uomo', 'in', 'abito', 'e', 'a', 'un', 'bambino', '.', '<END>']]
# [['<START>', "c'erano", 'molte', 'persone', 'in', 'una', 'stanza', 'buia', 'come', 'un', 'bar', ',', 'compresa', 'una', 'ragazza', 'su', 'un', 'tavolo', '.', '<END>'], ['<START>', 'una', 'ragazza', 'seduta', 'in', 'un', 'bar', 'buio', '.', '<END>'], ['<START>', 'un', 'nightclub', 'buio', 'con', 'sedie', '.', '<END>'], ['<START>', 'una', 'ragazza', 'siede', 'su', 'un', 'tavolo', 'da', 'bar', '.', '<END>'], ['<START>', 'una', 'donna', 'siede', 'in', 'un', 'bar', 'buio', '.', '<END>']]
# [['<START>', 'i', 'pastori', 'camminano', 'in', "un'area", 'aperta', 'tra', 'diversi', 'edifici', 'tradizionali', 'giapponesi', 'o', 'cinesi', '.', '<END>'], ['<START>', "un'area", 'in', 'giappone', 'che', 'sembra', 'essere', 'estremamente', 'affollata', ',', 'con', 'molte', 'persone', 'che', 'sembrano', 'turisti', '.', '<END>'], ['<START>', 'molte', 'persone', 'camminano', 'in', 'una', 'piazza', 'con', 'edifici', 'di', 'architettura', 'asiatica', '.', '<END>'], ['<START>', 'la', 'gente', 'cammina', 'sul', 'marciapiede', 'dove', 'c', "'", 'è', 'un', 'mercato', "all'aperto", '.', '<END>'], ['<START>', 'una', 'folla', 'di', 'persone', 'riempie', 'una', 'piazza', 'di', 'fronte', 'a', 'una', 'pagoda', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'con', 'uno', 'zaino', 'blu', ',', 'che', 'legge', 'il', 'giornale', ',', 'e', 'una', 'donna', 'con', 'il', 'camice', 'nero', 'aspettano', 'il', 'treno', '.', '<END>'], ['<START>', 'un', 'uomo', 'con', 'uno', 'zaino', 'blu', 'legge', 'il', 'giornale', 'mentre', 'aspetta', 'di', 'salire', 'sulla', 'metropolitana', '.', '<END>'], ['<START>', 'un', 'uomo', 'legge', 'il', 'giornale', 'mentre', 'aspetta', 'la', 'metropolitana', '.', '<END>'], ['<START>', 'un', 'uomo', 'che', 'legge', 'il', 'giornale', 'in', 'attesa', 'di', 'salire', 'in', 'metropolitana', '.', '<END>'], ['<START>', 'un', 'uomo', 'che', 'legge', 'un', 'giornale', 'vicino', 'ad', 'un', 'treno', '.', '<END>']]
# [['<START>', 'cane', 'marrone', "sull'erba", ',', 'che', 'spruzza', 'acqua', 'dal', 'lato', 'sinistro', 'della', 'foto', '.', '<END>'], ['<START>', 'un', 'cane', 'marrone', 'si', 'sta', 'piegando', 'cercando', 'di', 'bere', 'da', 'un', 'getto', "d'acqua", '.', '<END>'], ['<START>', 'un', 'grosso', 'cane', 'marrone', 'gli', 'sta', 'attaccando', 'la', 'faccia', "nell'erogatore", '.', '<END>'], ['<START>', 'un', 'cane', 'marrone', 'annusa', "l'acqua", 'di', 'un', 'irrigatore', "sull'erba", '.', '<END>'], ['<START>', 'un', 'cane', 'che', 'beve', 'da', 'una', 'sorgente', '.', '<END>']]
# [['<START>', 'un', 'ragazzo', 'biondo', 'in', 'una', 'maglietta', 'blu', 'sta', 'sorridendo', 'davanti', 'a', 'una', 'fabbrica', 'di', 'tessuto', 'di', 'nylon', 'verde', '.', '<END>'], ['<START>', 'un', 'ragazzo', 'con', 'gli', 'occhiali', 'da', 'nuoto', 'indossa', 'una', 'maglietta', 'blu', 'con', 'un', 'cranio', 'di', 'pirata', '.', '<END>'], ['<START>', 'un', 'bambino', 'in', 'posa', 'con', 'gli', 'occhiali', 'vicino', "all'acqua", 'fuori', '.', '<END>'], ['<START>', 'una', 'bambina', 'sorridente', 'in', 'spiaggia', '.', '<END>'], ['<START>', 'un', 'ragazzino', 'in', 'spiaggia', '.', '<END>']]
# [['<START>', 'qui', 'c', "'", 'è', 'un', 'ragazzino', 'il', 'cui', 'comportamento', 'cooperativo', 'è', 'quello', 'di', 'pulire', "l'area", 'del', 'portico', 'esterno', 'con', 'una', 'grande', 'spazzola', 'sul', 'portico', 'anteriore', 'che', 'ha', 'un', 'forte', 'ringhiera', '.', '<END>'], ['<START>', 'un', 'ragazzino', 'sta', 'spazzando', 'via', 'il', 'ponte', 'di', 'legno', 'dietro', 'una', 'casa', 'con', 'una', 'spazzatura', 'di', 'grandezzatura', ';', 'dietro', 'c', "'", 'è', 'una', 'foresta', 'selvaggia', '.', '<END>'], ['<START>', 'un', 'ragazzino', 'si', 'diverte', 'a', 'spazzare', 'le', 'foglie', 'del', 'mazzo', 'di', 'carte', '.', '<END>'], ['<START>', 'un', 'giovane', 'maschio', 'bianco', 'sta', 'spazzolando', 'un', 'portico', 'con', 'una', 'grande', 'spazzola', '.', '<END>'], ['<START>', 'bambino', 'con', 'la', 'spazzatura', 'spazza', 'un', 'mazzolino', 'in', 'una', 'zona', 'di', 'boschi', '.', '<END>']]
# [['<START>', 'una', 'persona', 'nel', 'mezzo', 'di', 'lanciare', 'una', 'palla', 'da', 'bowling', 'verde', 'lungo', 'una', 'corsia', 'di', 'bowling', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'camicia', 'abbronzata', 'che', 'sta', 'per', 'mandare', 'giù', 'una', 'palla', 'da', 'bowling', 'verde', '.', '<END>'], ['<START>', 'un', 'uomo', 'lancia', 'da', 'solo', 'con', 'una', 'palla', 'verde', '.', '<END>'], ['<START>', 'un', 'tizio', 'che', 'lancia', 'una', 'palla', 'da', 'bowling', 'verde', '.', '<END>'], ['<START>', 'un', 'uomo', 'lancia', 'una', 'palla', 'da', 'bowling', 'verde', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'è', 'sul', 'palco', 'a', 'cantare', 'e', 'tre', 'persone', 'suonano', 'la', 'chitarra', 'di', 'fronte', 'a', 'una', 'folla', '.', '<END>'], ['<START>', 'un', 'gruppo', 'che', 'canta', 'e', 'suona', 'la', 'chitarra', 'elettrica', 'per', 'una', 'folla', 'di', 'persone', '.', '<END>'], ['<START>', 'le', 'persone', 'sono', 'sul', 'palco', 'che', 'suonano', 'a', 'un', 'gruppo', 'di', 'persone', '.', '<END>'], ['<START>', 'un', 'gruppo', 'suona', 'uno', 'spettacolo', 'rock', 'al', 'pubblico', 'di', 'un', 'bar', '.', '<END>'], ['<START>', 'un', 'gruppo', 'che', 'si', 'esibisce', 'in', 'un', 'bar', 'o', 'in', 'un', 'club', 'locale', '.', '<END>']]
# [['<START>', 'un', 'anziano', 'con', 'una', 'macchina', 'fotografica', 'mentre', 'cammina', 'un', 'cane', 'marrone', '.', '<END>'], ['<START>', 'un', 'anziano', 'sta', 'camminando', 'con', 'un', 'cane', 'marrone', 'usando', 'un', 'cane', 'rosso', '.', '<END>'], ['<START>', 'un', 'anziano', 'porta', 'il', 'suo', 'cane', 'a', 'fare', 'una', 'passeggiata', 'vicino', "all'acqua", '.', '<END>'], ['<START>', 'un', 'uomo', 'e', 'un', 'cane', 'sono', 'in', 'piedi', 'su', 'una', 'collina', 'che', 'domina', "l'acqua", '.', '<END>'], ['<START>', 'un', 'uomo', 'porta', 'il', 'suo', 'cane', 'vicino', "all'oceano", '.', '<END>']]
# [['<START>', 'una', 'macchina', 'rossa', 'segnata', 'con', 'il', 'numero', 'sette', 'è', 'guidata', 'da', 'un', 'uomo', 'in', 'maglietta', 'blu', 'e', 'beige', '.', '<END>'], ['<START>', "l'auto", 'rossa', 'ha', 'il', 'numero', 'sette', 'sul', 'lato', 'in', 'un', 'cerchio', 'bianco', '.', '<END>'], ['<START>', "l'uomo", 'guida', 'una', 'piccola', 'macchina', 'rossa', 'da', 'corsa', 'intorno', 'a', 'un', 'circuito', '.', '<END>'], ['<START>', 'un', 'uomo', 'guida', 'una', 'vecchia', 'auto', 'da', 'corsa', 'rossa', '.', '<END>'], ['<START>', 'uomo', 'che', 'guida', "l'auto", 'da', 'corsa', 'numero', '7', '.', '<END>']]
# [['<START>', 'un', 'gruppo', 'di', 'bambini', 'che', 'sono', 'seduti', 'o', 'in', 'fila', ',', 'mentre', 'due', 'hanno', 'in', 'mano', 'un', 'oggetto', 'rotondo', '.', '<END>'], ['<START>', 'giovani', 'adulti', 'che', 'indossano', 'magliette', 'rosse', ',', 'gialle', 'e', 'nere', 'in', 'linea', 'retta', 'fanno', 'uno', 'schizzo', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'bambini', 'balla', 'e', 'suona', 'strumenti', 'sotto', 'luci', 'colorate', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'ragazzi', 'che', 'fanno', 'una', 'performance', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'persone', 'sul', 'palco', '<END>']]
# [['<START>', 'un', 'bambino', 'sta', 'gettando', 'una', 'grande', 'roccia', 'in', 'un', 'corpo', "d'acqua", '.', '<END>'], ['<START>', 'un', 'ragazzo', 'lancia', 'una', 'grande', 'roccia', 'in', 'un', 'corpo', "d'acqua", '.', '<END>'], ['<START>', 'un', 'ragazzo', 'in', 'maglietta', 'blu', 'che', 'getta', 'una', 'roccia', 'in', 'acqua', '.', '<END>'], ['<START>', 'un', 'ragazzo', 'che', 'getta', 'una', 'pietra', "nell'acqua", 'calma', '.', '<END>'], ['<START>', 'bambino', 'lancia', 'una', 'roccia', "nell'acqua", '.', '<END>']]
# [['<START>', 'una', 'donna', 'bionda', 'è', 'in', 'cucina', 'con', 'un', 'coltello', 'e', 'dei', 'graham', 'crackers', 'mentre', 'fa', 'una', 'torta', 'con', 'fragole', 'e', 'mirtilli', '.', '<END>'], ['<START>', 'due', 'donne', 'con', 'i', 'capelli', 'corti', 'si', 'stanno', 'guardando', 'e', 'quella', 'bionda', 'sta', 'parlando', '.', '<END>'], ['<START>', 'due', 'donne', ',', 'una', 'delle', 'quali', 'sta', 'pulendo', 'il', 'coltello', ',', 'stanno', 'parlando', 'in', 'cucina', '.', '<END>'], ['<START>', 'due', 'donne', 'in', 'magliette', 'bianche', ',', 'una', 'con', 'un', 'coltello', 'che', 'taglia', 'un', 'pasto', '.', '<END>'], ['<START>', 'donna', 'in', 'cima', 'bianca', 'chatta', 'mentre', 'taglia', 'il', 'pane', '.', '<END>']]
# [['<START>', 'due', 'persone', 'indossano', 'un', 'costume', 'di', 'drago', 'cinese', 'di', 'fronte', 'a', 'uno', 'gazebo', 'cinese', 'ornato', 'con', 'pilastri', 'rossi', 'e', 'lo', 'gazebo', 'ha', 'due', 'grandi', 'lanterna', 'rosse', 'appese', 'al', 'tetto', '.', '<END>'], ['<START>', 'due', 'persone', 'con', 'il', 'tradizionale', 'costume', 'di', 'dragone', 'giapponese', 'si', 'esibiscono', 'di', 'fronte', 'a', 'un', 'piccolo', 'santuario', 'giapponese', 'con', 'un', 'uomo', 'in', 'abito', 'da', 'lavoro', 'che', 'guarda', 'in', 'fondo', '.', '<END>'], ['<START>', 'una', 'figura', 'elaborata', 'costumata', 'si', 'trova', 'di', 'fronte', 'a', 'una', 'struttura', 'brillantemente', 'decorata', '.', '<END>'], ['<START>', 'un', 'costume', 'rosso', 'di', 'drago', 'cinese', 'si', 'trova', 'di', 'fronte', 'a', 'uno', 'gazebo', 'asiatico', '.', '<END>'], ['<START>', 'un', 'dragone', 'cinese', 'sta', 'camminando', 'di', 'fronte', 'ad', 'un', 'edificio', '.', '<END>']]
# [['<START>', 'un', 'cane', 'che', 'cammina', 'attraverso', 'un', 'ruscello', 'con', 'un', 'asciugamano', 'bianco', 'in', 'bocca', '.', '<END>'], ['<START>', 'un', 'cane', 'che', 'cammina', 'in', 'un', 'piccolo', 'ruscello', 'con', 'una', 'ragnatela', 'in', 'bocca', '.', '<END>'], ['<START>', 'un', 'cane', 'trascina', 'una', 'ragnatela', 'bianca', 'attraverso', 'una', 'cresta', 'quasi', 'prosciugata', '.', '<END>'], ['<START>', 'un', 'cane', 'sta', 'nuotando', 'in', 'un', 'fiume', 'con', 'una', 'salvietta', 'in', 'bocca', '.', '<END>'], ['<START>', 'un', 'cane', 'nero', 'prende', 'un', 'tessuto', 'da', 'un', 'ruscello', '.', '<END>']]
# [['<START>', 'tre', 'cani', 'piccoli', ',', 'due', 'bianchi', 'e', 'uno', 'nero', 'e', 'bianco', ',', 'su', 'un', 'marciapiede', '.', '<END>'], ['<START>', 'due', 'cani', 'bianchi', 'guardano', 'un', 'cane', 'nero', 'su', 'un', 'sentiero', 'asfaltato', '.', '<END>'], ['<START>', 'tre', 'cani', 'che', 'guardano', 'un', 'bordo', 'di', 'cemento', '.', '<END>'], ['<START>', 'tre', 'piccoli', 'cani', 'annusano', 'qualcosa', '.', '<END>'], ['<START>', 'tre', 'cani', 'sul', 'marciapiede', '.', '<END>']]
# [['<START>', 'un', 'grande', 'uomo', 'siede', 'sul', 'fondo', 'di', 'una', 'canoa', 'con', 'un', 'altro', 'uomo', 'davanti', 'a', 'un', 'fiume', '.', '<END>'], ['<START>', 'due', 'uomini', 'stanno', 'nuotando', 'in', 'kayak', 'lungo', 'un', 'fiume', 'con', 'alberi', 'verdi', 'da', 'entrambi', 'i', 'lati', '.', '<END>'], ['<START>', 'due', 'pattinatori', 'spingono', 'una', 'canoa', 'giù', 'in', 'un', 'ruscello', 'lungo', 'gli', 'alberi', '.', '<END>'], ['<START>', 'due', 'uomini', 'che', 'nuotano', 'su', 'una', 'canoa', 'in', 'un', 'fiume', 'stretto', '.', '<END>'], ['<START>', 'due', 'uomini', 'in', 'una', 'piccola', 'barca', 'che', 'nuotano', 'lungo', 'un', 'fiume', '.', '<END>']]
# [['<START>', 'due', 'ragazze', 'di', 'fronte', 'hanno', 'un', 'sacchetto', 'con', 'il', 'cranio', 'che', 'indossa', 'una', 'maglietta', 'rossa', 'e', 'nera', ',', "l'altra", 'indossa', 'una', 'cintura', 'a', 'perline', '.', '<END>'], ['<START>', 'una', 'ragazza', 'con', 'capelli', 'rosa', 'stracciati', 'e', 'guanti', 'di', 'pelliccia', 'le', 'guarda', 'indietro', 'mentre', 'la', 'ragazza', 'che', 'le', 'cammina', 'accanto', 'la', 'guarda', '.', '<END>'], ['<START>', 'due', 'ragazze', 'che', 'indossano', 'vestiti', 'alla', 'moda', 'mentre', 'una', 'guarda', 'la', 'telecamera', '.', '<END>'], ['<START>', 'due', 'ragazze', 'che', 'indossano', 'abiti', 'da', 'bagno', '.', '<END>'], ['<START>', 'due', 'ragazze', 'che', 'camminano', 'per', 'strada', '.', '<END>']]
# [['<START>', 'un', 'gruppo', 'di', 'quattro', 'ragazze', 'è', 'sul', 'retro', 'di', 'un', 'veicolo', 'e', 'guarda', 'un', 'libro', 'con', 'la', 'copertina', 'rosa', '.', '<END>'], ['<START>', 'quattro', 'ragazze', 'che', 'leggono', 'un', 'libro', 'sul', 'retro', 'di', "un'auto", 'con', 'scatole', 'di', 'prodotti', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'bambini', 'seduti', 'nel', 'retro', 'di', 'un', 'furgone', 'insieme', 'a', 'guardare', 'un', 'libro', '.', '<END>'], ['<START>', 'molte', 'ragazze', 'sono', 'sedute', 'in', 'un', 'minivan', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'ragazze', 'guarda', 'un', 'libro', '.', '<END>']]
# [['<START>', 'la', 'gente', 'sulla', 'spiaggia', 'guarda', 'al', 'cielo', 'per', 'vedere', 'un', 'grande', 'cuore', 'scritto', 'in', 'aria', 'al', 'contrario', 'di', 'un', 'aereo', '.', '<END>'], ['<START>', 'mentre', 'molti', 'si', 'radunano', 'sulla', 'spiaggia', 'per', 'assistere', 'allo', 'spettacolo', 'aereo', ',', 'gli', 'aerei', 'creano', 'un', 'cuore', 'nel', 'cielo', '.', '<END>'], ['<START>', 'persone', 'sulla', 'sabbia', 'che', 'guardano', 'un', 'cuore', 'bianco', 'disegnato', 'da', 'un', 'getto', 'nel', 'cielo', 'blu', '.', '<END>'], ['<START>', "l'osservatore", 'del', 'deserto', 'guardava', 'la', 'nuvola', 'a', 'forma', 'di', 'cuore', 'nel', 'cielo', 'blu', 'chiaro', '.', '<END>'], ['<START>', 'gli', 'amanti', 'della', 'spiaggia', 'guardano', 'un', 'cuore', 'rimasto', 'nel', 'cielo', 'da', 'uno', 'scrittore', 'di', 'cielo', '.', '<END>']]
# [['<START>', 'una', 'donna', 'in', 'giacca', 'bianca', 'e', 'pantaloni', 'rosa', 'si', 'siede', ',', 'legge', 'un', 'libro', 'con', 'la', 'testa', 'appesa', 'alla', 'destra', '.', '<END>'], ['<START>', 'seduto', 'casualmente', 'in', 'un', 'posto', 'pubblico', ',', 'una', 'ragazza', 'legge', 'tenendo', 'aperto', 'il', 'libro', 'con', 'la', 'mano', 'sul', 'quale', 'c', "'", 'è', 'un', 'anello', 'di', 'farfalle', '.', '<END>'], ['<START>', 'una', 'donna', 'è', 'seduta', 'su', 'una', 'sedia', 'a', 'leggere', 'un', 'libro', 'con', 'la', 'testa', 'appoggiata', 'sulla', 'mano', 'libera', '.', '<END>'], ['<START>', 'una', 'donna', 'con', 'una', 'giacca', 'bianca', 'e', 'un', 'anello', 'di', 'farfalle', 'argentato', ',', 'aspetta', 'e', 'legge', 'un', 'libro', '.', '<END>'], ['<START>', 'donna', 'in', 'maglione', 'bianco', 'che', 'legge', 'intenzionalmente', 'seduta', 'su', 'una', 'panchina', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'con', 'i', 'capelli', 'scuri', 'indossa', 'una', 'camicia', 'bianca', 'con', 'fiamme', 'stampate', 'e', 'tiene', 'un', 'paio', 'di', 'pinze', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'una', 'maglietta', 'colorata', 'sta', 'versando', 'su', 'qualcosa', 'quello', 'che', 'sembra', 'essere', 'una', 'salsa', 'barbecue', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'camicia', 'a', 'tema', 'fiamma', 'sta', 'guardando', 'strumenti', 'da', 'barbecue', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'un', 'ristorante', 'che', 'pranza', '.', '<END>'], ['<START>', 'un', 'anziano', 'prende', 'un', 'barbecue', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'in', 'camicia', 'blu', 'e', 'camicia', 'sportiva', 'marrone', 'regola', 'qualcosa', 'che', 'ha', 'in', 'mano', '.', '<END>'], ['<START>', 'un', 'uomo', 'anziano', 'con', 'gli', 'occhiali', 'alza', 'le', 'sopracciglia', 'con', 'sorpresa', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'abito', 'e', 'vetro', 'ha', 'un', 'oggetto', 'nelle', 'mani', '.', '<END>'], ['<START>', 'gente', 'con', 'gli', 'occhiali', 'che', 'indossa', 'un', 'microfono', '.', '<END>'], ['<START>', 'un', 'uomo', 'anziano', 'con', 'gli', 'occhiali', 'sembra', 'sorpreso', '.', '<END>']]
# [['<START>', 'il', 'ragazzo', 'in', 'muta', 'nera', 'guida', "un'onda", 'con', 'una', 'tavola', 'da', 'surf', 'bianca', '.', '<END>'], ['<START>', 'un', 'uomo', 'sta', 'facendo', 'surf', 'con', 'la', 'muta', 'e', 'sta', 'uscendo', 'dalla', 'curva', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'mutande', 'cattura', "un'onda", 'sulla', 'sua', 'tavola', 'da', 'surf', 'bianca', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'muta', 'nera', 'surfa', 'su', 'una', 'tavola', 'bianca', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'muta', 'nera', 'sta', 'surfando', 'su', "un'onda", '.', '<END>']]
# [['<START>', 'una', 'donna', 'asiatica', 'seduta', 'su', 'una', 'panchina', 'che', 'passa', 'attraverso', 'un', 'portatile', 'rosa', '.', '<END>'], ['<START>', 'una', 'donna', 'asiatica', 'si', 'siede', 'su', 'una', 'panchina', 'con', 'dei', 'sacchetti', '.', '<END>'], ['<START>', 'una', 'donna', 'in', 'camicia', 'blu', 'sta', 'portando', 'una', 'borsa', 'rosa', '.', '<END>'], ['<START>', 'una', 'giovane', 'donna', 'in', 'maglietta', 'blu', 'seduta', 'su', 'una', 'panchina', '.', '<END>'], ['<START>', 'una', 'donna', 'con', 'una', 'borsa', 'rosa', 'è', 'seduta', 'su', 'una', 'panchina', '.', '<END>']]
# [['<START>', 'una', 'donna', 'con', 'una', 'camicia', 'a', 'strisce', 'siede', 'tra', 'le', 'altre', 'donne', '.', '<END>'], ['<START>', 'quattro', 'donne', 'siedono', 'e', 'guardano', 'qualcosa', 'oltre', 'la', 'telecamera', '.', '<END>'], ['<START>', 'tre', 'donne', 'asiatiche', 'più', 'anziane', 'sono', 'sedute', 'a', 'terra', '.', '<END>'], ['<START>', 'le', 'donne', 'asiatiche', 'sedute', 'in', 'giro', 'si', 'divertono', '.', '<END>'], ['<START>', 'tre', 'donne', 'sorridono', 'e', 'si', 'siedono', '.', '<END>']]
# [['<START>', 'una', 'plne', 'rossa', 'sta', 'volando', 'vicino', 'alla', 'regina', 'elisabeth', '2', 'che', 'spara', 'fumo', 'rosso', '.', '<END>'], ['<START>', 'un', 'aereo', 'rosso', 'che', 'vola', 'sopra', 'una', 'barca', 'mentre', 'traccia', 'fumo', 'rosa', '.', '<END>'], ['<START>', 'un', 'aereo', 'rosso', 'è', 'sorvolato', 'da', 'una', 'grande', 'nave', '.', '<END>'], ['<START>', 'un', 'aereo', 'vola', 'sopra', 'una', 'grande', 'nave', 'da', 'crociera', '.', '<END>'], ['<START>', 'un', 'aereo', 'rosso', 'che', 'vola', 'sopra', 'una', 'nave', 'da', 'crociera', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'in', 'camicia', 'bianca', 'e', 'casco', 'usa', "l'attrezzatura", 'da', 'arrampicata', '.', '<END>'], ['<START>', 'un', 'uomo', 'con', 'una', 'camicia', 'bianca', 'e', 'un', 'casco', 'sta', 'scalando', 'una', 'montagna', '.', '<END>'], ['<START>', 'un', 'ragazzo', 'con', 'un', 'casco', 'bianco', 'che', 'si', 'arrampica', 'su', 'un', 'muro', 'di', 'roccia', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'carro', 'armato', 'che', 'si', 'arrampica', 'contro', 'un', 'muro', 'di', 'roccia', '.', '<END>'], ['<START>', 'uomo', 'che', 'fa', 'arrampicata', 'guardando', 'la', 'roccia', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'in', 'camicia', 'arancione', 'e', 'cappello', 'rigido', 'bianco', 'si', 'trova', 'di', 'fronte', 'a', 'un', 'veicolo', 'di', 'costruzione', 'arancione', 'mentre', 'scarica', 'la', 'terra', 'in', 'un', 'camion', '.', '<END>'], ['<START>', 'due', 'operai', 'edili', 'aiutano', 'a', 'caricare', 'un', 'camion', 'di', 'spazzatura', 'in', 'un', 'cantiere', 'edile', 'urbano', '.', '<END>'], ['<START>', 'un', 'operaio', 'edile', "dall'aspetto", 'noioso', 'sta', 'tenendo', 'da', 'bere', '.', '<END>'], ['<START>', 'due', 'uomini', 'che', 'lavorano', 'insieme', 'in', 'un', 'cantiere', '.', '<END>'], ['<START>', 'due', 'uomini', 'lavorano', 'sodo', 'caricando', 'un', 'camion', 'a', 'terra', '.', '<END>']]
# [['<START>', 'un', 'camion', 'pieno', 'di', 'bottiglie', 'da', '5', 'galloni', 'sul', 'retro', 'e', 'un', 'uomo', 'in', 'cima', 'che', 'le', 'guarda', '.', '<END>'], ['<START>', 'una', 'donna', 'vestita', 'di', 'colori', 'sta', 'camminando', 'vicino', 'a', 'un', 'camion', 'bianco', 'pieno', 'di', 'bottiglie', '.', '<END>'], ['<START>', "quest'uomo", ',', 'con', 'una', 'maglietta', 'rossa', 'e', 'white', 'ha', 'dei', 'bollitori', "d'acqua", 'su', 'questo', 'furgone', 'bianco', '.', '<END>'], ['<START>', 'un', 'operaio', 'è', 'nella', 'gabbia', 'in', 'cima', 'al', 'camion', 'in', 'una', 'strada', 'affollata', '.', '<END>'], ['<START>', 'un', 'vecchio', 'camion', 'picchiato', 'nel', 'cuore', 'di', 'una', 'città', 'vivace', '.', '<END>']]
# [['<START>', 'una', 'donna', 'con', 'un', 'cappello', 'bianco', ',', 'un', 'capo', 'bianco', ',', 'e', 'una', 'gon', 'na', 'arancione', 'sta', 'saltando', 'davanti', 'ad', 'alcuni', 'alberi', '.', '<END>'], ['<START>', 'donna', 'vestita', 'di', 'sandali', ',', 'gon', 'na', 'e', 'cappello', 'che', 'salta', 'di', 'fronte', 'a', 'un', 'cespuglio', 'di', 'lilac', 'in', 'fiore', '.', '<END>'], ['<START>', 'una', 'donna', 'con', 'un', 'cappello', 'blu', 'e', 'una', 'gon', 'na', 'gialla', 'sta', 'saltando', 'in', "un'area", 'piena', 'di', 'lilac', '.', '<END>'], ['<START>', 'una', 'donna', 'con', 'una', 'camicia', 'gialla', 'sta', 'saltando', 'in', 'aria', 'in', 'un', 'parco', '.', '<END>'], ['<START>', 'una', 'donna', 'balla', 'di', 'fronte', 'a', 'un', 'cespuglio', '.', '<END>']]
# [['<START>', 'nel', 'mezzo', 'di', 'un', 'centro', 'commerciale', ',', 'c', "'", 'è', 'un', 'uomo', 'dipinto', "d'oro", 'con', 'una', 'bicicletta', "d'oro", '.', '<END>'], ['<START>', 'un', 'uomo', 'vestito', "d'oro", 'con', 'la', 'sua', 'bici', "d'oro", 'si', 'ferma', 'per', 'guardare', 'la', 'città', '.', '<END>'], ['<START>', 'un', 'uomo', 'indossa', 'un', 'abito', "d'oro", 'mentre', 'sta', 'in', 'piedi', 'con', 'la', 'sua', 'bici', "d'oro", '.', '<END>'], ['<START>', 'un', 'uomo', 'dipinto', "d'oro", 'con', 'dei', 'marciapiedi', 'per', 'strada', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'camicia', "d'oro", 'ha', 'una', 'bicicletta', "d'oro", 'in', 'città', '.', '<END>']]
# [['<START>', 'un', 'bambino', 'con', 'un', 'maglione', 'rosa', 'guarda', 'un', 'ramo', 'di', 'foglia', '.', '<END>'], ['<START>', 'una', 'bambina', 'che', 'guarda', 'un', 'ramo', 'di', 'foglie', 'sopra', 'la', 'testa', '.', '<END>'], ['<START>', 'bambino', 'che', 'guarda', 'le', 'foglie', 'di', 'un', 'ramo', 'di', 'un', 'albero', '.', '<END>'], ['<START>', 'un', 'bambino', "all'esterno", 'che', 'guarda', 'una', 'leave', '.', '<END>'], ['<START>', 'un', 'bambino', 'guarda', 'un', 'ramo', 'di', 'foglia', '.', '<END>']]
# [['<START>', 'due', 'operai', 'in', 'una', 'stazione', 'ferroviaria', 'stanno', 'pulendo', 'un', 'ascensore', '.', '<END>'], ['<START>', 'un', 'custode', 'sta', 'parlando', 'con', 'un', 'altro', 'uomo', 'con', 'un', 'ascensore', '.', '<END>'], ['<START>', 'due', 'uomini', 'sono', 'in', 'una', 'stazione', 'della', 'metropolitana', 'e', 'si', 'preparano', 'a', 'pulire', '.', '<END>'], ['<START>', 'un', 'custode', 'che', 'sta', 'per', 'pulire', 'una', 'stazione', 'del', 'treno', '.', '<END>'], ['<START>', "l'equipaggio", 'janitoriale', 'in', 'una', 'stazione', 'metro', '.', '<END>']]
# [['<START>', 'due', 'ragazzi', 'africani', 'a', 'piedi', 'nudi', 'in', 'vestiti', 'dai', 'colori', 'brillanti', 'sono', 'seduti', 'su', 'un', 'pavimento', 'di', 'pietra', ',', 'uno', 'tiene', 'in', 'mano', 'una', 'bottiglia', "d'acqua", 'chiara', 'con', 'un', 'secondo', ',', 'una', 'bottiglia', 'blu', 'tra', 'le', 'gambe', '.', '<END>'], ['<START>', 'due', 'bambini', 'africani', 'pieni', 'di', 'brillanti', 'vestiti', 'con', 'bottiglie', "d'acqua", 'sono', 'seduti', 'su', 'un', 'pavimento', 'di', 'pietra', '.', '<END>'], ['<START>', 'due', 'ragazzi', 'neri', 'giocano', 'con', 'le', 'bottiglie', 'di', 'plastica', 'e', 'si', 'divertono', 'un', 'sacco', '.', '<END>'], ['<START>', 'due', 'ragazzi', 'neri', 'siedono', 'sul', 'pavimento', 'con', 'delle', 'bottiglie', "d'acqua", '.', '<END>'], ['<START>', 'due', 'bambini', 'afroamericani', 'che', 'giocano', 'con', 'le', 'bottiglie', "d'acqua", '.', '<END>']]
# [['<START>', 'molte', 'persone', 'si', 'divertono', 'e', 'ammirano', 'moto', 'parcheggiate', 'ad', 'un', 'evento', "all'aperto", '.', '<END>'], ['<START>', 'i', 'segnali', 'stradali', 'verdi', 'si', 'accendono', 'quando', 'la', 'gente', 'guarda', 'le', 'moto', '.', '<END>'], ['<START>', 'le', 'moto', 'sono', 'parcheggiate', 'dietro', 'una', 'recinzione', 'su', 'una', 'strada', 'affollata', '.', '<END>'], ['<START>', 'la', 'gente', 'guarda', 'in', 'un', 'parcheggio', 'pieno', 'di', 'moto', '.', '<END>'], ['<START>', 'le', 'persone', 'si', 'riuniscono', 'ad', 'un', 'evento', 'in', 'città', '.', '<END>']]
# ...
# [['<START>', 'una', 'coppia', 'asiatica', 'che', 'si', 'esibisce', 'in', 'strada', 'indossando', 'vestiti', 'neri', 'con', 'archi', 'giganti', 'fanno', 'gesti', 'buffi', 'di', 'fronte', 'a', 'un', 'pubblico', 'che', 'è', 'seduto', 'sul', 'marciapiede', '.', '<END>'], ['<START>', 'due', 'uomini', 'vestiti', 'di', 'nero', 'con', 'grandi', 'gonne', 'colorate', 'stanno', 'recitando', 'una', 'routine', 'comica', 'vicino', 'ad', 'alcuni', 'cespugli', 'di', 'fronte', 'a', 'un', 'piccolo', 'pubblico', '.', '<END>'], ['<START>', 'un', 'uomo', 'asiatico', 'con', 'gli', 'occhiali', 'fa', 'il', 'cartello', 'di', 'pace', 'mentre', "l'altro", 'fa', 'un', 'cuore', 'con', 'le', 'braccia', '.', '<END>'], ['<START>', 'due', 'uomini', 'in', 'vestiti', 'neri', 'con', 'cravatte', 'blu', 'e', 'rosse', 'si', 'esibiscono', 'di', 'fronte', 'a', 'una', 'folla', '.', '<END>'], ['<START>', 'due', 'persone', 'danzano', 'in', 'giro', 'con', 'la', 'gente', 'che', 'li', 'guarda', '.', '<END>']]
# [['<START>', 'due', 'uomini', ',', 'uno', 'afroamericano', 'e', 'uno', 'bianco', ',', 'suonano', 'chitarre', 'acustiche', 'e', 'cantano', 'al', 'microfono', 'in', 'un', 'ambiente', 'esterno', '.', '<END>'], ['<START>', 'due', 'uomini', 'cantano', 'e', 'suonano', 'la', 'chitarra', 'fuori', 'da', 'una', 'struttura', 'di', 'cemento', 'con', 'gli', 'spettatori', 'seduti', 'sui', 'gradini', 'a', 'sinistra', '.', '<END>'], ['<START>', 'due', 'uomini', ',', 'uno', 'nero', 'e', 'uno', 'bianco', ',', 'suonano', 'la', 'chitarra', 'e', 'cantano', 'al', 'microfono', 'mentre', 'sono', "all'aperto", '.', '<END>'], ['<START>', 'un', 'uomo', 'di', 'colore', 'e', 'un', 'bianco', 'con', 'una', 'chitarra', 'acustica', 'sono', 'di', 'fronte', 'ai', 'microfoni', '.', '<END>'], ['<START>', 'due', 'maschi', ',', 'uno', 'bianco', 'e', 'uno', 'nero', ',', 'che', 'cantano', 'e', 'suonano', 'la', 'chitarra', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'in', 'maglietta', 'bianca', 'e', 'pantaloni', 'neri', 'con', 'cuscinetti', 'per', 'le', 'ginocchia', 'e', 'un', 'gomito', 'sul', 'braccio', 'sinistro', 'salta', 'e', 'cade', 'sulle', 'ginocchia', 'di', 'un', 'uomo', 'in', 'maglietta', 'nera', 'sulla', 'spalla', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'attrezzatura', 'atletica', 'sta', 'saltando', 'e', 'correndo', 'su', 'un', 'altro', 'uomo', 'con', 'testa', 'e', 'petto', '.', '<END>'], ['<START>', 'uomo', 'in', 'maglietta', 'bianca', 'che', 'si', 'mette', 'in', 'ginocchio', 'un', 'uomo', 'in', 'maglietta', 'nera', '.', '<END>'], ['<START>', 'un', 'kickboxer', 'colpisce', 'un', 'ginocchio', 'volante', 'in', 'faccia', 'al', 'suo', 'avversario', '.', '<END>'], ['<START>', 'due', 'persone', 'fanno', 'ginnastica', 'in', 'una', 'palestra', '.', '<END>']]
# [['<START>', 'un', 'corridore', 'in', 'blu', 'ha', 'la', 'prima', 'posizione', 'nella', 'corsia', 'interna', ',', 'mentre', 'due', 'corridori', 'in', 'verde', 'e', 'arancione', 'dalla', 'parte', 'esterna', '.', '<END>'], ['<START>', 'tre', 'persone', 'stanno', 'correndo', 'su', 'una', 'pista', 'rossa', '.', '<END>'], ['<START>', 'tre', 'corridori', 'corrono', 'davanti', 'ad', 'una', 'gara', '.', '<END>'], ['<START>', 'tre', 'corridori', 'competono', 'in', 'una', 'gara', '.', '<END>'], ['<START>', 'una', 'gara', 'per', 'battersi', 'un', 'record', '.', '<END>']]
# [['<START>', 'due', 'squadre', 'di', 'football', 'sono', 'nel', 'bel', 'mezzo', 'di', 'una', 'partita', 'mentre', 'i', 'massimi', 'bianchi', 'e', 'quelli', 'verdi', 'opposti', 'sono', 'in', 'tutte', 'le', 'posizioni', 'di', 'movimento', 'mentre', 'si', 'arrampicano', 'per', 'il', 'football', '.', '<END>'], ['<START>', 'i', 'san', 'francisco', '49ers', 'che', 'correno', 'indietro', 'sono', 'attaccati', 'dalla', 'difesa', 'dei', 'new', 'york', 'jets', '.', '<END>'], ['<START>', 'due', 'squadre', 'di', 'football', 'stanno', 'giocando', 'su', 'un', 'campo', 'con', 'il', 'logo', "dell'nfl", '.', '<END>'], ['<START>', 'due', 'squadre', 'di', 'football', 'impegnate', 'in', 'azione', 'competitiva', "l'una", 'contro', "l'altra", '.', '<END>'], ['<START>', 'i', 'giocatori', 'di', 'football', 'lottano', 'per', 'ottenere', 'partite', 'attraverso', 'una', 'linea', 'dura', '.', '<END>']]
# [['<START>', 'uomini', 'in', 'una', 'sola', 'fila', 'di', 'fronte', 'a', 'un', 'set', 'di', 'frutta', 'ben', 'piazzato', 'su', 'un', 'tavolo', ',', 'tutti', 'di', 'umore', 'solenne', 'con', 'altri', 'uomini', 'di', 'umore', 'simile', 'dietro', 'di', 'loro', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'uomini', 'si', 'inchina', 'davanti', 'a', 'un', 'tavolo', 'pieno', 'di', 'verdure', 'multicolori', '.', '<END>'], ['<START>', 'un', 'gruppo', 'mediorientale', 'prega', 'davanti', 'a', 'un', 'tavolo', 'pieno', 'di', 'vegetali', '.', '<END>'], ['<START>', 'molti', 'uomini', 'pregano', 'alla', 'fine', 'di', 'un', 'tavolo', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'uomini', 'inchina', 'la', 'testa', 'davanti', 'ai', 'tavoli', 'del', 'cibo', '.', '<END>']]
# [['<START>', 'due', 'bambini', 'indiani', 'in', 'costume', 'formale', 'che', 'si', 'esibiscono', 'felicemente', 'in', 'una', 'danza', 'rituale', '.', '<END>'], ['<START>', 'due', 'ragazze', 'in', 'vestiti', 'blu', 'con', 'un', 'velo', 'rosso', 'trasparente', 'in', 'posa', 'su', 'un', 'palco', '.', '<END>'], ['<START>', 'due', 'ragazze', 'indiane', 'con', 'vestiti', 'colorati', 'danzano', 'in', 'una', 'tromba', '.', '<END>'], ['<START>', 'due', 'bambini', 'piccoli', 'in', 'costumi', 'asiatici', 'su', 'un', 'palco', 'a', 'ballare', '.', '<END>'], ['<START>', 'due', 'ragazze', 'vestite', 'di', 'costumi', 'asiatici', 'danzano', 'a', 'piedi', 'nudi', '.', '<END>']]
# [['<START>', 'due', 'ragazze', 'e', 'un', 'bambino', 'in', 'piedi', 'accanto', 'a', 'un', 'palo', 'blu', 'mentre', 'una', 'ragazza', 'in', 'maglietta', 'rossa', 'ripara', 'la', 'ragazza', 'in', 'maglietta', 'grigia', '.', '<END>'], ['<START>', 'una', 'ragazzina', 'attacca', 'una', 'collana', 'al', 'collo', 'di', "un'altra", 'ragazzina', ',', 'mentre', 'una', 'terza', 'tiene', "l'orologio", '.', '<END>'], ['<START>', 'tre', 'bambini', 'in', 'piedi', "l'uno", 'vicino', "all'altro", 'e', 'accanto', 'ad', 'un', 'alto', 'pannello', 'di', 'legno', 'blu', '.', '<END>'], ['<START>', 'tre', 'bambini', 'fotografati', 'di', 'fronte', 'ad', 'un', 'edificio', '.', '<END>'], ['<START>', 'in', 'india', ',', 'i', 'bambini', 'giocano', '.', '<END>']]
# [['<START>', 'un', 'gruppo', 'di', 'donne', 'di', 'diverse', 'origini', 'etniche', 'sta', 'competindo', 'in', 'una', 'maratona', '.', '<END>'], ['<START>', 'le', 'corridori', 'femmine', 'dal', 'giappone', ',', 'dalla', 'germania', 'e', 'dalla', 'cina', 'corrono', 'fianco', 'a', 'fianco', '.', '<END>'], ['<START>', 'diverse', 'donne', 'in', 'gara', 'di', 'singlets', 'corrono', 'in', 'gruppo', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'persone', 'sta', 'correndo', '.', '<END>'], ['<START>', 'runner', 'che', 'corrono', 'in', 'una', 'gara', '.', '<END>']]
# [['<START>', 'due', 'donne', 'stanno', 'camminando', 'sulla', 'spiaggia', 'con', 'delle', 'tavole', 'da', 'surf', 'in', 'mano', 'con', 'persone', 'e', 'palme', 'sullo', 'sfondo', '.', '<END>'], ['<START>', 'due', 'donne', 'stanno', 'camminando', 'per', 'la', 'spiaggia', 'portando', 'tavole', 'e', 'pinne', '.', '<END>'], ['<START>', 'due', 'surfisti', 'che', 'si', 'preparano', 'ad', 'entrare', 'in', 'acqua', 'per', 'una', 'competizione', '.', '<END>'], ['<START>', '2', 'surfiste', 'portano', 'le', 'loro', 'tavole', 'sulla', 'spiaggia', '.', '<END>'], ['<START>', 'due', 'donne', 'portavano', 'delle', 'tavole', 'da', 'surf', '.', '<END>']]
# [['<START>', 'un', 'bambino', 'di', 'circa', 'otto', 'anni', 'si', 'siede', 'in', 'cima', 'a', 'una', 'roccia', ',', 'guardando', 'la', 'picturesque', 'foresta', 'sotto', 'di', 'lui', '.', '<END>'], ['<START>', 'un', 'ragazzino', 'appoggiato', 'sulla', 'cima', 'di', 'una', 'montagna', 'che', 'guarda', 'lo', 'scenario', 'sotto', 'di', 'lui', '.', '<END>'], ['<START>', 'un', 'ragazzino', 'siede', 'su', 'una', 'roccia', 'e', 'gode', 'di', 'una', 'vista', 'panoramica', 'delle', 'montagne', '.', '<END>'], ['<START>', 'un', 'ragazzo', 'è', 'seduto', 'su', 'una', 'roccia', ',', 'guarda', 'la', 'valle', 'sottostante', '.', '<END>'], ['<START>', 'un', 'giovane', 'sta', 'guardando', 'giù', 'dalla', 'cima', 'di', 'una', 'montagna', '.', '<END>']]
# [['<START>', 'una', 'donna', 'in', 'piedi', 'su', 'una', 'roccia', 'con', 'una', 'gamba', 'in', 'su', 'e', 'le', 'braccia', 'in', 'su', '.', '<END>'], ['<START>', 'una', 'donna', 'in', 'piedi', 'su', 'una', 'scogliera', 'su', 'una', 'gamba', 'che', 'guarda', 'un', 'fiume', '.', '<END>'], ['<START>', 'una', 'donna', 'è', 'in', 'piedi', 'su', 'una', 'roccia', 'che', 'guarda', 'un', 'fiume', '.', '<END>'], ['<START>', 'una', 'ragazza', 'in', 'posa', 'su', 'una', 'scogliera', 'sopra', 'un', 'fiume', '.', '<END>'], ['<START>', 'donna', 'sul', 'precipizio', 'che', 'cerca', 'di', 'volare', '.', '<END>']]
# [['<START>', 'donna', 'che', 'indossa', 'pantaloni', 'neri', 'sul', 'marciapiede', 'in', 'attesa', 'di', 'un', 'cambio', 'di', 'luce', 'per', 'attraversare', 'la', 'strada', '.', '<END>'], ['<START>', 'una', 'donna', 'con', 'dei', 'pantaloni', 'neri', 'e', 'un', 'maglione', 'sta', 'sul', 'marciapiede', 'accanto', 'a', 'una', 'strada', 'asfaltata', '.', '<END>'], ['<START>', 'una', 'donna', 'bruna', 'è', 'in', 'piedi', 'sul', 'marciapiede', 'a', 'guardare', 'la', 'strada', '.', '<END>'], ['<START>', 'una', 'donna', 'si', 'ferma', 'e', 'aspetta', 'che', 'passi', 'una', 'macchina', 'prima', 'di', 'attraversare', 'la', 'strada', '.', '<END>'], ['<START>', 'donna', 'che', 'aspetta', 'di', 'attraversare', 'e', 'guarda', 'qualcosa', 'a', 'sinistra', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'in', 'maglietta', 'blu', 'racconta', 'una', 'storia', 'emozionante', 'mentre', 'un', 'altro', 'uomo', 'in', 'viola', 'lo', 'guarda', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'tre', 'amici', 'stanno', 'parlando', 'in', 'una', 'casa', '.', '<END>'], ['<START>', 'due', 'uomini', 'in', 'maglietta', 'bianca', 'e', "un'altra", 'persona', 'stanno', 'parlando', '.', '<END>'], ['<START>', 'tre', 'uomini', 'stanno', 'discutendo', '.', '<END>'], ['<START>', 'tre', 'uomini', 'stanno', 'insieme', '.', '<END>']]
# [['<START>', 'un', 'ragazzo', 'in', 'camicia', 'bianca', 'sta', 'facendo', 'una', 'faccia', 'mentre', 'il', 'suo', 'compagno', 'e', 'lui', 'stanno', 'lavorando', 'ai', 'compiti', 'a', 'scuola', '.', '<END>'], ['<START>', 'due', 'cinesi', 'stanno', 'stando', 'vicino', 'a', 'una', 'lavagna', '.', '<END>'], ['<START>', 'due', 'studenti', 'asiatici', 'stanno', 'lavorando', 'su', 'una', 'lavagna', '.', '<END>'], ['<START>', 'due', 'persone', 'stanno', 'in', 'piedi', 'vicino', 'a', 'una', 'lavagna', '.', '<END>'], ['<START>', 'due', 'giovani', 'adulti', 'stanno', 'lavorando', 'su', 'una', 'lavagna', '.', '<END>']]
# [['<START>', 'un', 'bambino', 'vestito', 'di', 'jeans', 'blu', 'con', 'cuffi', 'arrotolati', 'e', 'un', 'cappuccio', 'rosa', 'aspetta', "all'aperto", 'ai', 'piedi', 'delle', 'scale', 'con', "un'ascia", '.', '<END>'], ['<START>', 'una', 'persona', 'con', 'jeans', 'blu', 'e', 'maglione', 'rosso', 'ci', 'ha', 'fatto', 'girare', "l'angolo", 'di', 'un', 'muro', 'di', 'mattoni', '.', '<END>'], ['<START>', 'un', 'bambino', 'che', 'gioca', 'con', 'una', 'spada', 'sul', 'fondo', 'delle', 'scale', '.', '<END>'], ['<START>', 'un', 'ragazzo', 'in', 'maglione', 'rosso', 'con', "un'ascia", 'che', 'fa', 'finta', '.', '<END>'], ['<START>', 'un', 'ragazzino', 'in', 'maglietta', 'rossa', 'ha', "un'ascia", 'giocattolo', '.', '<END>']]
# [['<START>', 'gli', 'agricoltori', 'fanno', 'la', 'loro', 'agricoltura', 'durante', 'il', 'giorno', '.', '<END>'], ['<START>', 'persone', 'e', 'capre', 'camminano', 'in', 'un', 'campo', 'paludoso', '.', '<END>'], ['<START>', 'i', 'lavoratori', 'del', 'campo', 'lavorano', 'in', 'un', 'pascolo', 'di', 'riso', '.', '<END>'], ['<START>', 'due', 'uomini', 'sono', 'fuori', 'con', 'delle', 'capre', 'in', 'una', 'fattoria', '.', '<END>'], ['<START>', 'cinque', 'operai', 'in', 'un', 'campo', 'paludoso', '.', '<END>']]
# [['<START>', 'un', 'uomo', 'sbronzato', 'con', 'i', 'capelli', 'bianchi', 'con', 'dei', 'guanti', 'di', 'plastica', 'che', 'fa', 'caramelle', 'di', 'cotone', 'davanti', 'a', 'una', 'piccola', 'festa', 'con', 'genitori', 'e', 'bambini', '.', '<END>'], ['<START>', 'un', 'uomo', 'anziano', 'fa', 'caramelle', 'di', 'cotone', 'mentre', 'gli', 'altri', 'guardano', '.', '<END>'], ['<START>', 'in', 'una', 'specie', 'di', 'carnevale', ',', 'un', 'uomo', 'fa', 'caramelle', 'di', 'cotone', '.', '<END>'], ['<START>', 'un', 'uomo', 'in', 'maglietta', 'blu', 'che', 'fa', 'caramelle', 'di', 'cotone', 'rosa', '.', '<END>'], ['<START>', 'un', 'uomo', 'fa', 'caramelle', 'di', 'cotone', '.', '<END>']]
# [['<START>', 'un', 'gruppo', 'di', 'poliziotti', 'in', 'uniforme', 'in', 'piedi', 'in', 'un', 'parcheggio', ',', 'sorridendo', 'e', 'parlando', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'poliziotti', 'si', 'sta', 'radunando', 'vicino', 'al', 'loro', 'posto', 'di', 'comando', 'mobile', '.', '<END>'], ['<START>', 'la', 'polizia', 'si', 'riunì', 'in', "un'area", 'vicino', 'ad', 'un', 'posto', 'di', 'comando', 'etichettato', 'come', 'postazione', 'di', 'comando', '.', '<END>'], ['<START>', 'un', 'gruppo', 'di', 'poliziotti', 'sta', 'fuori', 'da', 'un', 'autobus', '.', '<END>'], ['<START>', 'un', 'grande', 'gruppo', 'di', 'poliziotti', 'che', 'parlano', '.', '<END>']]
# [['<START>', 'una', 'donna', 'anziana', 'con', 'capelli', 'bianchi', 'e', 'occhiali', 'è', 'vicino', 'a', 'una', 'finestra', 'e', 'davanti', 'ad', 'un', 'cassetto', 'aperto', '.', '<END>'], ['<START>', 'una', 'donna', 'anziana', 'di', 'capelli', 'bianchi', 'guarda', "all'interno", 'del', 'suo', 'registro', 'e', 'guarda', 'attraverso', 'gli', 'occhiali', '.', '<END>'], ['<START>', 'una', 'donna', 'con', 'i', 'capelli', 'bianchi', 'sta', 'osservando', 'qualcosa', 'seduta', 'a', 'una', 'scrivania', '.', '<END>'], ['<START>', 'una', 'donna', 'anziana', 'in', 'camicia', 'rosa', 'usa', 'una', 'cassa', 'di', 'contanti', 'antica', '.', '<END>'], ['<START>', 'una', 'vecchia', 'signora', 'che', 'lavorava', 'al', 'registro', 'dei', 'contanti', '.', '<END>']]
# [['<START>', 'due', 'uomini', 'stanno', 'usando', 'delle', 'cabine', 'telefoniche', 'che', 'sono', 'collocate', 'poco', 'fuori', 'dal', 'centro', 'di', 'una', 'città', ',', 'da', 'alcuni', 'alberi', '.', '<END>'], ['<START>', 'c', "'", 'è', "l'ultimo", 'telefono', 'pubblico', 'situato', 'nello', 'stato', '.', '<END>'], ['<START>', 'due', 'uomini', 'stanno', 'seduti', 'alle', 'cabine', 'telefoniche', 'fuori', '.', '<END>'], ['<START>', 'due', 'uomini', 'al', 'telefono', 'in', 'una', 'banca', 'di', 'telefoni', 'cellulari', '.', '<END>'], ['<START>', 'due', 'uomini', 'che', 'usano', 'un', 'telefono', 'cellulare', '.', '<END>']]
# [['<START>', 'una', 'donna', 'con', 'un', 'vestito', 'rosso', 'stampato', ',', 'e', 'sandali', 'marroni', ',', 'in', 'piedi', 'con', "un'altra", 'donna', 'che', 'indossa', 'pantaloni', 'bianchi', "d'estate", ',', 'che', 'aspetta', 'di', 'usare', 'un', 'portone', 'verde', 'lungo', 'una', 'strada', 'di', 'cemento', '.', '<END>'], ['<START>', 'un', 'uomo', 'sta', 'uscendo', 'da', 'un', 'portone', ',', 'sollevato', "dall'odore", 'di', 'aria', 'fresca', '.', '<END>'], ['<START>', 'due', 'donne', 'vestite', 'di', 'rosso', 'e', 'un', 'uomo', 'che', 'esce', 'da', 'una', 'postazione', '.', '<END>'], ['<START>', 'due', 'donne', 'stanno', 'lungo', 'una', 'barricata', 'vicino', 'a', 'un', 'porto', 'verde', '.', '<END>'], ['<START>', 'una', 'persona', 'sta', 'uscendo', 'da', 'un', 'bagno', 'portatile', '.', '<END>']]

# %%
if(caption_id in captions_dict):
        captions_dict_updated[int(caption_id)] = str(captions_dict[int(caption_id)]).join(word for word in new_words)
    else:
        captions_dict_updated[int(caption_id)] = ''.join(word for word in new_words)

# %%
for caption in captions_dict_updated:
    caption_list = captions_dict_updated[caption_id]
    for caption in caption_list:
        print(caption)

# %%
def word_idx_map(raw_captions, threshold):
    caps = []
    for im in raw_captions:
        for s in raw_captions[im]:
            caps.append(s.split())

    word_freq = nltk.FreqDist(itertools.chain(*caps))
    idx_to_word = ['<pad>'] + [word for word, cnt in word_freq.items() if cnt >= threshold] + ['<unk>']
    word_to_idx = {word:idx for idx, word in enumerate(idx_to_word)}

    return idx_to_word, word_to_idx

# %%
idx_to_word, word_to_idx = word_idx_map(captions_dict, 5)

# %%
def tokenize(captions, word_to_idx, maxlen):
    '''
    Inputs:
    - captions: dictionary with image_id as key, captions as value
    - word_to_idx: mapping from word to index
    - maxlen: max length of each sequence of tokens
    Returns:
    - tokens: array of shape (data_size, maxlen)
    - image_ids: list of length data_size, mapping token to corresponding image_id
    '''
    tokens, image_ids = [], []
    for im_id in captions:
        for cap in captions[im_id]:
            token = [(lambda x: word_to_idx[x] if x in word_to_idx else word_to_idx['<unk>'])(w) \
                     for w in cap.split()]
            if len(token) > maxlen:
                token = token[:maxlen]
            else:
                token += [0] * (maxlen-len(token))
            tokens.append(token)
            image_ids.append(im_id)
    return np.array(tokens).astype('int32'), np.array(image_ids)

# %%
word_to_idx

# %%
def process_captions(raw_captions_dict):
        """
        Use this function to generate dictionary and other preprocessing on captions
        """

        raw_captions_dict = raw_captions_dict
        captions_dict = {}
        word_counter = Counter()
        FREQUENCY_THRESHOLD = 5
        # Do the preprocessing here
        for caption_id in raw_captions_dict:
            caption_list = raw_captions_dict[caption_id]
            for caption in caption_list:
                words = word_tokenize(caption.lower())
                # update word frequency
                word_counter.update(words)
        words_final = [word for word, wordcount in word_counter.items() if wordcount >= FREQUENCY_THRESHOLD] 
        
        #reset dictionary
        for caption_id in raw_captions_dict:
            caption_list = raw_captions_dict[caption_id]
            for caption in caption_list:
                words = word_tokenize(caption.lower())
                # remove less frequent word
                #new_words = [word for word in words if word in words_final]
                new_words = ['<START>'] + [word for word in words if word in words_final] + ['<END>']
                #print(new_words)
                if(caption_id in captions_dict):
                    captions_dict[int(caption_id)] = str(captions_dict[int(caption_id)]).join(word for word in new_words)
                else:
                    captions_dict[int(caption_id)] = ''.join(word for word in new_words)
        
        for caption_id in captions_dict:
            caption_list = captions_dict[caption_id]
            print(caption_id, caption_list)
        
        return captions_dict

# %%
process_captions(captions_dict)

# %%
import nltk
import pickle
import argparse
from collections import Counter
from pycocotools.coco import COCO

# %%
coco = COCO(json)
counter = Counter()
ids = coco.anns.keys()
for i, id in enumerate(ids):
    caption = str(coco.anns[id]['caption'])
    tokens = nltk.tokenize.word_tokenize(caption.lower())
