# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from collections import Counter
from skimage import io, transform

from torchsummary import summary

import matplotlib.pyplot as plt # for plotting
import numpy as np
from time import time
import collections

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
print("Let's use", torch.cuda.device_count(), "GPUs!")
parallel = True
platform = "colab"
restore = False
# Out:
# cuda
# Let's use 1 GPUs!

# %%
VOCAB = {}

# %% [markdown]
# ### Image Transforms

# %%
class Rescale(object):
    """Rescale the image in a sample to a given size.

    Args:
        output_size (tuple or int): Desired output size. If tuple, output is
            matched to output_size. If int, smaller of image edges is matched
            to output_size keeping aspect ratio the same.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size

    def __call__(self, image):
        h, w = image.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)
        img = transform.resize(image, (new_h, new_w))
        return img


class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, image):
        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose((2, 0, 1))
        return image


IMAGE_RESIZE = (256, 256)
# Sequentially compose the transforms
img_transform = transforms.Compose([Rescale(IMAGE_RESIZE), ToTensor()])

# %% [markdown]
# ### Captions Preprocessing

# %%
class CaptionsPreprocessing:
    """Preprocess the captions, generate vocabulary and convert words to tensor tokens
    Args:
        captions_file_path (string): captions tsv file path
    """
    def __init__(self, captions_file_path):
        self.captions_file_path = captions_file_path

        # Read raw captions
        self.raw_captions_dict = self.read_raw_captions()

        # Preprocess captions
        self.captions_dict = self.process_captions()

        # Create vocabulary
        self.start = "<start>"
        self.end = "<end>"
        self.oov = "<unk>"
        self.pad = "<pad>"
        self.vocab = self.generate_vocabulary()
        self.word2index = self.convert_word2index()        
        self.index2word = self.convert_index2word()
        self.max_len_caption = 50

    def read_raw_captions(self):
        """
        Returns:
            Dictionary with raw captions list keyed by image ids (integers)
        """
        captions_dict = {}
        with open(self.captions_file_path, 'r', encoding='utf-8') as f:
            for img_caption_line in f.readlines():
                img_captions = img_caption_line.strip().split('\t')
                captions_dict[int(img_captions[0])] = img_captions[1:]

        return captions_dict 

    def process_captions(self):
        """
        Use this function to generate dictionary and other preprocessing on captions
        """

        raw_captions_dict = self.raw_captions_dict 
        
        # Do the preprocessing here                
        captions_dict = raw_captions_dict

        return captions_dict

 

    def generate_vocabulary(self):
        """
        Use this function to generate dictionary and other preprocessing on captions
        """
        captions_dict = self.captions_dict

        # Generate the vocabulary
        
        all_captions = ""        
        for cap_lists in captions_dict.values():
            all_captions += " ".join(cap_lists)
        all_captions = all_captions.lower().replace(".", "").split(" ")
        
        vocab = {self.pad :1, self.oov :1, self.start :1, self.end :1}
        vocab_update = Counter(all_captions) 
        vocab_update = {k:v for k,v in vocab_update.items() if v >= freq_threshold}
        vocab.update(vocab_update)
        vocab_size = len(vocab)   
        VOCAB.update(vocab)
        print("VOCAB SIZE =", vocab_size)
        return vocab
    
    def convert_word2index(self):
        word2index = {}
        vocab = self.vocab
        idx = 0
        for k, v in vocab.items():
            word2index[k] = idx
            idx +=1
        
        return word2index
    
    def convert_index2word(self):
        index2word = {}
        vocab = self.vocab
        idx = 0
        
        for k, v in vocab.items():
            index2word[idx] = k
            idx +=1
        
        return index2word

 

    def captions_transform(self, img_caption_list, max_len):
        """
        Use this function to generate tensor tokens for the text captions
        Args:
            img_caption_list: List of captions for a particular image
        """
        word2index = self.word2index
        vocab = self.vocab
        #index2word = self.index2word        
        #embed = self.embed
        start = self.start
        end = self.end
        oov = self.oov
        #print("MX LEN", max_len)
        processed_list = list(map(lambda x: start + " "+ x + " " + end, img_caption_list))
        processed_list = list(map(lambda x: x.lower().replace(".", "").split(" "), processed_list))
        processed_list = list(map(lambda x: list(map(lambda y: word2index[y] if y in vocab else word2index[oov],x)),
                                  processed_list))
        processed_list = list(map(lambda x: x + ( [0] * int(max_len - len(x) + 2) ),processed_list))
        
        # Generate tensors
        #print(np.array(processed_list).shape)
        processed_list = torch.LongTensor(processed_list)
        #processed_captions = embed(processed_list)   
        #print(processed_captions)    
        
        #return torch.zeros(len(img_caption_list), 10)
        return processed_list


if platform == "colab":
    CAPTIONS_FILE_PATH = '/content/drive/My Drive/A4/train_captions.tsv'
else:
    CAPTIONS_FILE_PATH = "../data/train_captions.tsv"
    
embedding_dim = 256
freq_threshold = 4
captions_preprocessing_obj = CaptionsPreprocessing(CAPTIONS_FILE_PATH)
# Out:
# VOCAB SIZE = 10700

# %% [markdown]
# ### Dataset Class

# %%
class ImageCaptionsDataset(Dataset):

    def __init__(self, img_dir, captions_dict, img_transform=None, captions_transform=None):
        """
        Args:
            img_dir (string): Directory with all the images.
            captions_dict: Dictionary with captions list keyed by image ids (integers)
            img_transform (callable, optional): Optional transform to be applied
                on the image sample.

            captions_transform: (callable, optional): Optional transform to be applied
                on the caption sample (list).
        """
        self.img_dir = img_dir
        self.captions_dict = captions_dict
        self.img_transform = img_transform
        self.captions_transform = captions_transform

        self.image_ids = list(captions_dict.keys())
        self.max_len = max([max(list(map(lambda x: len(x.lower().replace(".", "").split(" ")), v))) for k,v in captions_dict.items()])
        

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        img_name = os.path.join(self.img_dir, 'image_{}.jpg'.format(self.image_ids[idx]))
        image = io.imread(img_name)
        captions = self.captions_dict[self.image_ids[idx]]
        if self.img_transform:
            image = self.img_transform(image)

        if self.captions_transform:            
            captions = self.captions_transform(captions, self.max_len)

        sample = {'image': image, 'captions': captions}

        return sample

# %%
#ENCODER

class ResidualBlock(nn.Module):
    def __init__(self, channels, kernel_size, filters, stride=1):
        """
        Args:
            channels: Int: Number of Input channels to 1st convolutional layer
            kernel_size: integer, Symmetric Conv Window = (kernel_size, kernel_size)
            filters: python list of integers, defining the number of filters in the CONV layers of the main path
            stride: Tuple: (stride, stride)
        """
        super(ResidualBlock, self).__init__()
        F1, F2, F3 = filters
        #N, in_channels , H, W = shape
        kernel_size = (kernel_size, kernel_size)
        padding = (1,1)
        stride = (stride, stride)
        self.conv1 = nn.Conv2d(in_channels = channels, out_channels = F1, kernel_size=(1,1), stride=stride, padding=0)
        self.bn1 = nn.BatchNorm2d(F1)
        self.relu = nn.ReLU(inplace=True) 
        self.conv2 = nn.Conv2d(in_channels = F1, out_channels = F2, kernel_size=kernel_size, stride=stride, padding=padding)
        self.bn2 = nn.BatchNorm2d(F2)
        self.conv3 = nn.Conv2d(in_channels = F2, out_channels = F3, kernel_size=(1,1), stride=stride, padding=0)
        self.bn3 = nn.BatchNorm2d(F3)
        
    def forward(self, x):
        x_residual = x #backup x for residual connection
        
        #stage 1 main path
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        #print("RESI:", x.shape)
        
        #stage 2 main path
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        #print("RESI:", x.shape)
        
        #stage 3 main path
        x = self.conv3(x)
        x = self.bn3(x)
        #print("RESI:", x.shape)
        
        x += x_residual #add output with residual connection
        x = self.relu(x)
        return x
    
class ConvolutionalBlock(nn.Module):
    def __init__(self, channels, kernel_size, filters, stride=1):
        """
        Args:
            channels: Int: Number of Input channels to 1st convolutional layer
            kernel_size: integer, Symmetric Conv Window = (kernel_size, kernel_size)
            filters: python list of integers, defining the number of filters in the CONV layers of the main path
            stride: Tuple: (stride, stride)
        """
        super(ConvolutionalBlock, self).__init__()
        F1, F2, F3 = filters
        kernel_size = (kernel_size, kernel_size)
        padding = (1,1)
        stride = (stride, stride)
        
        self.conv1 = nn.Conv2d(in_channels = channels, out_channels = F1, kernel_size=(1,1), stride=stride, padding=0)
        self.bn1 = nn.BatchNorm2d(F1)
        self.relu = nn.ReLU(inplace=True) 
        self.conv2 = nn.Conv2d(in_channels = F1, out_channels = F2, kernel_size=kernel_size, stride=(1,1), padding=padding)
        self.bn2 = nn.BatchNorm2d(F2)
        self.conv3 = nn.Conv2d(in_channels = F2, out_channels = F3, kernel_size=(1,1), stride=(1,1), padding=0)
        self.bn3 = nn.BatchNorm2d(F3)
        self.conv4 = nn.Conv2d(in_channels = channels, out_channels = F3, kernel_size=(1,1), stride=stride, padding=0)
        self.bn4 = nn.BatchNorm2d(F3)
        
    def forward(self,x):
        x_residual = x #backup x for residual connection
        
        #stage 1 main path
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        #print("CONV:", x.shape)
        
        #stage 2 main path
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        #print("CONV:", x.shape)
        
        #stage 3 main path
        x = self.conv3(x)
        x = self.bn3(x)
        #print("CONV:", x.shape)
        
        #residual connection
        x_residual = self.conv4(x_residual)
        x_residual = self.bn4(x_residual)
        x += x_residual #add output with residual connection
        x = self.relu(x)
        return x
    
class ResNet50(nn.Module):
    def __init__(self, input_shape = (256, 256, 3), classes = 5):
        """
        It Implements Famous Resnet50 Architecture
        Args:
            input_shape(tuple):(callable, optional): dimensions of image sample
            classes(int):(callable, optional): Final output classes of softmax layer.
        """
        super(ResNet50, self).__init__()
        
        self.pad = nn.ZeroPad2d((1, 1, 3, 3))        
        ###STAGE1
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels=64, kernel_size=(7,7), stride = (2,2), padding=1) # convolve each of our 3-channel images with 6 different 5x5 kernels, giving us 6 feature maps
        self.batch_norm1 = nn.BatchNorm2d(64) #BatchNorm
        self.pool1 = nn.MaxPool2d((3,3), stride=(2,2), padding=1, dilation=1)
        
        ###STAGE2 channels, kernel_size=3, filters, stride=1, stage
        self.conv_block1 = ConvolutionalBlock(channels = 64, kernel_size = 3, filters = [64, 64, 256],stride = 1)
        self.residual_block1 = ResidualBlock(channels = 256, kernel_size = 3, filters = [64, 64, 256])
        
        ###STAGE3 
        self.conv_block2 = ConvolutionalBlock(channels = 256, kernel_size = 3, filters = [128, 128, 512],stride = 2)
        self.residual_block2 = ResidualBlock(channels = 512, kernel_size = 3, filters = [128, 128, 512],)
        
        ###STAGE4 
        self.conv_block3 = ConvolutionalBlock(channels = 512, kernel_size = 3, filters = [256, 256, 1024], stride = 2)
        self.residual_block3 = ResidualBlock(channels = 1024, kernel_size = 3, filters = [256, 256, 1024])
        
        ###STAGE5 
        self.conv_block4 = ConvolutionalBlock(channels = 1024, kernel_size = 3, filters = [512, 512, 2048], stride = 2)
        self.residual_block4 = ResidualBlock(channels = 2048, kernel_size = 3, filters = [512, 512, 2048])
        
        self.adaptive_pool = nn.AdaptiveAvgPool2d(output_size = (1,1))
        self.fc1 = nn.Linear(in_features=2048, out_features=classes, bias = True)
        
        
    def forward(self, x):
        #print("IP_SIZE:", x.shape)
        
        ###STAGE1        
        #print("\n STAGE1")
        x = self.conv1(x)
        x = self.batch_norm1(x)
        x = self.pool1(x)
        #print("OP_STAGE1_SIZE:", x.shape)
        
        ###STAGE2 
        #print("\n STAGE2")
        x = self.conv_block1(x)
        x = self.residual_block1(x)
        x = self.residual_block1(x)
        #print("OP_STAGE2_SIZE:", x.shape)
        
        ###STAGE3 
        #print("\n STAGE3")
        x = self.conv_block2(x)
        x = self.residual_block2(x)
        x = self.residual_block2(x)
        x = self.residual_block2(x)
        #print("OP_STAGE3_SIZE:", x.shape)
        
        ###STAGE4  
        #print("\n STAGE4")
        x = self.conv_block3(x)
        x = self.residual_block3(x)
        x = self.residual_block3(x)
        x = self.residual_block3(x)
        x = self.residual_block3(x)
        x = self.residual_block3(x)
        #print("OP_STAGE4_SIZE:", x.shape)
        
        ###STAGE5  
        #print("\n STAGE5")
        x = self.conv_block4(x)
        x = self.residual_block4(x)
        x = self.residual_block4(x)
        #print("OP_STAGE5_SIZE:", x.shape)
        
        x = self.adaptive_pool(x)
        #print("OP_ADAPTIVEPOOL_SHAPE", x.shape)
        
        x = x.view(x.size(0), -1) # Flatten Vector
        x = self.fc1(x)
        #print("OP_FC1_SIZE:", x.shape)
        return x
        
        
class Encoder(nn.Module):    
    def __init__(self, embed_dim):
        """
        CNN ENCODER
        Args:
            embed_dim(int): embedding dimension ie output dimension of last FC Layer
        Returns:
            x: Feature vector of size(BatchSize, embed_dim)
        """
        super(Encoder, self).__init__()
        self.resnet50 = ResNet50(classes = embed_dim)
        
    def forward(self, x):
        return self.resnet50(x)

# %%
class AttentionBlock(nn.Module):
    def __init__(self, embed_dim, units, vocab_size):
        super(AttentionBlock, self).__init__()
        self.W1 = nn.Linear(in_features = embed_dim, out_features = units)
        self.W2 = nn.Linear(in_features=units, out_features=units)
        self.V = nn.Linear(in_features=units, out_features=1)
        self.tanh = nn.Tanh()
        self.softmax = nn.Softmax(dim=1)
        
    def forward(self, img_features, hidden):
        
        hidden = hidden.unsqueeze(dim=1)
        hidden = hidden.double()
        #print("feature and hidden shape",img_features.shape, hidden.shape)
        combined_score = self.tanh(self.W1(img_features) + self.W2(hidden))
        
        attention_weights = self.softmax(self.V(combined_score))
        context_vector = attention_weights * img_features
        context_vector = torch.sum(context_vector, dim=1)
        
        return context_vector, attention_weights    



class Decoder(nn.Module):
    def __init__(self, embed_dim, lstm_hidden_size,lstm_layers=1):
        super(Decoder, self).__init__()
        self.lstm_hidden_size = lstm_hidden_size
        self.vocab_size = len(VOCAB)
        print("VOCAB SIZE = ", self.vocab_size)
        
        self.lstm = nn.LSTM(input_size = embed_dim, hidden_size = lstm_hidden_size,
                            num_layers = lstm_layers, batch_first = True)
        
        self.linear = nn.Linear(lstm_hidden_size, self.vocab_size)        
        self.embed = nn.Embedding(self.vocab_size, embed_dim)
        
        self.attention = AttentionBlock(embed_dim, lstm_hidden_size, self.vocab_size)

        
    def forward(self, img_features, image_captions):
        image_features = torch.Tensor.repeat_interleave(img_features, repeats=5 , dim=0)
        image_features = image_features.unsqueeze(1)
        
        hidden = torch.zeros((image_features.shape[0], self.lstm_hidden_size))
        hidden = hidden.to(torch.device("cuda:0"))
        
        context, attention = self.attention(image_features, hidden)
        
        embedded_captions = self.embed(image_captions)
        #print("EMBED SHAPE", embedded_captions.shape)
        #print("SHAPES BEFORE CONCAT",context.unsqueeze(dim=1).shape, embedded_captions[:,1:].shape)
        input_lstm = torch.cat((context.unsqueeze(dim=1), embedded_captions[:,:-1]), dim = 1)
        
        lstm_outputs, _ = self.lstm(input_lstm)        
        lstm_outputs = self.linear(lstm_outputs)
        #print("lstm_outputs.shape", lstm_outputs.shape)
        
        
        return lstm_outputs

# %%
class ImageCaptionsNet(nn.Module):
    def __init__(self):
        super(ImageCaptionsNet, self).__init__()

        # Define your architecture here
        
        ##CNN ENCODER RESNET-50
        
        self.Encoder = Encoder(embed_dim = embedding_dim)
        self.Decoder = Decoder(embedding_dim, units, 1)
        #self.Decoder = DecoderRNN(256, 512, len(captions_preprocessing_obj.vocab), 1)
        
        

    def forward(self, x):
        x = image_batch, captions_batch

        # Forward Propogation
        x = self.Encoder(image_batch)
        #print(x.shape)
        x = self.Decoder(x, captions_batch)
        return x
    
units = 512
if restore == False:
    net = ImageCaptionsNet()
    net = net.double()
    # If GPU training is required
    if parallel == True and device != "cpu":
        print("Parallel Processing enabled")
        net = nn.DataParallel(net)

    if device == "cpu":
        print("Device to CPU")
    else:
        print("Device to CUDA")
        net = net.to(torch.device("cuda:0"))
# Out:
# VOCAB SIZE =  10700
# Parallel Processing enabled
# Device to CUDA

# %%
def create_checkpoint(path,model, optim_obj, loss_obj,iteration, epoch):
    checkpoint = {'epoch': epoch,
                  'iteration': iteration,
                  'model_state_dict': model.module.state_dict(),
                  'optimizer_state_dict': optim_obj.state_dict(),
                  'loss': loss_obj}

    if platform == "colab":
        directory = '/content/drive/My Drive/A4/checkpoint_withAttn/'
    else:
        directory = '../checkpoint/'

    torch.save(checkpoint, directory + path)
    
def restore_checkpoint(path):
    new_state_dict = collections.OrderedDict()
    if platform == "colab":
        directory = '/content/drive/My Drive/A4/checkpoint_withAttn/'
        checkpoint = torch.load(directory + path)
    else:
        directory = '../checkpoint/'
        checkpoint = torch.load(directory + path, map_location=torch.device('cpu'))    
    
    epoch = checkpoint['epoch']
    new_state_dict = checkpoint['model_state_dict']
    iteration = checkpoint['iteration']
    optimizer_state_dict = checkpoint['optimizer_state_dict']
    loss_obj = checkpoint['loss']
    print("Iterations = {}, Epoch = {}, loss = {}".format(iteration, epoch, loss_obj.item()))
    return new_state_dict

# %% [markdown]
# ### Training Loop

# %%
if platform == "colab":
    IMAGE_DIR = '/content/drive/My Drive/train_images/'
else:
    IMAGE_DIR = '../data/train/'

if restore == True:
    net = ImageCaptionsNet()
    net = net.double()
    #net = net.to(torch.device("cuda:0"))
    #net = nn.DataParallel(net)
    new_state_dict = collections.OrderedDict()
    new_state_dict = restore_checkpoint("caption_chkpt_multi.pth")
    '''
    for k, v in state_dict.items():
        name = k[7:] # remove `module.`
        new_state_dict[name] = v
    '''

    # load params
    #directory = '../checkpoint/'
    #path = "caption_chkpt_multi.pth"
    net.load_state_dict()
    print("State Dictionary Loaded Successfully.")
    net = nn.DataParallel(net)
    net = net.to(torch.device("cuda:0"))

# Creating the Dataset
train_dataset = ImageCaptionsDataset(
    IMAGE_DIR, captions_preprocessing_obj.captions_dict, img_transform=img_transform,
    captions_transform=captions_preprocessing_obj.captions_transform
)

# Define your hyperparameters
NUMBER_OF_EPOCHS = 3
LEARNING_RATE = 1e-1
BATCH_SIZE = 32
NUM_WORKERS = 0 # Parallel threads for dataloading
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=LEARNING_RATE)
loss_list = []
# Creating the DataLoader for batching purposes
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
import os
if device != "cpu":
    os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
    torch.backends.cudnn.benchmark = True
    #torch.cuda.set_device(1)
t0 = time()
for epoch in range(NUMBER_OF_EPOCHS):
    print("$$$$$----EPOCH {}----$$$$$$".format(epoch+1))
    iteration = 0
    for batch_idx, sample in enumerate(train_loader):
        iteration +=1
        net.zero_grad()

        image_batch, captions_batch = sample['image'], sample['captions']
        
        #print("image_shape", image_batch.shape)
        #print("batch_shape", captions_batch.shape)
        
        N, I, L = captions_batch.shape
        captions_batch = torch.reshape(captions_batch, (N*I,L))

        # If GPU training required
        if device != "cpu":
          #print("cuda")
          image_batch, captions_batch = image_batch.to(torch.device("cuda:0")), captions_batch.to(torch.device("cuda:0"))
        #print("Running Caption Gen")
        output_captions = net((image_batch, captions_batch))
        #print("output Achieved")

        #print("size for loss", output_captions.shape, captions_batch.shape)
        loss = loss_function(output_captions.reshape(-1, output_captions.shape[2]), captions_batch.reshape(-1))
        loss_list.append(loss.item())
        
        loss.backward()
        optimizer.step()
        #print("creating checkpoint")
        if iteration%5 == 0:
            create_checkpoint("caption_chkpt_multi.pth", net, optimizer, loss, iteration, epoch+1)
        print("ITERATION:[{}/{}] | LOSS: {} | EPOCH = [{}/{}] | TIME ELAPSED ={}Mins".format(iteration, round(29000/BATCH_SIZE)+1,
              round(loss.item(), 6), epoch+1, NUMBER_OF_EPOCHS, round((time()-t0)/60,2)))
    print("\n$$Loss = {},EPOCH: [{}/{}]\n\n".format(round(loss.item(), 6), epoch+1, NUMBER_OF_EPOCHS))
    create_checkpoint("epoch{}_chkpt_multi.pth".format(epoch+1), net, optimizer, loss, iteration, epoch+1)

create_checkpoint("Final_Model_multi.pth", net, optimizer, loss, iteration, epoch+1)
# Out:
# $$$$$----EPOCH 1----$$$$$$
# ITERATION:[1/907] | LOSS: 9.194864 | EPOCH = [1/3] | TIME ELAPSED =0.23Mins
# ITERATION:[2/907] | LOSS: 7.157344 | EPOCH = [1/3] | TIME ELAPSED =0.4Mins
# ITERATION:[3/907] | LOSS: 4.357884 | EPOCH = [1/3] | TIME ELAPSED =0.55Mins
# ITERATION:[4/907] | LOSS: 1.926964 | EPOCH = [1/3] | TIME ELAPSED =0.71Mins
# ITERATION:[5/907] | LOSS: 1.906151 | EPOCH = [1/3] | TIME ELAPSED =0.87Mins
# ITERATION:[6/907] | LOSS: 1.883244 | EPOCH = [1/3] | TIME ELAPSED =1.05Mins
# ITERATION:[7/907] | LOSS: 1.918969 | EPOCH = [1/3] | TIME ELAPSED =1.22Mins
# ITERATION:[8/907] | LOSS: 1.818737 | EPOCH = [1/3] | TIME ELAPSED =1.44Mins
# ITERATION:[9/907] | LOSS: 1.911962 | EPOCH = [1/3] | TIME ELAPSED =1.59Mins
# ITERATION:[10/907] | LOSS: 1.992242 | EPOCH = [1/3] | TIME ELAPSED =1.76Mins
# ITERATION:[11/907] | LOSS: 1.808718 | EPOCH = [1/3] | TIME ELAPSED =1.94Mins
# ITERATION:[12/907] | LOSS: 1.764682 | EPOCH = [1/3] | TIME ELAPSED =2.11Mins
# ITERATION:[13/907] | LOSS: 1.803393 | EPOCH = [1/3] | TIME ELAPSED =2.27Mins
# ITERATION:[14/907] | LOSS: 1.782172 | EPOCH = [1/3] | TIME ELAPSED =2.41Mins
# ITERATION:[15/907] | LOSS: 1.736625 | EPOCH = [1/3] | TIME ELAPSED =2.59Mins
# ITERATION:[16/907] | LOSS: 1.754846 | EPOCH = [1/3] | TIME ELAPSED =2.73Mins
# ITERATION:[17/907] | LOSS: 1.837684 | EPOCH = [1/3] | TIME ELAPSED =2.9Mins
# ITERATION:[18/907] | LOSS: 1.718034 | EPOCH = [1/3] | TIME ELAPSED =3.06Mins
# ITERATION:[19/907] | LOSS: 1.729092 | EPOCH = [1/3] | TIME ELAPSED =3.21Mins
# ITERATION:[20/907] | LOSS: 1.822226 | EPOCH = [1/3] | TIME ELAPSED =3.37Mins
# ITERATION:[21/907] | LOSS: 1.763682 | EPOCH = [1/3] | TIME ELAPSED =3.56Mins
# ITERATION:[22/907] | LOSS: 1.778942 | EPOCH = [1/3] | TIME ELAPSED =3.72Mins
# ITERATION:[23/907] | LOSS: 1.728163 | EPOCH = [1/3] | TIME ELAPSED =3.89Mins
# ITERATION:[24/907] | LOSS: 1.733638 | EPOCH = [1/3] | TIME ELAPSED =4.04Mins
# ITERATION:[25/907] | LOSS: 1.861607 | EPOCH = [1/3] | TIME ELAPSED =4.22Mins
# ITERATION:[26/907] | LOSS: 1.838522 | EPOCH = [1/3] | TIME ELAPSED =4.37Mins
# ITERATION:[27/907] | LOSS: 1.798041 | EPOCH = [1/3] | TIME ELAPSED =4.54Mins
# ITERATION:[28/907] | LOSS: 1.790022 | EPOCH = [1/3] | TIME ELAPSED =4.7Mins
# ITERATION:[29/907] | LOSS: 1.666624 | EPOCH = [1/3] | TIME ELAPSED =4.86Mins
# ITERATION:[30/907] | LOSS: 1.864256 | EPOCH = [1/3] | TIME ELAPSED =5.02Mins
# ITERATION:[31/907] | LOSS: 1.763392 | EPOCH = [1/3] | TIME ELAPSED =5.19Mins
# ITERATION:[32/907] | LOSS: 1.686774 | EPOCH = [1/3] | TIME ELAPSED =5.34Mins
# ITERATION:[33/907] | LOSS: 1.708975 | EPOCH = [1/3] | TIME ELAPSED =5.5Mins
# ITERATION:[34/907] | LOSS: 1.728322 | EPOCH = [1/3] | TIME ELAPSED =5.67Mins
# ITERATION:[35/907] | LOSS: 1.743665 | EPOCH = [1/3] | TIME ELAPSED =5.85Mins
# ITERATION:[36/907] | LOSS: 1.785723 | EPOCH = [1/3] | TIME ELAPSED =5.99Mins
# ITERATION:[37/907] | LOSS: 1.716163 | EPOCH = [1/3] | TIME ELAPSED =6.21Mins
# ITERATION:[38/907] | LOSS: 1.794801 | EPOCH = [1/3] | TIME ELAPSED =6.36Mins
# ITERATION:[39/907] | LOSS: 1.614528 | EPOCH = [1/3] | TIME ELAPSED =6.51Mins
# ITERATION:[40/907] | LOSS: 1.664152 | EPOCH = [1/3] | TIME ELAPSED =6.7Mins
# ITERATION:[41/907] | LOSS: 1.777648 | EPOCH = [1/3] | TIME ELAPSED =6.89Mins
# ITERATION:[42/907] | LOSS: 1.740601 | EPOCH = [1/3] | TIME ELAPSED =7.04Mins
# ITERATION:[43/907] | LOSS: 1.804699 | EPOCH = [1/3] | TIME ELAPSED =7.2Mins
# ITERATION:[44/907] | LOSS: 1.762371 | EPOCH = [1/3] | TIME ELAPSED =7.39Mins
# ITERATION:[45/907] | LOSS: 1.868835 | EPOCH = [1/3] | TIME ELAPSED =7.55Mins
# ITERATION:[46/907] | LOSS: 1.751813 | EPOCH = [1/3] | TIME ELAPSED =7.71Mins
# ITERATION:[47/907] | LOSS: 1.734571 | EPOCH = [1/3] | TIME ELAPSED =7.9Mins
# ITERATION:[48/907] | LOSS: 1.821073 | EPOCH = [1/3] | TIME ELAPSED =8.06Mins
# ITERATION:[49/907] | LOSS: 1.726455 | EPOCH = [1/3] | TIME ELAPSED =8.22Mins
# ITERATION:[50/907] | LOSS: 1.692578 | EPOCH = [1/3] | TIME ELAPSED =8.36Mins
# ITERATION:[51/907] | LOSS: 1.757289 | EPOCH = [1/3] | TIME ELAPSED =8.54Mins
# ITERATION:[52/907] | LOSS: 1.800301 | EPOCH = [1/3] | TIME ELAPSED =8.69Mins
# ITERATION:[53/907] | LOSS: 1.653144 | EPOCH = [1/3] | TIME ELAPSED =8.86Mins
# ITERATION:[54/907] | LOSS: 1.716103 | EPOCH = [1/3] | TIME ELAPSED =9.06Mins
# ITERATION:[55/907] | LOSS: 1.788172 | EPOCH = [1/3] | TIME ELAPSED =9.26Mins
# ITERATION:[56/907] | LOSS: 1.655313 | EPOCH = [1/3] | TIME ELAPSED =9.49Mins
# ITERATION:[57/907] | LOSS: 1.782917 | EPOCH = [1/3] | TIME ELAPSED =9.66Mins
# ITERATION:[58/907] | LOSS: 1.616588 | EPOCH = [1/3] | TIME ELAPSED =9.83Mins
# ITERATION:[59/907] | LOSS: 1.74385 | EPOCH = [1/3] | TIME ELAPSED =9.98Mins
# ITERATION:[60/907] | LOSS: 1.710948 | EPOCH = [1/3] | TIME ELAPSED =10.15Mins
# ITERATION:[61/907] | LOSS: 1.692612 | EPOCH = [1/3] | TIME ELAPSED =10.31Mins
# ITERATION:[62/907] | LOSS: 1.715141 | EPOCH = [1/3] | TIME ELAPSED =10.46Mins
# ITERATION:[63/907] | LOSS: 1.747525 | EPOCH = [1/3] | TIME ELAPSED =10.61Mins
# ITERATION:[64/907] | LOSS: 1.825094 | EPOCH = [1/3] | TIME ELAPSED =10.77Mins
# ITERATION:[65/907] | LOSS: 1.721752 | EPOCH = [1/3] | TIME ELAPSED =10.95Mins
# ITERATION:[66/907] | LOSS: 1.611318 | EPOCH = [1/3] | TIME ELAPSED =11.12Mins
# ITERATION:[67/907] | LOSS: 1.628655 | EPOCH = [1/3] | TIME ELAPSED =11.29Mins
# ITERATION:[68/907] | LOSS: 1.647135 | EPOCH = [1/3] | TIME ELAPSED =11.45Mins
# ITERATION:[69/907] | LOSS: 1.6909 | EPOCH = [1/3] | TIME ELAPSED =11.61Mins
# ITERATION:[70/907] | LOSS: 1.694112 | EPOCH = [1/3] | TIME ELAPSED =11.79Mins
# ITERATION:[71/907] | LOSS: 1.72035 | EPOCH = [1/3] | TIME ELAPSED =11.96Mins
# ITERATION:[72/907] | LOSS: 1.669852 | EPOCH = [1/3] | TIME ELAPSED =12.13Mins
# ITERATION:[73/907] | LOSS: 1.635418 | EPOCH = [1/3] | TIME ELAPSED =12.28Mins
# ITERATION:[74/907] | LOSS: 1.747312 | EPOCH = [1/3] | TIME ELAPSED =12.44Mins
# ITERATION:[75/907] | LOSS: 1.683803 | EPOCH = [1/3] | TIME ELAPSED =12.59Mins
# ITERATION:[76/907] | LOSS: 1.714033 | EPOCH = [1/3] | TIME ELAPSED =12.75Mins
# ITERATION:[77/907] | LOSS: 1.845738 | EPOCH = [1/3] | TIME ELAPSED =12.91Mins
# ITERATION:[78/907] | LOSS: 1.726902 | EPOCH = [1/3] | TIME ELAPSED =13.07Mins
# ITERATION:[79/907] | LOSS: 1.741576 | EPOCH = [1/3] | TIME ELAPSED =13.22Mins
# ITERATION:[80/907] | LOSS: 1.800456 | EPOCH = [1/3] | TIME ELAPSED =13.4Mins
# ITERATION:[81/907] | LOSS: 1.681361 | EPOCH = [1/3] | TIME ELAPSED =13.59Mins
# ITERATION:[82/907] | LOSS: 1.68457 | EPOCH = [1/3] | TIME ELAPSED =13.75Mins
# ITERATION:[83/907] | LOSS: 1.598568 | EPOCH = [1/3] | TIME ELAPSED =13.91Mins
# ITERATION:[84/907] | LOSS: 1.674151 | EPOCH = [1/3] | TIME ELAPSED =14.08Mins
# ITERATION:[85/907] | LOSS: 1.674973 | EPOCH = [1/3] | TIME ELAPSED =14.26Mins
# ITERATION:[86/907] | LOSS: 1.704229 | EPOCH = [1/3] | TIME ELAPSED =14.39Mins
# ITERATION:[87/907] | LOSS: 1.639407 | EPOCH = [1/3] | TIME ELAPSED =14.55Mins
# ITERATION:[88/907] | LOSS: 1.721574 | EPOCH = [1/3] | TIME ELAPSED =14.71Mins
# ITERATION:[89/907] | LOSS: 1.662282 | EPOCH = [1/3] | TIME ELAPSED =14.89Mins
# ITERATION:[90/907] | LOSS: 1.61755 | EPOCH = [1/3] | TIME ELAPSED =15.06Mins
# ITERATION:[91/907] | LOSS: 1.6943 | EPOCH = [1/3] | TIME ELAPSED =15.21Mins
# ITERATION:[92/907] | LOSS: 1.675828 | EPOCH = [1/3] | TIME ELAPSED =15.39Mins
# ITERATION:[93/907] | LOSS: 1.679407 | EPOCH = [1/3] | TIME ELAPSED =15.54Mins
# ITERATION:[94/907] | LOSS: 1.671176 | EPOCH = [1/3] | TIME ELAPSED =15.69Mins
# ITERATION:[95/907] | LOSS: 1.805097 | EPOCH = [1/3] | TIME ELAPSED =15.85Mins
# ITERATION:[96/907] | LOSS: 1.767063 | EPOCH = [1/3] | TIME ELAPSED =15.99Mins
# ITERATION:[97/907] | LOSS: 1.677426 | EPOCH = [1/3] | TIME ELAPSED =16.17Mins
# ITERATION:[98/907] | LOSS: 1.712031 | EPOCH = [1/3] | TIME ELAPSED =16.35Mins
# ITERATION:[99/907] | LOSS: 1.686365 | EPOCH = [1/3] | TIME ELAPSED =16.54Mins
# ITERATION:[100/907] | LOSS: 1.546897 | EPOCH = [1/3] | TIME ELAPSED =16.71Mins
# ITERATION:[101/907] | LOSS: 1.612159 | EPOCH = [1/3] | TIME ELAPSED =16.88Mins
# ITERATION:[102/907] | LOSS: 1.654806 | EPOCH = [1/3] | TIME ELAPSED =17.01Mins
# ITERATION:[103/907] | LOSS: 1.679885 | EPOCH = [1/3] | TIME ELAPSED =17.18Mins
# ITERATION:[104/907] | LOSS: 1.652241 | EPOCH = [1/3] | TIME ELAPSED =17.33Mins
# ITERATION:[105/907] | LOSS: 1.588318 | EPOCH = [1/3] | TIME ELAPSED =17.49Mins
# ITERATION:[106/907] | LOSS: 1.680629 | EPOCH = [1/3] | TIME ELAPSED =17.63Mins
# ITERATION:[107/907] | LOSS: 1.641465 | EPOCH = [1/3] | TIME ELAPSED =17.78Mins
# ITERATION:[108/907] | LOSS: 1.647197 | EPOCH = [1/3] | TIME ELAPSED =17.92Mins
# ITERATION:[109/907] | LOSS: 1.559904 | EPOCH = [1/3] | TIME ELAPSED =18.07Mins
# ITERATION:[110/907] | LOSS: 1.604377 | EPOCH = [1/3] | TIME ELAPSED =18.23Mins
# ITERATION:[111/907] | LOSS: 1.626221 | EPOCH = [1/3] | TIME ELAPSED =18.4Mins
# ITERATION:[112/907] | LOSS: 1.564755 | EPOCH = [1/3] | TIME ELAPSED =18.55Mins
# ITERATION:[113/907] | LOSS: 1.537875 | EPOCH = [1/3] | TIME ELAPSED =18.71Mins
# ITERATION:[114/907] | LOSS: 1.586699 | EPOCH = [1/3] | TIME ELAPSED =18.89Mins
# ITERATION:[115/907] | LOSS: 1.498403 | EPOCH = [1/3] | TIME ELAPSED =19.05Mins
# ITERATION:[116/907] | LOSS: 1.654152 | EPOCH = [1/3] | TIME ELAPSED =19.21Mins
# ITERATION:[117/907] | LOSS: 1.632812 | EPOCH = [1/3] | TIME ELAPSED =19.36Mins
# ITERATION:[118/907] | LOSS: 1.520362 | EPOCH = [1/3] | TIME ELAPSED =19.57Mins
# ITERATION:[119/907] | LOSS: 1.664868 | EPOCH = [1/3] | TIME ELAPSED =19.73Mins
# ITERATION:[120/907] | LOSS: 1.641275 | EPOCH = [1/3] | TIME ELAPSED =19.92Mins
# ITERATION:[121/907] | LOSS: 1.57043 | EPOCH = [1/3] | TIME ELAPSED =20.07Mins
# ITERATION:[122/907] | LOSS: 1.660001 | EPOCH = [1/3] | TIME ELAPSED =20.24Mins
# ITERATION:[123/907] | LOSS: 1.628337 | EPOCH = [1/3] | TIME ELAPSED =20.39Mins
# ITERATION:[124/907] | LOSS: 1.64856 | EPOCH = [1/3] | TIME ELAPSED =20.55Mins
# ITERATION:[125/907] | LOSS: 1.658624 | EPOCH = [1/3] | TIME ELAPSED =20.69Mins
# ITERATION:[126/907] | LOSS: 1.649613 | EPOCH = [1/3] | TIME ELAPSED =20.85Mins
# ITERATION:[127/907] | LOSS: 1.482706 | EPOCH = [1/3] | TIME ELAPSED =21.02Mins
# ITERATION:[128/907] | LOSS: 1.65042 | EPOCH = [1/3] | TIME ELAPSED =21.17Mins
# ITERATION:[129/907] | LOSS: 1.710553 | EPOCH = [1/3] | TIME ELAPSED =21.34Mins
# ITERATION:[130/907] | LOSS: 1.659324 | EPOCH = [1/3] | TIME ELAPSED =21.5Mins
# ITERATION:[131/907] | LOSS: 1.537028 | EPOCH = [1/3] | TIME ELAPSED =21.64Mins
# ITERATION:[132/907] | LOSS: 1.737466 | EPOCH = [1/3] | TIME ELAPSED =21.8Mins
# ITERATION:[133/907] | LOSS: 1.538864 | EPOCH = [1/3] | TIME ELAPSED =21.98Mins
# ITERATION:[134/907] | LOSS: 1.618307 | EPOCH = [1/3] | TIME ELAPSED =22.12Mins
# ITERATION:[135/907] | LOSS: 1.45405 | EPOCH = [1/3] | TIME ELAPSED =22.29Mins
# ITERATION:[136/907] | LOSS: 1.668459 | EPOCH = [1/3] | TIME ELAPSED =22.44Mins
# ITERATION:[137/907] | LOSS: 1.67699 | EPOCH = [1/3] | TIME ELAPSED =22.61Mins
# ITERATION:[138/907] | LOSS: 1.565203 | EPOCH = [1/3] | TIME ELAPSED =22.79Mins
# ITERATION:[139/907] | LOSS: 1.668728 | EPOCH = [1/3] | TIME ELAPSED =22.95Mins
# ITERATION:[140/907] | LOSS: 1.560215 | EPOCH = [1/3] | TIME ELAPSED =23.11Mins
# ITERATION:[141/907] | LOSS: 1.684487 | EPOCH = [1/3] | TIME ELAPSED =23.3Mins
# ITERATION:[142/907] | LOSS: 1.697216 | EPOCH = [1/3] | TIME ELAPSED =23.46Mins
# ITERATION:[143/907] | LOSS: 1.607007 | EPOCH = [1/3] | TIME ELAPSED =23.61Mins
# ITERATION:[144/907] | LOSS: 1.643508 | EPOCH = [1/3] | TIME ELAPSED =23.78Mins
# ITERATION:[145/907] | LOSS: 1.544579 | EPOCH = [1/3] | TIME ELAPSED =23.95Mins
# ITERATION:[146/907] | LOSS: 1.485943 | EPOCH = [1/3] | TIME ELAPSED =24.11Mins
# ITERATION:[147/907] | LOSS: 1.525799 | EPOCH = [1/3] | TIME ELAPSED =24.28Mins
# ITERATION:[148/907] | LOSS: 1.480524 | EPOCH = [1/3] | TIME ELAPSED =24.52Mins
# ITERATION:[149/907] | LOSS: 1.621769 | EPOCH = [1/3] | TIME ELAPSED =24.68Mins
# ITERATION:[150/907] | LOSS: 1.528426 | EPOCH = [1/3] | TIME ELAPSED =24.86Mins
# ITERATION:[151/907] | LOSS: 1.496975 | EPOCH = [1/3] | TIME ELAPSED =25.03Mins
# ITERATION:[152/907] | LOSS: 1.602732 | EPOCH = [1/3] | TIME ELAPSED =25.19Mins
# ITERATION:[153/907] | LOSS: 1.471263 | EPOCH = [1/3] | TIME ELAPSED =25.33Mins
# ITERATION:[154/907] | LOSS: 1.602094 | EPOCH = [1/3] | TIME ELAPSED =25.48Mins
# ITERATION:[155/907] | LOSS: 1.522639 | EPOCH = [1/3] | TIME ELAPSED =25.66Mins
# ITERATION:[156/907] | LOSS: 1.609077 | EPOCH = [1/3] | TIME ELAPSED =28.13Mins
# ITERATION:[157/907] | LOSS: 1.548431 | EPOCH = [1/3] | TIME ELAPSED =28.59Mins
# ITERATION:[158/907] | LOSS: 1.530692 | EPOCH = [1/3] | TIME ELAPSED =28.91Mins
# ITERATION:[159/907] | LOSS: 1.592595 | EPOCH = [1/3] | TIME ELAPSED =29.21Mins
# ITERATION:[160/907] | LOSS: 1.563775 | EPOCH = [1/3] | TIME ELAPSED =29.5Mins
# ITERATION:[161/907] | LOSS: 1.640348 | EPOCH = [1/3] | TIME ELAPSED =29.73Mins
# ITERATION:[162/907] | LOSS: 1.605406 | EPOCH = [1/3] | TIME ELAPSED =29.94Mins
# ITERATION:[163/907] | LOSS: 1.59378 | EPOCH = [1/3] | TIME ELAPSED =30.17Mins
# ITERATION:[164/907] | LOSS: 1.459419 | EPOCH = [1/3] | TIME ELAPSED =30.39Mins
# ITERATION:[165/907] | LOSS: 1.607912 | EPOCH = [1/3] | TIME ELAPSED =30.58Mins
# ITERATION:[166/907] | LOSS: 1.619452 | EPOCH = [1/3] | TIME ELAPSED =30.74Mins
# ITERATION:[167/907] | LOSS: 1.50397 | EPOCH = [1/3] | TIME ELAPSED =30.91Mins
# ITERATION:[168/907] | LOSS: 1.629229 | EPOCH = [1/3] | TIME ELAPSED =31.11Mins
# ITERATION:[169/907] | LOSS: 1.441892 | EPOCH = [1/3] | TIME ELAPSED =31.27Mins
# ITERATION:[170/907] | LOSS: 1.598868 | EPOCH = [1/3] | TIME ELAPSED =31.47Mins
# ITERATION:[171/907] | LOSS: 1.565579 | EPOCH = [1/3] | TIME ELAPSED =31.63Mins
# ITERATION:[172/907] | LOSS: 1.50971 | EPOCH = [1/3] | TIME ELAPSED =31.8Mins
# ITERATION:[173/907] | LOSS: 1.538839 | EPOCH = [1/3] | TIME ELAPSED =32.0Mins
# ITERATION:[174/907] | LOSS: 1.471476 | EPOCH = [1/3] | TIME ELAPSED =32.17Mins
# ITERATION:[175/907] | LOSS: 1.494373 | EPOCH = [1/3] | TIME ELAPSED =32.35Mins
# ITERATION:[176/907] | LOSS: 1.689523 | EPOCH = [1/3] | TIME ELAPSED =32.52Mins
# ITERATION:[177/907] | LOSS: 1.580617 | EPOCH = [1/3] | TIME ELAPSED =32.67Mins
# ITERATION:[178/907] | LOSS: 1.580089 | EPOCH = [1/3] | TIME ELAPSED =32.83Mins
# ITERATION:[179/907] | LOSS: 1.569298 | EPOCH = [1/3] | TIME ELAPSED =32.98Mins
# ITERATION:[180/907] | LOSS: 1.477989 | EPOCH = [1/3] | TIME ELAPSED =33.17Mins
# ITERATION:[181/907] | LOSS: 1.516046 | EPOCH = [1/3] | TIME ELAPSED =33.35Mins
# ITERATION:[182/907] | LOSS: 1.535134 | EPOCH = [1/3] | TIME ELAPSED =33.55Mins
# ITERATION:[183/907] | LOSS: 1.479851 | EPOCH = [1/3] | TIME ELAPSED =33.7Mins
# ITERATION:[184/907] | LOSS: 1.472036 | EPOCH = [1/3] | TIME ELAPSED =33.85Mins
# ITERATION:[185/907] | LOSS: 1.521208 | EPOCH = [1/3] | TIME ELAPSED =34.0Mins
# ITERATION:[186/907] | LOSS: 1.535764 | EPOCH = [1/3] | TIME ELAPSED =34.14Mins
# ITERATION:[187/907] | LOSS: 1.653589 | EPOCH = [1/3] | TIME ELAPSED =34.3Mins
# ITERATION:[188/907] | LOSS: 1.606404 | EPOCH = [1/3] | TIME ELAPSED =34.46Mins
# ITERATION:[189/907] | LOSS: 1.491597 | EPOCH = [1/3] | TIME ELAPSED =34.61Mins
# ITERATION:[190/907] | LOSS: 1.496795 | EPOCH = [1/3] | TIME ELAPSED =35.06Mins
# ITERATION:[191/907] | LOSS: 1.588222 | EPOCH = [1/3] | TIME ELAPSED =35.2Mins
# ITERATION:[192/907] | LOSS: 1.527518 | EPOCH = [1/3] | TIME ELAPSED =35.34Mins
# ITERATION:[193/907] | LOSS: 1.523038 | EPOCH = [1/3] | TIME ELAPSED =35.49Mins
# ITERATION:[194/907] | LOSS: 1.683173 | EPOCH = [1/3] | TIME ELAPSED =35.66Mins
# ITERATION:[195/907] | LOSS: 1.476373 | EPOCH = [1/3] | TIME ELAPSED =35.81Mins
# ITERATION:[196/907] | LOSS: 1.489349 | EPOCH = [1/3] | TIME ELAPSED =36.05Mins
# ITERATION:[197/907] | LOSS: 1.489558 | EPOCH = [1/3] | TIME ELAPSED =36.2Mins
# ITERATION:[198/907] | LOSS: 1.512158 | EPOCH = [1/3] | TIME ELAPSED =36.35Mins
# ITERATION:[199/907] | LOSS: 1.410384 | EPOCH = [1/3] | TIME ELAPSED =36.51Mins
# ITERATION:[200/907] | LOSS: 1.511547 | EPOCH = [1/3] | TIME ELAPSED =36.69Mins
# ITERATION:[201/907] | LOSS: 1.572197 | EPOCH = [1/3] | TIME ELAPSED =36.83Mins
# ITERATION:[202/907] | LOSS: 1.455382 | EPOCH = [1/3] | TIME ELAPSED =36.98Mins
# ITERATION:[203/907] | LOSS: 1.512253 | EPOCH = [1/3] | TIME ELAPSED =37.2Mins
# ITERATION:[204/907] | LOSS: 1.544316 | EPOCH = [1/3] | TIME ELAPSED =37.36Mins
# ITERATION:[205/907] | LOSS: 1.498459 | EPOCH = [1/3] | TIME ELAPSED =37.53Mins
# ITERATION:[206/907] | LOSS: 1.445392 | EPOCH = [1/3] | TIME ELAPSED =37.67Mins
# ITERATION:[207/907] | LOSS: 1.444855 | EPOCH = [1/3] | TIME ELAPSED =37.84Mins
# ITERATION:[208/907] | LOSS: 1.568799 | EPOCH = [1/3] | TIME ELAPSED =37.98Mins
# ITERATION:[209/907] | LOSS: 1.491161 | EPOCH = [1/3] | TIME ELAPSED =38.14Mins
# ITERATION:[210/907] | LOSS: 1.535465 | EPOCH = [1/3] | TIME ELAPSED =38.3Mins
# ITERATION:[211/907] | LOSS: 1.548637 | EPOCH = [1/3] | TIME ELAPSED =38.47Mins
# ITERATION:[212/907] | LOSS: 1.578635 | EPOCH = [1/3] | TIME ELAPSED =38.65Mins
# ITERATION:[213/907] | LOSS: 1.490606 | EPOCH = [1/3] | TIME ELAPSED =38.79Mins
# ITERATION:[214/907] | LOSS: 1.597787 | EPOCH = [1/3] | TIME ELAPSED =38.98Mins
# ITERATION:[215/907] | LOSS: 1.446959 | EPOCH = [1/3] | TIME ELAPSED =39.12Mins
# ITERATION:[216/907] | LOSS: 1.493651 | EPOCH = [1/3] | TIME ELAPSED =39.28Mins
# ITERATION:[217/907] | LOSS: 1.616055 | EPOCH = [1/3] | TIME ELAPSED =39.42Mins
# ITERATION:[218/907] | LOSS: 1.470453 | EPOCH = [1/3] | TIME ELAPSED =39.57Mins
# ITERATION:[219/907] | LOSS: 1.590658 | EPOCH = [1/3] | TIME ELAPSED =39.77Mins
# ITERATION:[220/907] | LOSS: 1.541971 | EPOCH = [1/3] | TIME ELAPSED =39.92Mins
# ITERATION:[221/907] | LOSS: 1.479473 | EPOCH = [1/3] | TIME ELAPSED =40.07Mins
# ITERATION:[222/907] | LOSS: 1.480252 | EPOCH = [1/3] | TIME ELAPSED =40.25Mins
# ITERATION:[223/907] | LOSS: 1.539499 | EPOCH = [1/3] | TIME ELAPSED =40.4Mins
# ITERATION:[224/907] | LOSS: 1.453801 | EPOCH = [1/3] | TIME ELAPSED =40.54Mins
# ITERATION:[225/907] | LOSS: 1.476722 | EPOCH = [1/3] | TIME ELAPSED =40.7Mins
# ITERATION:[226/907] | LOSS: 1.504427 | EPOCH = [1/3] | TIME ELAPSED =40.84Mins
# ITERATION:[227/907] | LOSS: 1.508827 | EPOCH = [1/3] | TIME ELAPSED =41.0Mins
# ITERATION:[228/907] | LOSS: 1.458533 | EPOCH = [1/3] | TIME ELAPSED =41.14Mins
# ITERATION:[229/907] | LOSS: 1.512309 | EPOCH = [1/3] | TIME ELAPSED =41.29Mins
# ITERATION:[230/907] | LOSS: 1.509566 | EPOCH = [1/3] | TIME ELAPSED =41.45Mins
# ITERATION:[231/907] | LOSS: 1.608172 | EPOCH = [1/3] | TIME ELAPSED =41.61Mins
# ITERATION:[232/907] | LOSS: 1.570308 | EPOCH = [1/3] | TIME ELAPSED =41.76Mins
# ITERATION:[233/907] | LOSS: 1.592732 | EPOCH = [1/3] | TIME ELAPSED =41.91Mins
# ITERATION:[234/907] | LOSS: 1.531894 | EPOCH = [1/3] | TIME ELAPSED =42.06Mins
# ITERATION:[235/907] | LOSS: 1.467004 | EPOCH = [1/3] | TIME ELAPSED =42.23Mins
# ITERATION:[236/907] | LOSS: 1.547786 | EPOCH = [1/3] | TIME ELAPSED =42.37Mins
# ITERATION:[237/907] | LOSS: 1.428726 | EPOCH = [1/3] | TIME ELAPSED =42.53Mins
# ITERATION:[238/907] | LOSS: 1.518055 | EPOCH = [1/3] | TIME ELAPSED =42.69Mins
# ITERATION:[239/907] | LOSS: 1.500586 | EPOCH = [1/3] | TIME ELAPSED =42.82Mins
# ITERATION:[240/907] | LOSS: 1.544877 | EPOCH = [1/3] | TIME ELAPSED =42.99Mins
# ITERATION:[241/907] | LOSS: 1.519637 | EPOCH = [1/3] | TIME ELAPSED =43.14Mins
# ITERATION:[242/907] | LOSS: 1.490783 | EPOCH = [1/3] | TIME ELAPSED =43.3Mins
# ITERATION:[243/907] | LOSS: 1.398074 | EPOCH = [1/3] | TIME ELAPSED =43.44Mins
# ITERATION:[244/907] | LOSS: 1.53772 | EPOCH = [1/3] | TIME ELAPSED =43.59Mins
# ITERATION:[245/907] | LOSS: 1.530266 | EPOCH = [1/3] | TIME ELAPSED =43.75Mins
# ITERATION:[246/907] | LOSS: 1.498819 | EPOCH = [1/3] | TIME ELAPSED =43.92Mins
# ITERATION:[247/907] | LOSS: 1.573961 | EPOCH = [1/3] | TIME ELAPSED =44.08Mins
# ITERATION:[248/907] | LOSS: 1.560759 | EPOCH = [1/3] | TIME ELAPSED =44.24Mins
# ITERATION:[249/907] | LOSS: 1.626854 | EPOCH = [1/3] | TIME ELAPSED =44.39Mins
# ITERATION:[250/907] | LOSS: 1.529839 | EPOCH = [1/3] | TIME ELAPSED =44.55Mins
# ITERATION:[251/907] | LOSS: 1.378492 | EPOCH = [1/3] | TIME ELAPSED =44.71Mins
# ITERATION:[252/907] | LOSS: 1.48893 | EPOCH = [1/3] | TIME ELAPSED =44.88Mins
# ITERATION:[253/907] | LOSS: 1.525943 | EPOCH = [1/3] | TIME ELAPSED =45.03Mins
# ITERATION:[254/907] | LOSS: 1.526523 | EPOCH = [1/3] | TIME ELAPSED =45.18Mins
# ITERATION:[255/907] | LOSS: 1.564484 | EPOCH = [1/3] | TIME ELAPSED =45.35Mins
# ITERATION:[256/907] | LOSS: 1.522506 | EPOCH = [1/3] | TIME ELAPSED =45.5Mins
# ITERATION:[257/907] | LOSS: 1.55589 | EPOCH = [1/3] | TIME ELAPSED =45.65Mins
# ITERATION:[258/907] | LOSS: 1.437598 | EPOCH = [1/3] | TIME ELAPSED =45.79Mins
# ITERATION:[259/907] | LOSS: 1.560771 | EPOCH = [1/3] | TIME ELAPSED =45.94Mins
# ITERATION:[260/907] | LOSS: 1.492221 | EPOCH = [1/3] | TIME ELAPSED =46.11Mins
# ITERATION:[261/907] | LOSS: 1.40659 | EPOCH = [1/3] | TIME ELAPSED =46.25Mins
# ITERATION:[262/907] | LOSS: 1.534834 | EPOCH = [1/3] | TIME ELAPSED =46.4Mins
# ITERATION:[263/907] | LOSS: 1.417932 | EPOCH = [1/3] | TIME ELAPSED =46.57Mins
# ITERATION:[264/907] | LOSS: 1.561116 | EPOCH = [1/3] | TIME ELAPSED =46.72Mins
# ITERATION:[265/907] | LOSS: 1.478078 | EPOCH = [1/3] | TIME ELAPSED =46.89Mins
# ITERATION:[266/907] | LOSS: 1.54957 | EPOCH = [1/3] | TIME ELAPSED =47.04Mins
# ITERATION:[267/907] | LOSS: 1.513859 | EPOCH = [1/3] | TIME ELAPSED =47.2Mins
# ITERATION:[268/907] | LOSS: 1.526092 | EPOCH = [1/3] | TIME ELAPSED =47.34Mins
# ITERATION:[269/907] | LOSS: 1.502777 | EPOCH = [1/3] | TIME ELAPSED =47.47Mins
# ITERATION:[270/907] | LOSS: 1.445063 | EPOCH = [1/3] | TIME ELAPSED =47.65Mins
# ITERATION:[271/907] | LOSS: 1.548836 | EPOCH = [1/3] | TIME ELAPSED =47.81Mins
# ITERATION:[272/907] | LOSS: 1.498013 | EPOCH = [1/3] | TIME ELAPSED =47.97Mins
# ITERATION:[273/907] | LOSS: 1.46701 | EPOCH = [1/3] | TIME ELAPSED =48.12Mins
# ITERATION:[274/907] | LOSS: 1.492449 | EPOCH = [1/3] | TIME ELAPSED =48.29Mins
# ITERATION:[275/907] | LOSS: 1.493094 | EPOCH = [1/3] | TIME ELAPSED =48.44Mins
# ITERATION:[276/907] | LOSS: 1.467549 | EPOCH = [1/3] | TIME ELAPSED =48.61Mins
# ITERATION:[277/907] | LOSS: 1.422026 | EPOCH = [1/3] | TIME ELAPSED =48.75Mins
# ITERATION:[278/907] | LOSS: 1.652748 | EPOCH = [1/3] | TIME ELAPSED =48.9Mins
# ITERATION:[279/907] | LOSS: 1.459564 | EPOCH = [1/3] | TIME ELAPSED =49.05Mins
# ITERATION:[280/907] | LOSS: 1.381462 | EPOCH = [1/3] | TIME ELAPSED =49.21Mins
# ITERATION:[281/907] | LOSS: 1.531381 | EPOCH = [1/3] | TIME ELAPSED =49.34Mins
# ITERATION:[282/907] | LOSS: 1.386813 | EPOCH = [1/3] | TIME ELAPSED =49.49Mins
# ITERATION:[283/907] | LOSS: 1.534484 | EPOCH = [1/3] | TIME ELAPSED =49.65Mins
# ITERATION:[284/907] | LOSS: 1.513592 | EPOCH = [1/3] | TIME ELAPSED =49.81Mins
# ITERATION:[285/907] | LOSS: 1.517268 | EPOCH = [1/3] | TIME ELAPSED =49.96Mins
# ITERATION:[286/907] | LOSS: 1.404356 | EPOCH = [1/3] | TIME ELAPSED =50.11Mins
# ITERATION:[287/907] | LOSS: 1.460354 | EPOCH = [1/3] | TIME ELAPSED =50.26Mins
# ITERATION:[288/907] | LOSS: 1.508491 | EPOCH = [1/3] | TIME ELAPSED =50.43Mins
# ITERATION:[289/907] | LOSS: 1.522556 | EPOCH = [1/3] | TIME ELAPSED =50.6Mins
# ITERATION:[290/907] | LOSS: 1.393292 | EPOCH = [1/3] | TIME ELAPSED =50.77Mins
# ITERATION:[291/907] | LOSS: 1.545628 | EPOCH = [1/3] | TIME ELAPSED =50.93Mins
# ITERATION:[292/907] | LOSS: 1.531317 | EPOCH = [1/3] | TIME ELAPSED =51.09Mins
# ITERATION:[293/907] | LOSS: 1.449102 | EPOCH = [1/3] | TIME ELAPSED =51.24Mins
# ITERATION:[294/907] | LOSS: 1.385752 | EPOCH = [1/3] | TIME ELAPSED =51.39Mins
# ITERATION:[295/907] | LOSS: 1.472118 | EPOCH = [1/3] | TIME ELAPSED =51.54Mins
# ITERATION:[296/907] | LOSS: 1.551904 | EPOCH = [1/3] | TIME ELAPSED =51.7Mins
# ITERATION:[297/907] | LOSS: 1.588216 | EPOCH = [1/3] | TIME ELAPSED =51.85Mins
# ITERATION:[298/907] | LOSS: 1.417278 | EPOCH = [1/3] | TIME ELAPSED =52.0Mins
# ITERATION:[299/907] | LOSS: 1.515408 | EPOCH = [1/3] | TIME ELAPSED =52.16Mins
# ITERATION:[300/907] | LOSS: 1.421967 | EPOCH = [1/3] | TIME ELAPSED =52.33Mins
# ITERATION:[301/907] | LOSS: 1.471378 | EPOCH = [1/3] | TIME ELAPSED =52.47Mins
# ITERATION:[302/907] | LOSS: 1.446653 | EPOCH = [1/3] | TIME ELAPSED =52.62Mins
# ITERATION:[303/907] | LOSS: 1.492705 | EPOCH = [1/3] | TIME ELAPSED =52.78Mins
# ITERATION:[304/907] | LOSS: 1.46025 | EPOCH = [1/3] | TIME ELAPSED =52.93Mins
# ITERATION:[305/907] | LOSS: 1.490603 | EPOCH = [1/3] | TIME ELAPSED =53.1Mins
# ITERATION:[306/907] | LOSS: 1.462127 | EPOCH = [1/3] | TIME ELAPSED =53.25Mins
# ITERATION:[307/907] | LOSS: 1.431793 | EPOCH = [1/3] | TIME ELAPSED =53.39Mins
# ITERATION:[308/907] | LOSS: 1.546289 | EPOCH = [1/3] | TIME ELAPSED =53.54Mins
# ITERATION:[309/907] | LOSS: 1.574971 | EPOCH = [1/3] | TIME ELAPSED =53.7Mins
# ITERATION:[310/907] | LOSS: 1.533705 | EPOCH = [1/3] | TIME ELAPSED =53.86Mins
# ITERATION:[311/907] | LOSS: 1.426082 | EPOCH = [1/3] | TIME ELAPSED =54.01Mins
# ITERATION:[312/907] | LOSS: 1.319536 | EPOCH = [1/3] | TIME ELAPSED =54.14Mins
# ITERATION:[313/907] | LOSS: 1.42279 | EPOCH = [1/3] | TIME ELAPSED =54.28Mins
# ITERATION:[314/907] | LOSS: 1.386279 | EPOCH = [1/3] | TIME ELAPSED =54.45Mins
# ITERATION:[315/907] | LOSS: 1.536876 | EPOCH = [1/3] | TIME ELAPSED =54.6Mins
# ITERATION:[316/907] | LOSS: 1.387886 | EPOCH = [1/3] | TIME ELAPSED =54.76Mins
# ITERATION:[317/907] | LOSS: 1.476871 | EPOCH = [1/3] | TIME ELAPSED =54.9Mins
# ITERATION:[318/907] | LOSS: 1.36992 | EPOCH = [1/3] | TIME ELAPSED =55.04Mins
# ITERATION:[319/907] | LOSS: 1.467697 | EPOCH = [1/3] | TIME ELAPSED =55.18Mins
# ITERATION:[320/907] | LOSS: 1.42976 | EPOCH = [1/3] | TIME ELAPSED =55.36Mins
# ITERATION:[321/907] | LOSS: 1.499098 | EPOCH = [1/3] | TIME ELAPSED =55.51Mins
# ITERATION:[322/907] | LOSS: 1.408905 | EPOCH = [1/3] | TIME ELAPSED =55.66Mins
# ITERATION:[323/907] | LOSS: 1.554359 | EPOCH = [1/3] | TIME ELAPSED =55.8Mins
# ITERATION:[324/907] | LOSS: 1.378242 | EPOCH = [1/3] | TIME ELAPSED =55.94Mins
# ITERATION:[325/907] | LOSS: 1.470327 | EPOCH = [1/3] | TIME ELAPSED =56.12Mins
# ITERATION:[326/907] | LOSS: 1.4355 | EPOCH = [1/3] | TIME ELAPSED =56.26Mins
# ITERATION:[327/907] | LOSS: 1.454254 | EPOCH = [1/3] | TIME ELAPSED =56.4Mins
# ITERATION:[328/907] | LOSS: 1.359728 | EPOCH = [1/3] | TIME ELAPSED =56.55Mins
# ITERATION:[329/907] | LOSS: 1.435136 | EPOCH = [1/3] | TIME ELAPSED =56.7Mins
# ITERATION:[330/907] | LOSS: 1.487528 | EPOCH = [1/3] | TIME ELAPSED =56.87Mins
# ITERATION:[331/907] | LOSS: 1.432743 | EPOCH = [1/3] | TIME ELAPSED =57.01Mins
# ITERATION:[332/907] | LOSS: 1.457849 | EPOCH = [1/3] | TIME ELAPSED =57.17Mins
# ITERATION:[333/907] | LOSS: 1.4804 | EPOCH = [1/3] | TIME ELAPSED =57.32Mins
# ITERATION:[334/907] | LOSS: 1.446708 | EPOCH = [1/3] | TIME ELAPSED =57.47Mins
# ITERATION:[335/907] | LOSS: 1.439213 | EPOCH = [1/3] | TIME ELAPSED =57.63Mins
# ITERATION:[336/907] | LOSS: 1.328349 | EPOCH = [1/3] | TIME ELAPSED =57.77Mins
# ITERATION:[337/907] | LOSS: 1.45721 | EPOCH = [1/3] | TIME ELAPSED =57.93Mins
# ITERATION:[338/907] | LOSS: 1.507192 | EPOCH = [1/3] | TIME ELAPSED =58.08Mins
# ITERATION:[339/907] | LOSS: 1.392526 | EPOCH = [1/3] | TIME ELAPSED =58.23Mins
# ITERATION:[340/907] | LOSS: 1.561686 | EPOCH = [1/3] | TIME ELAPSED =58.38Mins
# ITERATION:[341/907] | LOSS: 1.454812 | EPOCH = [1/3] | TIME ELAPSED =58.54Mins
# ITERATION:[342/907] | LOSS: 1.453224 | EPOCH = [1/3] | TIME ELAPSED =58.72Mins
# ITERATION:[343/907] | LOSS: 1.405782 | EPOCH = [1/3] | TIME ELAPSED =58.88Mins
# ITERATION:[344/907] | LOSS: 1.448421 | EPOCH = [1/3] | TIME ELAPSED =59.01Mins
# ITERATION:[345/907] | LOSS: 1.394544 | EPOCH = [1/3] | TIME ELAPSED =59.19Mins
# ITERATION:[346/907] | LOSS: 1.499488 | EPOCH = [1/3] | TIME ELAPSED =59.35Mins
# ITERATION:[347/907] | LOSS: 1.439984 | EPOCH = [1/3] | TIME ELAPSED =59.51Mins
# ITERATION:[348/907] | LOSS: 1.420786 | EPOCH = [1/3] | TIME ELAPSED =59.65Mins
# ITERATION:[349/907] | LOSS: 1.394095 | EPOCH = [1/3] | TIME ELAPSED =59.81Mins
# ITERATION:[350/907] | LOSS: 1.432805 | EPOCH = [1/3] | TIME ELAPSED =60.0Mins
# ITERATION:[351/907] | LOSS: 1.404567 | EPOCH = [1/3] | TIME ELAPSED =60.16Mins
# ITERATION:[352/907] | LOSS: 1.351586 | EPOCH = [1/3] | TIME ELAPSED =60.3Mins
# ITERATION:[353/907] | LOSS: 1.430773 | EPOCH = [1/3] | TIME ELAPSED =60.45Mins
# ITERATION:[354/907] | LOSS: 1.477888 | EPOCH = [1/3] | TIME ELAPSED =60.6Mins
# ITERATION:[355/907] | LOSS: 1.459701 | EPOCH = [1/3] | TIME ELAPSED =60.77Mins
# ITERATION:[356/907] | LOSS: 1.360917 | EPOCH = [1/3] | TIME ELAPSED =60.9Mins
# ITERATION:[357/907] | LOSS: 1.336868 | EPOCH = [1/3] | TIME ELAPSED =61.06Mins
# ITERATION:[358/907] | LOSS: 1.387082 | EPOCH = [1/3] | TIME ELAPSED =61.2Mins
# ITERATION:[359/907] | LOSS: 1.360379 | EPOCH = [1/3] | TIME ELAPSED =61.36Mins
# ITERATION:[360/907] | LOSS: 1.454611 | EPOCH = [1/3] | TIME ELAPSED =61.53Mins
# ITERATION:[361/907] | LOSS: 1.328034 | EPOCH = [1/3] | TIME ELAPSED =61.68Mins
# ITERATION:[362/907] | LOSS: 1.428938 | EPOCH = [1/3] | TIME ELAPSED =61.83Mins
# ITERATION:[363/907] | LOSS: 1.394426 | EPOCH = [1/3] | TIME ELAPSED =61.99Mins
# ITERATION:[364/907] | LOSS: 1.510592 | EPOCH = [1/3] | TIME ELAPSED =62.14Mins
# ITERATION:[365/907] | LOSS: 1.457202 | EPOCH = [1/3] | TIME ELAPSED =62.3Mins
# ITERATION:[366/907] | LOSS: 1.466886 | EPOCH = [1/3] | TIME ELAPSED =62.45Mins
# ITERATION:[367/907] | LOSS: 1.390694 | EPOCH = [1/3] | TIME ELAPSED =62.6Mins
# ITERATION:[368/907] | LOSS: 1.473633 | EPOCH = [1/3] | TIME ELAPSED =62.74Mins
# ITERATION:[369/907] | LOSS: 1.428518 | EPOCH = [1/3] | TIME ELAPSED =62.89Mins
# ITERATION:[370/907] | LOSS: 1.453977 | EPOCH = [1/3] | TIME ELAPSED =63.06Mins
# ITERATION:[371/907] | LOSS: 1.317546 | EPOCH = [1/3] | TIME ELAPSED =63.2Mins
# ITERATION:[372/907] | LOSS: 1.462485 | EPOCH = [1/3] | TIME ELAPSED =63.35Mins
# ITERATION:[373/907] | LOSS: 1.422172 | EPOCH = [1/3] | TIME ELAPSED =63.5Mins
# ITERATION:[374/907] | LOSS: 1.371803 | EPOCH = [1/3] | TIME ELAPSED =63.64Mins
# ITERATION:[375/907] | LOSS: 1.432136 | EPOCH = [1/3] | TIME ELAPSED =63.81Mins
# ITERATION:[376/907] | LOSS: 1.527833 | EPOCH = [1/3] | TIME ELAPSED =63.99Mins
# ITERATION:[377/907] | LOSS: 1.500227 | EPOCH = [1/3] | TIME ELAPSED =64.15Mins
# ITERATION:[378/907] | LOSS: 1.437509 | EPOCH = [1/3] | TIME ELAPSED =64.31Mins
# ITERATION:[379/907] | LOSS: 1.40921 | EPOCH = [1/3] | TIME ELAPSED =64.46Mins
# ITERATION:[380/907] | LOSS: 1.494356 | EPOCH = [1/3] | TIME ELAPSED =64.62Mins
# ITERATION:[381/907] | LOSS: 1.431988 | EPOCH = [1/3] | TIME ELAPSED =64.76Mins
# ITERATION:[382/907] | LOSS: 1.368218 | EPOCH = [1/3] | TIME ELAPSED =64.92Mins
# ITERATION:[383/907] | LOSS: 1.265862 | EPOCH = [1/3] | TIME ELAPSED =65.04Mins
# ITERATION:[384/907] | LOSS: 1.436985 | EPOCH = [1/3] | TIME ELAPSED =65.19Mins
# ITERATION:[385/907] | LOSS: 1.487733 | EPOCH = [1/3] | TIME ELAPSED =65.35Mins
# ITERATION:[386/907] | LOSS: 1.3934 | EPOCH = [1/3] | TIME ELAPSED =65.49Mins
# ITERATION:[387/907] | LOSS: 1.387086 | EPOCH = [1/3] | TIME ELAPSED =65.64Mins
# ITERATION:[388/907] | LOSS: 1.343613 | EPOCH = [1/3] | TIME ELAPSED =65.83Mins
# ITERATION:[389/907] | LOSS: 1.507291 | EPOCH = [1/3] | TIME ELAPSED =66.01Mins
# ITERATION:[390/907] | LOSS: 1.320606 | EPOCH = [1/3] | TIME ELAPSED =66.17Mins
# ITERATION:[391/907] | LOSS: 1.409171 | EPOCH = [1/3] | TIME ELAPSED =66.32Mins
# ITERATION:[392/907] | LOSS: 1.388118 | EPOCH = [1/3] | TIME ELAPSED =66.47Mins
# ITERATION:[393/907] | LOSS: 1.38695 | EPOCH = [1/3] | TIME ELAPSED =66.63Mins
# ITERATION:[394/907] | LOSS: 1.364064 | EPOCH = [1/3] | TIME ELAPSED =66.78Mins
# ITERATION:[395/907] | LOSS: 1.399585 | EPOCH = [1/3] | TIME ELAPSED =66.93Mins
# ITERATION:[396/907] | LOSS: 1.353374 | EPOCH = [1/3] | TIME ELAPSED =67.08Mins
# ITERATION:[397/907] | LOSS: 1.339631 | EPOCH = [1/3] | TIME ELAPSED =67.24Mins
# ITERATION:[398/907] | LOSS: 1.391187 | EPOCH = [1/3] | TIME ELAPSED =67.39Mins
# ITERATION:[399/907] | LOSS: 1.328442 | EPOCH = [1/3] | TIME ELAPSED =67.53Mins
# ITERATION:[400/907] | LOSS: 1.407017 | EPOCH = [1/3] | TIME ELAPSED =67.7Mins
# ITERATION:[401/907] | LOSS: 1.44825 | EPOCH = [1/3] | TIME ELAPSED =67.86Mins
# ITERATION:[402/907] | LOSS: 1.382009 | EPOCH = [1/3] | TIME ELAPSED =68.0Mins
# ITERATION:[403/907] | LOSS: 1.317045 | EPOCH = [1/3] | TIME ELAPSED =68.16Mins
# ITERATION:[404/907] | LOSS: 1.333147 | EPOCH = [1/3] | TIME ELAPSED =68.3Mins
# ITERATION:[405/907] | LOSS: 1.402894 | EPOCH = [1/3] | TIME ELAPSED =68.46Mins
# ITERATION:[406/907] | LOSS: 1.405267 | EPOCH = [1/3] | TIME ELAPSED =68.6Mins
# ITERATION:[407/907] | LOSS: 1.301756 | EPOCH = [1/3] | TIME ELAPSED =68.75Mins
# ITERATION:[408/907] | LOSS: 1.318015 | EPOCH = [1/3] | TIME ELAPSED =68.9Mins
# ITERATION:[409/907] | LOSS: 1.390896 | EPOCH = [1/3] | TIME ELAPSED =69.04Mins
# ITERATION:[410/907] | LOSS: 1.347208 | EPOCH = [1/3] | TIME ELAPSED =69.2Mins
# ITERATION:[411/907] | LOSS: 1.376928 | EPOCH = [1/3] | TIME ELAPSED =69.36Mins
# ITERATION:[412/907] | LOSS: 1.292591 | EPOCH = [1/3] | TIME ELAPSED =69.52Mins
# ITERATION:[413/907] | LOSS: 1.416955 | EPOCH = [1/3] | TIME ELAPSED =69.66Mins
# ITERATION:[414/907] | LOSS: 1.328802 | EPOCH = [1/3] | TIME ELAPSED =69.8Mins
# ITERATION:[415/907] | LOSS: 1.393088 | EPOCH = [1/3] | TIME ELAPSED =69.99Mins
# ITERATION:[416/907] | LOSS: 1.352149 | EPOCH = [1/3] | TIME ELAPSED =70.14Mins
# ITERATION:[417/907] | LOSS: 1.398649 | EPOCH = [1/3] | TIME ELAPSED =70.31Mins
# ITERATION:[418/907] | LOSS: 1.358643 | EPOCH = [1/3] | TIME ELAPSED =70.46Mins
# ITERATION:[419/907] | LOSS: 1.350571 | EPOCH = [1/3] | TIME ELAPSED =70.64Mins
# ITERATION:[420/907] | LOSS: 1.323145 | EPOCH = [1/3] | TIME ELAPSED =70.81Mins
# ITERATION:[421/907] | LOSS: 1.418516 | EPOCH = [1/3] | TIME ELAPSED =70.96Mins
# ITERATION:[422/907] | LOSS: 1.388838 | EPOCH = [1/3] | TIME ELAPSED =71.11Mins
# ITERATION:[423/907] | LOSS: 1.346645 | EPOCH = [1/3] | TIME ELAPSED =71.34Mins
# ITERATION:[424/907] | LOSS: 1.41482 | EPOCH = [1/3] | TIME ELAPSED =71.5Mins
# ITERATION:[425/907] | LOSS: 1.39778 | EPOCH = [1/3] | TIME ELAPSED =71.65Mins
# ITERATION:[426/907] | LOSS: 1.278896 | EPOCH = [1/3] | TIME ELAPSED =71.81Mins
# ITERATION:[427/907] | LOSS: 1.316282 | EPOCH = [1/3] | TIME ELAPSED =71.97Mins
# ITERATION:[428/907] | LOSS: 1.431927 | EPOCH = [1/3] | TIME ELAPSED =72.11Mins
# ITERATION:[429/907] | LOSS: 1.313027 | EPOCH = [1/3] | TIME ELAPSED =72.26Mins
# ITERATION:[430/907] | LOSS: 1.353374 | EPOCH = [1/3] | TIME ELAPSED =72.43Mins
# ITERATION:[431/907] | LOSS: 1.258389 | EPOCH = [1/3] | TIME ELAPSED =72.59Mins
# ITERATION:[432/907] | LOSS: 1.282137 | EPOCH = [1/3] | TIME ELAPSED =72.73Mins
# ITERATION:[433/907] | LOSS: 1.280567 | EPOCH = [1/3] | TIME ELAPSED =72.87Mins
# ITERATION:[434/907] | LOSS: 1.404569 | EPOCH = [1/3] | TIME ELAPSED =73.02Mins
# ITERATION:[435/907] | LOSS: 1.45848 | EPOCH = [1/3] | TIME ELAPSED =73.2Mins
# ITERATION:[436/907] | LOSS: 1.285399 | EPOCH = [1/3] | TIME ELAPSED =73.35Mins
# ITERATION:[437/907] | LOSS: 1.36771 | EPOCH = [1/3] | TIME ELAPSED =73.52Mins
# ITERATION:[438/907] | LOSS: 1.37015 | EPOCH = [1/3] | TIME ELAPSED =73.67Mins
# ITERATION:[439/907] | LOSS: 1.325332 | EPOCH = [1/3] | TIME ELAPSED =73.84Mins
# ITERATION:[440/907] | LOSS: 1.26892 | EPOCH = [1/3] | TIME ELAPSED =74.0Mins
# ITERATION:[441/907] | LOSS: 1.329198 | EPOCH = [1/3] | TIME ELAPSED =74.14Mins
# ITERATION:[442/907] | LOSS: 1.292897 | EPOCH = [1/3] | TIME ELAPSED =74.29Mins
# ITERATION:[443/907] | LOSS: 1.338613 | EPOCH = [1/3] | TIME ELAPSED =74.44Mins
# ITERATION:[444/907] | LOSS: 1.424811 | EPOCH = [1/3] | TIME ELAPSED =74.59Mins
# ITERATION:[445/907] | LOSS: 1.238122 | EPOCH = [1/3] | TIME ELAPSED =74.75Mins
# ITERATION:[446/907] | LOSS: 1.313645 | EPOCH = [1/3] | TIME ELAPSED =74.93Mins
# ITERATION:[447/907] | LOSS: 1.400787 | EPOCH = [1/3] | TIME ELAPSED =75.07Mins
# ITERATION:[448/907] | LOSS: 1.344603 | EPOCH = [1/3] | TIME ELAPSED =75.22Mins
# ITERATION:[449/907] | LOSS: 1.306621 | EPOCH = [1/3] | TIME ELAPSED =75.37Mins
# ITERATION:[450/907] | LOSS: 1.3512 | EPOCH = [1/3] | TIME ELAPSED =75.52Mins
# ITERATION:[451/907] | LOSS: 1.249015 | EPOCH = [1/3] | TIME ELAPSED =75.67Mins
# ITERATION:[452/907] | LOSS: 1.320595 | EPOCH = [1/3] | TIME ELAPSED =75.81Mins
# ITERATION:[453/907] | LOSS: 1.368252 | EPOCH = [1/3] | TIME ELAPSED =75.98Mins
# ITERATION:[454/907] | LOSS: 1.268528 | EPOCH = [1/3] | TIME ELAPSED =76.12Mins
# ITERATION:[455/907] | LOSS: 1.307881 | EPOCH = [1/3] | TIME ELAPSED =76.28Mins
# ITERATION:[456/907] | LOSS: 1.263192 | EPOCH = [1/3] | TIME ELAPSED =76.43Mins
# ITERATION:[457/907] | LOSS: 1.395673 | EPOCH = [1/3] | TIME ELAPSED =76.58Mins
# ITERATION:[458/907] | LOSS: 1.350672 | EPOCH = [1/3] | TIME ELAPSED =76.74Mins
# ITERATION:[459/907] | LOSS: 1.205437 | EPOCH = [1/3] | TIME ELAPSED =76.91Mins
# ITERATION:[460/907] | LOSS: 1.29662 | EPOCH = [1/3] | TIME ELAPSED =77.09Mins
# ITERATION:[461/907] | LOSS: 1.263971 | EPOCH = [1/3] | TIME ELAPSED =77.23Mins
# ITERATION:[462/907] | LOSS: 1.228074 | EPOCH = [1/3] | TIME ELAPSED =77.39Mins
# ITERATION:[463/907] | LOSS: 1.310107 | EPOCH = [1/3] | TIME ELAPSED =77.55Mins
# ITERATION:[464/907] | LOSS: 1.299112 | EPOCH = [1/3] | TIME ELAPSED =77.71Mins
# ITERATION:[465/907] | LOSS: 1.192683 | EPOCH = [1/3] | TIME ELAPSED =77.87Mins
# ITERATION:[466/907] | LOSS: 1.300324 | EPOCH = [1/3] | TIME ELAPSED =78.01Mins
# ITERATION:[467/907] | LOSS: 1.304994 | EPOCH = [1/3] | TIME ELAPSED =78.17Mins
# ITERATION:[468/907] | LOSS: 1.253171 | EPOCH = [1/3] | TIME ELAPSED =78.33Mins
# ITERATION:[469/907] | LOSS: 1.241978 | EPOCH = [1/3] | TIME ELAPSED =78.47Mins
# ITERATION:[470/907] | LOSS: 1.199071 | EPOCH = [1/3] | TIME ELAPSED =78.65Mins
# ITERATION:[471/907] | LOSS: 1.293676 | EPOCH = [1/3] | TIME ELAPSED =78.79Mins
# ITERATION:[472/907] | LOSS: 1.279303 | EPOCH = [1/3] | TIME ELAPSED =78.95Mins
# ITERATION:[473/907] | LOSS: 1.324505 | EPOCH = [1/3] | TIME ELAPSED =79.1Mins
# ITERATION:[474/907] | LOSS: 1.215152 | EPOCH = [1/3] | TIME ELAPSED =79.24Mins
# ITERATION:[475/907] | LOSS: 1.246934 | EPOCH = [1/3] | TIME ELAPSED =79.41Mins
# ITERATION:[476/907] | LOSS: 1.254863 | EPOCH = [1/3] | TIME ELAPSED =79.55Mins
# ITERATION:[477/907] | LOSS: 1.292208 | EPOCH = [1/3] | TIME ELAPSED =79.7Mins
# ITERATION:[478/907] | LOSS: 1.3031 | EPOCH = [1/3] | TIME ELAPSED =79.85Mins
# ITERATION:[479/907] | LOSS: 1.288759 | EPOCH = [1/3] | TIME ELAPSED =80.01Mins
# ITERATION:[480/907] | LOSS: 1.240035 | EPOCH = [1/3] | TIME ELAPSED =80.16Mins
# ITERATION:[481/907] | LOSS: 1.197925 | EPOCH = [1/3] | TIME ELAPSED =80.31Mins
# ITERATION:[482/907] | LOSS: 1.162762 | EPOCH = [1/3] | TIME ELAPSED =80.46Mins
# ITERATION:[483/907] | LOSS: 1.224894 | EPOCH = [1/3] | TIME ELAPSED =80.62Mins
# ITERATION:[484/907] | LOSS: 1.263324 | EPOCH = [1/3] | TIME ELAPSED =80.77Mins
# ITERATION:[485/907] | LOSS: 1.197794 | EPOCH = [1/3] | TIME ELAPSED =80.92Mins
# ITERATION:[486/907] | LOSS: 1.24695 | EPOCH = [1/3] | TIME ELAPSED =81.05Mins
# ITERATION:[487/907] | LOSS: 1.191158 | EPOCH = [1/3] | TIME ELAPSED =81.21Mins
# ITERATION:[488/907] | LOSS: 1.198716 | EPOCH = [1/3] | TIME ELAPSED =81.37Mins
# ITERATION:[489/907] | LOSS: 1.221609 | EPOCH = [1/3] | TIME ELAPSED =81.53Mins
# ITERATION:[490/907] | LOSS: 1.211567 | EPOCH = [1/3] | TIME ELAPSED =81.69Mins
# ITERATION:[491/907] | LOSS: 1.301937 | EPOCH = [1/3] | TIME ELAPSED =81.84Mins
# ITERATION:[492/907] | LOSS: 1.300008 | EPOCH = [1/3] | TIME ELAPSED =81.99Mins
# ITERATION:[493/907] | LOSS: 1.17087 | EPOCH = [1/3] | TIME ELAPSED =82.15Mins
# ITERATION:[494/907] | LOSS: 1.201973 | EPOCH = [1/3] | TIME ELAPSED =82.3Mins
# ITERATION:[495/907] | LOSS: 1.228777 | EPOCH = [1/3] | TIME ELAPSED =82.47Mins
# ITERATION:[496/907] | LOSS: 1.36261 | EPOCH = [1/3] | TIME ELAPSED =82.62Mins
# ITERATION:[497/907] | LOSS: 1.248643 | EPOCH = [1/3] | TIME ELAPSED =82.78Mins
# ITERATION:[498/907] | LOSS: 1.2689 | EPOCH = [1/3] | TIME ELAPSED =82.93Mins
# ITERATION:[499/907] | LOSS: 1.218404 | EPOCH = [1/3] | TIME ELAPSED =83.09Mins
# ITERATION:[500/907] | LOSS: 1.16934 | EPOCH = [1/3] | TIME ELAPSED =83.26Mins
# ITERATION:[501/907] | LOSS: 1.219942 | EPOCH = [1/3] | TIME ELAPSED =83.4Mins
# ITERATION:[502/907] | LOSS: 1.175415 | EPOCH = [1/3] | TIME ELAPSED =83.54Mins
# ITERATION:[503/907] | LOSS: 1.215442 | EPOCH = [1/3] | TIME ELAPSED =83.9Mins
# ITERATION:[504/907] | LOSS: 1.226342 | EPOCH = [1/3] | TIME ELAPSED =84.04Mins
# ITERATION:[505/907] | LOSS: 1.238486 | EPOCH = [1/3] | TIME ELAPSED =84.21Mins
# ITERATION:[506/907] | LOSS: 1.214537 | EPOCH = [1/3] | TIME ELAPSED =84.36Mins
# ITERATION:[507/907] | LOSS: 1.182042 | EPOCH = [1/3] | TIME ELAPSED =84.5Mins
# ITERATION:[508/907] | LOSS: 1.18202 | EPOCH = [1/3] | TIME ELAPSED =84.64Mins
# ITERATION:[509/907] | LOSS: 1.164807 | EPOCH = [1/3] | TIME ELAPSED =84.8Mins
# ITERATION:[510/907] | LOSS: 1.212847 | EPOCH = [1/3] | TIME ELAPSED =84.97Mins
# ITERATION:[511/907] | LOSS: 1.199712 | EPOCH = [1/3] | TIME ELAPSED =85.12Mins
# ITERATION:[512/907] | LOSS: 1.221079 | EPOCH = [1/3] | TIME ELAPSED =85.67Mins
# ITERATION:[513/907] | LOSS: 1.153085 | EPOCH = [1/3] | TIME ELAPSED =85.81Mins
# ITERATION:[514/907] | LOSS: 1.138988 | EPOCH = [1/3] | TIME ELAPSED =85.96Mins
# ITERATION:[515/907] | LOSS: 1.177041 | EPOCH = [1/3] | TIME ELAPSED =86.12Mins
# ITERATION:[516/907] | LOSS: 1.166076 | EPOCH = [1/3] | TIME ELAPSED =86.27Mins
# ITERATION:[517/907] | LOSS: 1.249849 | EPOCH = [1/3] | TIME ELAPSED =86.43Mins
# ITERATION:[518/907] | LOSS: 1.221869 | EPOCH = [1/3] | TIME ELAPSED =86.58Mins
# ITERATION:[519/907] | LOSS: 1.252363 | EPOCH = [1/3] | TIME ELAPSED =86.74Mins
# ITERATION:[520/907] | LOSS: 1.110924 | EPOCH = [1/3] | TIME ELAPSED =86.9Mins
# ITERATION:[521/907] | LOSS: 1.261789 | EPOCH = [1/3] | TIME ELAPSED =87.04Mins
# ITERATION:[522/907] | LOSS: 1.270398 | EPOCH = [1/3] | TIME ELAPSED =87.22Mins
# ITERATION:[523/907] | LOSS: 1.162345 | EPOCH = [1/3] | TIME ELAPSED =87.37Mins
# ITERATION:[524/907] | LOSS: 1.1859 | EPOCH = [1/3] | TIME ELAPSED =87.51Mins
# ITERATION:[525/907] | LOSS: 1.273215 | EPOCH = [1/3] | TIME ELAPSED =87.67Mins
# ITERATION:[526/907] | LOSS: 1.15589 | EPOCH = [1/3] | TIME ELAPSED =87.83Mins
# ITERATION:[527/907] | LOSS: 1.277412 | EPOCH = [1/3] | TIME ELAPSED =87.98Mins
# ITERATION:[528/907] | LOSS: 1.131492 | EPOCH = [1/3] | TIME ELAPSED =88.14Mins
# ITERATION:[529/907] | LOSS: 1.195565 | EPOCH = [1/3] | TIME ELAPSED =88.29Mins
# ITERATION:[530/907] | LOSS: 1.187654 | EPOCH = [1/3] | TIME ELAPSED =88.44Mins
# ITERATION:[531/907] | LOSS: 1.208 | EPOCH = [1/3] | TIME ELAPSED =88.61Mins
# ITERATION:[532/907] | LOSS: 1.230866 | EPOCH = [1/3] | TIME ELAPSED =88.74Mins
# ITERATION:[533/907] | LOSS: 1.201749 | EPOCH = [1/3] | TIME ELAPSED =88.89Mins
# ITERATION:[534/907] | LOSS: 1.085111 | EPOCH = [1/3] | TIME ELAPSED =89.03Mins
# ITERATION:[535/907] | LOSS: 1.13938 | EPOCH = [1/3] | TIME ELAPSED =89.19Mins
# ITERATION:[536/907] | LOSS: 1.189742 | EPOCH = [1/3] | TIME ELAPSED =89.34Mins
# ITERATION:[537/907] | LOSS: 1.222064 | EPOCH = [1/3] | TIME ELAPSED =89.49Mins
# ITERATION:[538/907] | LOSS: 1.165473 | EPOCH = [1/3] | TIME ELAPSED =89.64Mins
# ITERATION:[539/907] | LOSS: 1.16836 | EPOCH = [1/3] | TIME ELAPSED =89.79Mins
# ITERATION:[540/907] | LOSS: 1.236308 | EPOCH = [1/3] | TIME ELAPSED =89.96Mins
# ITERATION:[541/907] | LOSS: 1.132705 | EPOCH = [1/3] | TIME ELAPSED =90.1Mins
# ITERATION:[542/907] | LOSS: 1.100467 | EPOCH = [1/3] | TIME ELAPSED =90.23Mins
# ITERATION:[543/907] | LOSS: 1.125858 | EPOCH = [1/3] | TIME ELAPSED =90.37Mins
# ITERATION:[544/907] | LOSS: 1.151697 | EPOCH = [1/3] | TIME ELAPSED =90.52Mins
# ITERATION:[545/907] | LOSS: 1.114666 | EPOCH = [1/3] | TIME ELAPSED =90.67Mins
# ITERATION:[546/907] | LOSS: 1.202449 | EPOCH = [1/3] | TIME ELAPSED =90.83Mins
# ITERATION:[547/907] | LOSS: 1.240612 | EPOCH = [1/3] | TIME ELAPSED =90.98Mins
# ITERATION:[548/907] | LOSS: 1.155704 | EPOCH = [1/3] | TIME ELAPSED =91.13Mins
# ITERATION:[549/907] | LOSS: 1.212718 | EPOCH = [1/3] | TIME ELAPSED =91.27Mins
# ITERATION:[550/907] | LOSS: 1.128266 | EPOCH = [1/3] | TIME ELAPSED =91.55Mins
# ITERATION:[551/907] | LOSS: 1.156508 | EPOCH = [1/3] | TIME ELAPSED =91.69Mins
# ITERATION:[552/907] | LOSS: 1.244804 | EPOCH = [1/3] | TIME ELAPSED =91.84Mins
# ITERATION:[553/907] | LOSS: 1.119409 | EPOCH = [1/3] | TIME ELAPSED =91.99Mins
# ITERATION:[554/907] | LOSS: 1.170647 | EPOCH = [1/3] | TIME ELAPSED =92.14Mins
# ITERATION:[555/907] | LOSS: 1.177158 | EPOCH = [1/3] | TIME ELAPSED =92.29Mins
# ITERATION:[556/907] | LOSS: 1.215956 | EPOCH = [1/3] | TIME ELAPSED =92.44Mins
# ITERATION:[557/907] | LOSS: 1.217289 | EPOCH = [1/3] | TIME ELAPSED =92.59Mins
# ITERATION:[558/907] | LOSS: 1.130715 | EPOCH = [1/3] | TIME ELAPSED =92.75Mins
# ITERATION:[559/907] | LOSS: 1.14282 | EPOCH = [1/3] | TIME ELAPSED =92.91Mins
# ITERATION:[560/907] | LOSS: 1.126245 | EPOCH = [1/3] | TIME ELAPSED =93.1Mins
# ITERATION:[561/907] | LOSS: 1.198636 | EPOCH = [1/3] | TIME ELAPSED =93.27Mins
# ITERATION:[562/907] | LOSS: 1.138081 | EPOCH = [1/3] | TIME ELAPSED =93.43Mins
# ITERATION:[563/907] | LOSS: 1.187596 | EPOCH = [1/3] | TIME ELAPSED =93.57Mins
# ITERATION:[564/907] | LOSS: 1.090016 | EPOCH = [1/3] | TIME ELAPSED =93.7Mins
# ITERATION:[565/907] | LOSS: 1.227535 | EPOCH = [1/3] | TIME ELAPSED =93.87Mins
# ITERATION:[566/907] | LOSS: 1.120588 | EPOCH = [1/3] | TIME ELAPSED =94.04Mins
# ITERATION:[567/907] | LOSS: 1.248955 | EPOCH = [1/3] | TIME ELAPSED =94.19Mins
# ITERATION:[568/907] | LOSS: 1.125576 | EPOCH = [1/3] | TIME ELAPSED =94.34Mins
# ITERATION:[569/907] | LOSS: 1.245958 | EPOCH = [1/3] | TIME ELAPSED =94.49Mins
# ITERATION:[570/907] | LOSS: 1.143971 | EPOCH = [1/3] | TIME ELAPSED =94.64Mins
# ITERATION:[571/907] | LOSS: 1.128147 | EPOCH = [1/3] | TIME ELAPSED =94.78Mins
# ITERATION:[572/907] | LOSS: 1.15285 | EPOCH = [1/3] | TIME ELAPSED =94.93Mins
# ITERATION:[573/907] | LOSS: 1.191563 | EPOCH = [1/3] | TIME ELAPSED =95.1Mins
# ITERATION:[574/907] | LOSS: 1.105894 | EPOCH = [1/3] | TIME ELAPSED =95.25Mins
# ITERATION:[575/907] | LOSS: 1.092687 | EPOCH = [1/3] | TIME ELAPSED =95.41Mins
# ITERATION:[576/907] | LOSS: 1.219839 | EPOCH = [1/3] | TIME ELAPSED =95.55Mins
# ITERATION:[577/907] | LOSS: 1.174746 | EPOCH = [1/3] | TIME ELAPSED =95.69Mins
# ITERATION:[578/907] | LOSS: 1.107468 | EPOCH = [1/3] | TIME ELAPSED =95.84Mins
# ITERATION:[579/907] | LOSS: 1.136026 | EPOCH = [1/3] | TIME ELAPSED =95.99Mins
# ITERATION:[580/907] | LOSS: 1.162636 | EPOCH = [1/3] | TIME ELAPSED =96.15Mins
# ITERATION:[581/907] | LOSS: 1.138026 | EPOCH = [1/3] | TIME ELAPSED =96.31Mins
# ITERATION:[582/907] | LOSS: 1.190267 | EPOCH = [1/3] | TIME ELAPSED =96.45Mins
# ITERATION:[583/907] | LOSS: 1.251841 | EPOCH = [1/3] | TIME ELAPSED =96.59Mins
# ITERATION:[584/907] | LOSS: 1.218997 | EPOCH = [1/3] | TIME ELAPSED =96.75Mins
# ITERATION:[585/907] | LOSS: 1.12658 | EPOCH = [1/3] | TIME ELAPSED =96.89Mins
# ITERATION:[586/907] | LOSS: 1.151055 | EPOCH = [1/3] | TIME ELAPSED =97.05Mins
# ITERATION:[587/907] | LOSS: 1.083599 | EPOCH = [1/3] | TIME ELAPSED =97.21Mins
# ITERATION:[588/907] | LOSS: 1.229727 | EPOCH = [1/3] | TIME ELAPSED =97.36Mins
# ITERATION:[589/907] | LOSS: 1.086686 | EPOCH = [1/3] | TIME ELAPSED =97.49Mins
# ITERATION:[590/907] | LOSS: 1.152051 | EPOCH = [1/3] | TIME ELAPSED =97.65Mins
# ITERATION:[591/907] | LOSS: 1.253725 | EPOCH = [1/3] | TIME ELAPSED =97.8Mins
# ITERATION:[592/907] | LOSS: 1.197237 | EPOCH = [1/3] | TIME ELAPSED =97.94Mins
# ITERATION:[593/907] | LOSS: 1.169404 | EPOCH = [1/3] | TIME ELAPSED =98.11Mins
# ITERATION:[594/907] | LOSS: 1.189644 | EPOCH = [1/3] | TIME ELAPSED =98.27Mins
# ITERATION:[595/907] | LOSS: 1.155461 | EPOCH = [1/3] | TIME ELAPSED =98.45Mins
# ITERATION:[596/907] | LOSS: 1.164189 | EPOCH = [1/3] | TIME ELAPSED =98.6Mins
# ITERATION:[597/907] | LOSS: 1.072653 | EPOCH = [1/3] | TIME ELAPSED =98.76Mins
# ITERATION:[598/907] | LOSS: 1.183334 | EPOCH = [1/3] | TIME ELAPSED =98.91Mins
# ITERATION:[599/907] | LOSS: 1.16239 | EPOCH = [1/3] | TIME ELAPSED =99.07Mins
# ITERATION:[600/907] | LOSS: 1.205796 | EPOCH = [1/3] | TIME ELAPSED =99.25Mins
# ITERATION:[601/907] | LOSS: 1.139097 | EPOCH = [1/3] | TIME ELAPSED =99.4Mins
# ITERATION:[602/907] | LOSS: 1.201832 | EPOCH = [1/3] | TIME ELAPSED =99.56Mins
# ITERATION:[603/907] | LOSS: 1.130732 | EPOCH = [1/3] | TIME ELAPSED =99.71Mins
# ITERATION:[604/907] | LOSS: 1.141116 | EPOCH = [1/3] | TIME ELAPSED =99.87Mins
# ITERATION:[605/907] | LOSS: 1.192948 | EPOCH = [1/3] | TIME ELAPSED =100.03Mins
# ITERATION:[606/907] | LOSS: 1.159789 | EPOCH = [1/3] | TIME ELAPSED =100.24Mins
# ITERATION:[607/907] | LOSS: 1.15881 | EPOCH = [1/3] | TIME ELAPSED =100.4Mins
# ITERATION:[608/907] | LOSS: 1.09644 | EPOCH = [1/3] | TIME ELAPSED =100.55Mins
# ITERATION:[609/907] | LOSS: 1.16626 | EPOCH = [1/3] | TIME ELAPSED =100.71Mins
# ITERATION:[610/907] | LOSS: 1.199453 | EPOCH = [1/3] | TIME ELAPSED =100.87Mins
# ITERATION:[611/907] | LOSS: 1.195917 | EPOCH = [1/3] | TIME ELAPSED =101.03Mins
# ...
# ITERATION:[709/907] | LOSS: 0.877521 | EPOCH = [3/3] | TIME ELAPSED =236.52Mins
# ITERATION:[710/907] | LOSS: 0.939456 | EPOCH = [3/3] | TIME ELAPSED =236.58Mins
# ITERATION:[711/907] | LOSS: 0.880759 | EPOCH = [3/3] | TIME ELAPSED =236.63Mins
# ITERATION:[712/907] | LOSS: 0.879853 | EPOCH = [3/3] | TIME ELAPSED =236.67Mins
# ITERATION:[713/907] | LOSS: 0.953255 | EPOCH = [3/3] | TIME ELAPSED =236.71Mins
# ITERATION:[714/907] | LOSS: 0.911954 | EPOCH = [3/3] | TIME ELAPSED =236.76Mins
# ITERATION:[715/907] | LOSS: 0.911708 | EPOCH = [3/3] | TIME ELAPSED =236.82Mins
# ITERATION:[716/907] | LOSS: 0.915059 | EPOCH = [3/3] | TIME ELAPSED =236.87Mins
# ITERATION:[717/907] | LOSS: 0.918905 | EPOCH = [3/3] | TIME ELAPSED =236.91Mins
# ITERATION:[718/907] | LOSS: 0.896277 | EPOCH = [3/3] | TIME ELAPSED =236.95Mins
# ITERATION:[719/907] | LOSS: 0.911069 | EPOCH = [3/3] | TIME ELAPSED =237.0Mins
# ITERATION:[720/907] | LOSS: 0.903205 | EPOCH = [3/3] | TIME ELAPSED =237.06Mins
# ITERATION:[721/907] | LOSS: 0.863938 | EPOCH = [3/3] | TIME ELAPSED =237.11Mins
# ITERATION:[722/907] | LOSS: 0.899543 | EPOCH = [3/3] | TIME ELAPSED =237.15Mins
# ITERATION:[723/907] | LOSS: 0.929584 | EPOCH = [3/3] | TIME ELAPSED =237.19Mins
# ITERATION:[724/907] | LOSS: 0.962768 | EPOCH = [3/3] | TIME ELAPSED =237.24Mins
# ITERATION:[725/907] | LOSS: 0.859806 | EPOCH = [3/3] | TIME ELAPSED =237.3Mins
# ITERATION:[726/907] | LOSS: 0.849467 | EPOCH = [3/3] | TIME ELAPSED =237.34Mins
# ITERATION:[727/907] | LOSS: 0.885278 | EPOCH = [3/3] | TIME ELAPSED =237.39Mins
# ITERATION:[728/907] | LOSS: 0.922057 | EPOCH = [3/3] | TIME ELAPSED =237.43Mins
# ITERATION:[729/907] | LOSS: 0.868671 | EPOCH = [3/3] | TIME ELAPSED =237.48Mins
# ITERATION:[730/907] | LOSS: 0.901682 | EPOCH = [3/3] | TIME ELAPSED =237.54Mins
# ITERATION:[731/907] | LOSS: 0.935501 | EPOCH = [3/3] | TIME ELAPSED =237.59Mins
# ITERATION:[732/907] | LOSS: 0.860971 | EPOCH = [3/3] | TIME ELAPSED =237.63Mins
# ITERATION:[733/907] | LOSS: 0.925299 | EPOCH = [3/3] | TIME ELAPSED =237.67Mins
# ITERATION:[734/907] | LOSS: 0.875086 | EPOCH = [3/3] | TIME ELAPSED =237.72Mins
# ITERATION:[735/907] | LOSS: 0.968094 | EPOCH = [3/3] | TIME ELAPSED =237.78Mins
# ITERATION:[736/907] | LOSS: 0.927057 | EPOCH = [3/3] | TIME ELAPSED =237.82Mins
# ITERATION:[737/907] | LOSS: 0.944149 | EPOCH = [3/3] | TIME ELAPSED =237.87Mins
# ITERATION:[738/907] | LOSS: 0.828615 | EPOCH = [3/3] | TIME ELAPSED =237.92Mins
# ITERATION:[739/907] | LOSS: 0.83088 | EPOCH = [3/3] | TIME ELAPSED =237.97Mins
# ITERATION:[740/907] | LOSS: 0.978342 | EPOCH = [3/3] | TIME ELAPSED =238.02Mins
# ITERATION:[741/907] | LOSS: 0.896579 | EPOCH = [3/3] | TIME ELAPSED =238.07Mins
# ITERATION:[742/907] | LOSS: 0.863577 | EPOCH = [3/3] | TIME ELAPSED =238.11Mins
# ITERATION:[743/907] | LOSS: 0.963022 | EPOCH = [3/3] | TIME ELAPSED =238.16Mins
# ITERATION:[744/907] | LOSS: 0.950199 | EPOCH = [3/3] | TIME ELAPSED =238.2Mins
# ITERATION:[745/907] | LOSS: 0.949068 | EPOCH = [3/3] | TIME ELAPSED =238.26Mins
# ITERATION:[746/907] | LOSS: 0.961518 | EPOCH = [3/3] | TIME ELAPSED =238.31Mins
# ITERATION:[747/907] | LOSS: 0.918678 | EPOCH = [3/3] | TIME ELAPSED =238.35Mins
# ITERATION:[748/907] | LOSS: 0.942199 | EPOCH = [3/3] | TIME ELAPSED =238.4Mins
# ITERATION:[749/907] | LOSS: 0.903277 | EPOCH = [3/3] | TIME ELAPSED =238.44Mins
# ITERATION:[750/907] | LOSS: 0.977406 | EPOCH = [3/3] | TIME ELAPSED =238.5Mins
# ITERATION:[751/907] | LOSS: 0.904121 | EPOCH = [3/3] | TIME ELAPSED =238.54Mins
# ITERATION:[752/907] | LOSS: 0.845405 | EPOCH = [3/3] | TIME ELAPSED =238.59Mins
# ITERATION:[753/907] | LOSS: 0.936486 | EPOCH = [3/3] | TIME ELAPSED =238.63Mins
# ITERATION:[754/907] | LOSS: 0.923872 | EPOCH = [3/3] | TIME ELAPSED =238.68Mins
# ITERATION:[755/907] | LOSS: 0.890518 | EPOCH = [3/3] | TIME ELAPSED =238.74Mins
# ITERATION:[756/907] | LOSS: 0.856905 | EPOCH = [3/3] | TIME ELAPSED =238.78Mins
# ITERATION:[757/907] | LOSS: 0.916415 | EPOCH = [3/3] | TIME ELAPSED =238.83Mins
# ITERATION:[758/907] | LOSS: 0.923313 | EPOCH = [3/3] | TIME ELAPSED =238.87Mins
# ITERATION:[759/907] | LOSS: 0.867529 | EPOCH = [3/3] | TIME ELAPSED =238.92Mins
# ITERATION:[760/907] | LOSS: 0.960996 | EPOCH = [3/3] | TIME ELAPSED =238.98Mins
# ITERATION:[761/907] | LOSS: 0.895101 | EPOCH = [3/3] | TIME ELAPSED =239.02Mins
# ITERATION:[762/907] | LOSS: 0.833272 | EPOCH = [3/3] | TIME ELAPSED =239.07Mins
# ITERATION:[763/907] | LOSS: 0.906563 | EPOCH = [3/3] | TIME ELAPSED =239.11Mins
# ITERATION:[764/907] | LOSS: 0.961943 | EPOCH = [3/3] | TIME ELAPSED =239.16Mins
# ITERATION:[765/907] | LOSS: 0.853134 | EPOCH = [3/3] | TIME ELAPSED =239.22Mins
# ITERATION:[766/907] | LOSS: 1.067119 | EPOCH = [3/3] | TIME ELAPSED =239.26Mins
# ITERATION:[767/907] | LOSS: 0.866459 | EPOCH = [3/3] | TIME ELAPSED =239.3Mins
# ITERATION:[768/907] | LOSS: 0.883009 | EPOCH = [3/3] | TIME ELAPSED =239.35Mins
# ITERATION:[769/907] | LOSS: 0.855155 | EPOCH = [3/3] | TIME ELAPSED =239.39Mins
# ITERATION:[770/907] | LOSS: 0.866425 | EPOCH = [3/3] | TIME ELAPSED =239.46Mins
# ITERATION:[771/907] | LOSS: 0.878956 | EPOCH = [3/3] | TIME ELAPSED =239.5Mins
# ITERATION:[772/907] | LOSS: 0.858307 | EPOCH = [3/3] | TIME ELAPSED =239.55Mins
# ITERATION:[773/907] | LOSS: 0.90065 | EPOCH = [3/3] | TIME ELAPSED =239.59Mins
# ITERATION:[774/907] | LOSS: 0.974732 | EPOCH = [3/3] | TIME ELAPSED =239.64Mins
# ITERATION:[775/907] | LOSS: 0.873757 | EPOCH = [3/3] | TIME ELAPSED =239.7Mins
# ITERATION:[776/907] | LOSS: 0.959211 | EPOCH = [3/3] | TIME ELAPSED =239.75Mins
# ITERATION:[777/907] | LOSS: 0.824457 | EPOCH = [3/3] | TIME ELAPSED =239.79Mins
# ITERATION:[778/907] | LOSS: 0.896957 | EPOCH = [3/3] | TIME ELAPSED =239.84Mins
# ITERATION:[779/907] | LOSS: 0.946108 | EPOCH = [3/3] | TIME ELAPSED =239.89Mins
# ITERATION:[780/907] | LOSS: 0.956334 | EPOCH = [3/3] | TIME ELAPSED =239.95Mins
# ITERATION:[781/907] | LOSS: 0.926406 | EPOCH = [3/3] | TIME ELAPSED =239.99Mins
# ITERATION:[782/907] | LOSS: 0.932654 | EPOCH = [3/3] | TIME ELAPSED =240.04Mins
# ITERATION:[783/907] | LOSS: 0.871776 | EPOCH = [3/3] | TIME ELAPSED =240.08Mins
# ITERATION:[784/907] | LOSS: 0.948229 | EPOCH = [3/3] | TIME ELAPSED =240.13Mins
# ITERATION:[785/907] | LOSS: 0.876323 | EPOCH = [3/3] | TIME ELAPSED =240.19Mins
# ITERATION:[786/907] | LOSS: 0.883568 | EPOCH = [3/3] | TIME ELAPSED =240.23Mins
# ITERATION:[787/907] | LOSS: 0.862345 | EPOCH = [3/3] | TIME ELAPSED =240.28Mins
# ITERATION:[788/907] | LOSS: 0.912842 | EPOCH = [3/3] | TIME ELAPSED =240.32Mins
# ITERATION:[789/907] | LOSS: 0.86011 | EPOCH = [3/3] | TIME ELAPSED =240.37Mins
# ITERATION:[790/907] | LOSS: 0.909691 | EPOCH = [3/3] | TIME ELAPSED =240.43Mins
# ITERATION:[791/907] | LOSS: 0.849679 | EPOCH = [3/3] | TIME ELAPSED =240.47Mins
# ITERATION:[792/907] | LOSS: 0.844302 | EPOCH = [3/3] | TIME ELAPSED =240.52Mins
# ITERATION:[793/907] | LOSS: 0.886222 | EPOCH = [3/3] | TIME ELAPSED =240.56Mins
# ITERATION:[794/907] | LOSS: 0.925658 | EPOCH = [3/3] | TIME ELAPSED =240.61Mins
# ITERATION:[795/907] | LOSS: 0.904304 | EPOCH = [3/3] | TIME ELAPSED =240.67Mins
# ITERATION:[796/907] | LOSS: 0.904286 | EPOCH = [3/3] | TIME ELAPSED =240.71Mins
# ITERATION:[797/907] | LOSS: 0.916565 | EPOCH = [3/3] | TIME ELAPSED =240.76Mins
# ITERATION:[798/907] | LOSS: 0.971723 | EPOCH = [3/3] | TIME ELAPSED =240.8Mins
# ITERATION:[799/907] | LOSS: 0.887613 | EPOCH = [3/3] | TIME ELAPSED =240.85Mins
# ITERATION:[800/907] | LOSS: 0.865755 | EPOCH = [3/3] | TIME ELAPSED =240.91Mins
# ITERATION:[801/907] | LOSS: 0.839799 | EPOCH = [3/3] | TIME ELAPSED =240.95Mins
# ITERATION:[802/907] | LOSS: 0.974646 | EPOCH = [3/3] | TIME ELAPSED =241.0Mins
# ITERATION:[803/907] | LOSS: 0.850843 | EPOCH = [3/3] | TIME ELAPSED =241.04Mins
# ITERATION:[804/907] | LOSS: 0.945757 | EPOCH = [3/3] | TIME ELAPSED =241.09Mins
# ITERATION:[805/907] | LOSS: 0.923839 | EPOCH = [3/3] | TIME ELAPSED =241.15Mins
# ITERATION:[806/907] | LOSS: 0.940364 | EPOCH = [3/3] | TIME ELAPSED =241.19Mins
# ITERATION:[807/907] | LOSS: 0.926573 | EPOCH = [3/3] | TIME ELAPSED =241.24Mins
# ITERATION:[808/907] | LOSS: 0.904392 | EPOCH = [3/3] | TIME ELAPSED =241.28Mins
# ITERATION:[809/907] | LOSS: 0.95803 | EPOCH = [3/3] | TIME ELAPSED =241.33Mins
# ITERATION:[810/907] | LOSS: 0.853068 | EPOCH = [3/3] | TIME ELAPSED =241.39Mins
# ITERATION:[811/907] | LOSS: 0.859479 | EPOCH = [3/3] | TIME ELAPSED =241.43Mins
# ITERATION:[812/907] | LOSS: 0.963609 | EPOCH = [3/3] | TIME ELAPSED =241.48Mins
# ITERATION:[813/907] | LOSS: 0.883939 | EPOCH = [3/3] | TIME ELAPSED =241.52Mins
# ITERATION:[814/907] | LOSS: 0.907103 | EPOCH = [3/3] | TIME ELAPSED =241.57Mins
# ITERATION:[815/907] | LOSS: 0.935883 | EPOCH = [3/3] | TIME ELAPSED =241.63Mins
# ITERATION:[816/907] | LOSS: 0.883811 | EPOCH = [3/3] | TIME ELAPSED =241.67Mins
# ITERATION:[817/907] | LOSS: 0.896733 | EPOCH = [3/3] | TIME ELAPSED =241.72Mins
# ITERATION:[818/907] | LOSS: 0.946523 | EPOCH = [3/3] | TIME ELAPSED =241.76Mins
# ITERATION:[819/907] | LOSS: 0.867671 | EPOCH = [3/3] | TIME ELAPSED =241.81Mins
# ITERATION:[820/907] | LOSS: 0.8474 | EPOCH = [3/3] | TIME ELAPSED =241.86Mins
# ITERATION:[821/907] | LOSS: 0.913816 | EPOCH = [3/3] | TIME ELAPSED =241.91Mins
# ITERATION:[822/907] | LOSS: 0.885057 | EPOCH = [3/3] | TIME ELAPSED =241.95Mins
# ITERATION:[823/907] | LOSS: 0.904774 | EPOCH = [3/3] | TIME ELAPSED =241.99Mins
# ITERATION:[824/907] | LOSS: 0.952695 | EPOCH = [3/3] | TIME ELAPSED =242.04Mins
# ITERATION:[825/907] | LOSS: 0.858498 | EPOCH = [3/3] | TIME ELAPSED =242.1Mins
# ITERATION:[826/907] | LOSS: 0.888972 | EPOCH = [3/3] | TIME ELAPSED =242.14Mins
# ITERATION:[827/907] | LOSS: 0.896395 | EPOCH = [3/3] | TIME ELAPSED =242.19Mins
# ITERATION:[828/907] | LOSS: 0.888592 | EPOCH = [3/3] | TIME ELAPSED =242.23Mins
# ITERATION:[829/907] | LOSS: 0.880416 | EPOCH = [3/3] | TIME ELAPSED =242.28Mins
# ITERATION:[830/907] | LOSS: 0.870318 | EPOCH = [3/3] | TIME ELAPSED =242.34Mins
# ITERATION:[831/907] | LOSS: 0.889818 | EPOCH = [3/3] | TIME ELAPSED =242.38Mins
# ITERATION:[832/907] | LOSS: 0.938251 | EPOCH = [3/3] | TIME ELAPSED =242.42Mins
# ITERATION:[833/907] | LOSS: 0.910229 | EPOCH = [3/3] | TIME ELAPSED =242.47Mins
# ITERATION:[834/907] | LOSS: 0.939975 | EPOCH = [3/3] | TIME ELAPSED =242.51Mins
# ITERATION:[835/907] | LOSS: 0.939407 | EPOCH = [3/3] | TIME ELAPSED =242.57Mins
# ITERATION:[836/907] | LOSS: 0.889427 | EPOCH = [3/3] | TIME ELAPSED =242.62Mins
# ITERATION:[837/907] | LOSS: 0.826395 | EPOCH = [3/3] | TIME ELAPSED =242.66Mins
# ITERATION:[838/907] | LOSS: 0.908731 | EPOCH = [3/3] | TIME ELAPSED =242.7Mins
# ITERATION:[839/907] | LOSS: 0.863798 | EPOCH = [3/3] | TIME ELAPSED =242.74Mins
# ITERATION:[840/907] | LOSS: 0.924541 | EPOCH = [3/3] | TIME ELAPSED =242.81Mins
# ITERATION:[841/907] | LOSS: 0.835471 | EPOCH = [3/3] | TIME ELAPSED =242.85Mins
# ITERATION:[842/907] | LOSS: 0.915647 | EPOCH = [3/3] | TIME ELAPSED =242.89Mins
# ITERATION:[843/907] | LOSS: 0.931741 | EPOCH = [3/3] | TIME ELAPSED =242.94Mins
# ITERATION:[844/907] | LOSS: 0.887197 | EPOCH = [3/3] | TIME ELAPSED =242.99Mins
# ITERATION:[845/907] | LOSS: 0.87415 | EPOCH = [3/3] | TIME ELAPSED =243.05Mins
# ITERATION:[846/907] | LOSS: 0.959699 | EPOCH = [3/3] | TIME ELAPSED =243.09Mins
# ITERATION:[847/907] | LOSS: 0.865197 | EPOCH = [3/3] | TIME ELAPSED =243.13Mins
# ITERATION:[848/907] | LOSS: 0.896566 | EPOCH = [3/3] | TIME ELAPSED =243.18Mins
# ITERATION:[849/907] | LOSS: 0.944392 | EPOCH = [3/3] | TIME ELAPSED =243.22Mins
# ITERATION:[850/907] | LOSS: 0.946493 | EPOCH = [3/3] | TIME ELAPSED =243.28Mins
# ITERATION:[851/907] | LOSS: 0.876328 | EPOCH = [3/3] | TIME ELAPSED =243.33Mins
# ITERATION:[852/907] | LOSS: 0.952593 | EPOCH = [3/3] | TIME ELAPSED =243.37Mins
# ITERATION:[853/907] | LOSS: 0.961668 | EPOCH = [3/3] | TIME ELAPSED =243.42Mins
# ITERATION:[854/907] | LOSS: 0.925972 | EPOCH = [3/3] | TIME ELAPSED =243.46Mins
# ITERATION:[855/907] | LOSS: 0.930563 | EPOCH = [3/3] | TIME ELAPSED =243.52Mins
# ITERATION:[856/907] | LOSS: 0.959326 | EPOCH = [3/3] | TIME ELAPSED =243.56Mins
# ITERATION:[857/907] | LOSS: 0.885408 | EPOCH = [3/3] | TIME ELAPSED =243.61Mins
# ITERATION:[858/907] | LOSS: 0.864992 | EPOCH = [3/3] | TIME ELAPSED =243.65Mins
# ITERATION:[859/907] | LOSS: 0.911458 | EPOCH = [3/3] | TIME ELAPSED =243.7Mins
# ITERATION:[860/907] | LOSS: 0.858702 | EPOCH = [3/3] | TIME ELAPSED =243.76Mins
# ITERATION:[861/907] | LOSS: 0.899874 | EPOCH = [3/3] | TIME ELAPSED =243.8Mins
# ITERATION:[862/907] | LOSS: 0.957685 | EPOCH = [3/3] | TIME ELAPSED =243.85Mins
# ITERATION:[863/907] | LOSS: 0.873975 | EPOCH = [3/3] | TIME ELAPSED =243.89Mins
# ITERATION:[864/907] | LOSS: 0.868801 | EPOCH = [3/3] | TIME ELAPSED =243.94Mins
# ITERATION:[865/907] | LOSS: 0.892204 | EPOCH = [3/3] | TIME ELAPSED =243.99Mins
# ITERATION:[866/907] | LOSS: 0.896887 | EPOCH = [3/3] | TIME ELAPSED =244.04Mins
# ITERATION:[867/907] | LOSS: 0.926367 | EPOCH = [3/3] | TIME ELAPSED =244.08Mins
# ITERATION:[868/907] | LOSS: 0.881875 | EPOCH = [3/3] | TIME ELAPSED =244.13Mins
# ITERATION:[869/907] | LOSS: 0.872525 | EPOCH = [3/3] | TIME ELAPSED =244.17Mins
# ITERATION:[870/907] | LOSS: 0.902037 | EPOCH = [3/3] | TIME ELAPSED =244.23Mins
# ITERATION:[871/907] | LOSS: 0.899642 | EPOCH = [3/3] | TIME ELAPSED =244.27Mins
# ITERATION:[872/907] | LOSS: 0.894431 | EPOCH = [3/3] | TIME ELAPSED =244.32Mins
# ITERATION:[873/907] | LOSS: 0.838616 | EPOCH = [3/3] | TIME ELAPSED =244.36Mins
# ITERATION:[874/907] | LOSS: 0.880604 | EPOCH = [3/3] | TIME ELAPSED =244.41Mins
# ITERATION:[875/907] | LOSS: 0.859182 | EPOCH = [3/3] | TIME ELAPSED =244.47Mins
# ITERATION:[876/907] | LOSS: 0.851282 | EPOCH = [3/3] | TIME ELAPSED =244.51Mins
# ITERATION:[877/907] | LOSS: 0.881578 | EPOCH = [3/3] | TIME ELAPSED =244.55Mins
# ITERATION:[878/907] | LOSS: 0.939811 | EPOCH = [3/3] | TIME ELAPSED =244.6Mins
# ITERATION:[879/907] | LOSS: 0.864066 | EPOCH = [3/3] | TIME ELAPSED =244.64Mins
# ITERATION:[880/907] | LOSS: 0.888622 | EPOCH = [3/3] | TIME ELAPSED =244.7Mins
# ITERATION:[881/907] | LOSS: 0.919968 | EPOCH = [3/3] | TIME ELAPSED =244.75Mins
# ITERATION:[882/907] | LOSS: 0.86921 | EPOCH = [3/3] | TIME ELAPSED =244.79Mins
# ITERATION:[883/907] | LOSS: 0.966664 | EPOCH = [3/3] | TIME ELAPSED =244.84Mins
# ITERATION:[884/907] | LOSS: 0.974328 | EPOCH = [3/3] | TIME ELAPSED =244.88Mins
# ITERATION:[885/907] | LOSS: 0.964416 | EPOCH = [3/3] | TIME ELAPSED =244.94Mins
# ITERATION:[886/907] | LOSS: 0.909677 | EPOCH = [3/3] | TIME ELAPSED =244.98Mins
# ITERATION:[887/907] | LOSS: 0.861872 | EPOCH = [3/3] | TIME ELAPSED =245.03Mins
# ITERATION:[888/907] | LOSS: 0.908337 | EPOCH = [3/3] | TIME ELAPSED =245.07Mins
# ITERATION:[889/907] | LOSS: 0.892997 | EPOCH = [3/3] | TIME ELAPSED =245.11Mins
# ITERATION:[890/907] | LOSS: 0.894651 | EPOCH = [3/3] | TIME ELAPSED =245.17Mins
# ITERATION:[891/907] | LOSS: 0.878445 | EPOCH = [3/3] | TIME ELAPSED =245.22Mins
# ITERATION:[892/907] | LOSS: 0.844169 | EPOCH = [3/3] | TIME ELAPSED =245.26Mins
# ITERATION:[893/907] | LOSS: 0.854766 | EPOCH = [3/3] | TIME ELAPSED =245.3Mins
# ITERATION:[894/907] | LOSS: 0.903306 | EPOCH = [3/3] | TIME ELAPSED =245.35Mins
# ITERATION:[895/907] | LOSS: 0.87333 | EPOCH = [3/3] | TIME ELAPSED =245.41Mins
# ITERATION:[896/907] | LOSS: 0.950525 | EPOCH = [3/3] | TIME ELAPSED =245.45Mins
# ITERATION:[897/907] | LOSS: 0.869154 | EPOCH = [3/3] | TIME ELAPSED =245.5Mins
# ITERATION:[898/907] | LOSS: 0.907045 | EPOCH = [3/3] | TIME ELAPSED =245.54Mins
# ITERATION:[899/907] | LOSS: 0.968191 | EPOCH = [3/3] | TIME ELAPSED =245.58Mins
# ITERATION:[900/907] | LOSS: 0.919416 | EPOCH = [3/3] | TIME ELAPSED =245.64Mins
# ITERATION:[901/907] | LOSS: 0.925618 | EPOCH = [3/3] | TIME ELAPSED =245.68Mins
# ITERATION:[902/907] | LOSS: 0.85877 | EPOCH = [3/3] | TIME ELAPSED =245.73Mins
# ITERATION:[903/907] | LOSS: 0.930492 | EPOCH = [3/3] | TIME ELAPSED =245.77Mins
# ITERATION:[904/907] | LOSS: 0.863357 | EPOCH = [3/3] | TIME ELAPSED =245.81Mins
# ITERATION:[905/907] | LOSS: 0.877087 | EPOCH = [3/3] | TIME ELAPSED =245.87Mins
# ITERATION:[906/907] | LOSS: 0.877553 | EPOCH = [3/3] | TIME ELAPSED =245.92Mins
# ITERATION:[907/907] | LOSS: 0.957864 | EPOCH = [3/3] | TIME ELAPSED =245.93Mins
#
# $$Loss = 0.957864,EPOCH: [3/3]

# %% [markdown]
# ### Test Function

# %%
if platform == "colab":
    IMAGE_DIR = '/content/drive/My Drive/public_test_images/'
else:
    IMAGE_DIR = 'D:/Padhai/IIT Delhi MS(R)/2019-20 Sem II/COL774 Machine Learning/Assignment/Assignment4/train_images/'
restore = True
if restore == True:
    net = ImageCaptionsNet()
    net = net.double()
    #net = net.to(torch.device("cuda:0"))
    #net = nn.DataParallel(net)
    '''
    state_dict = restore_checkpoint("caption_chkpt_multi.pth")
    new_state_dict = collections.OrderedDict()
    for k, v in state_dict.items():
        name = k.replace("module.","") # remove `module.`
        new_state_dict[name] = v
    '''
    net.load_state_dict(restore_checkpoint("caption_chkpt_multi.pth"))
    print("State Dictionary Loaded Successfully.")

    # load params
    if device != 'cpu':
        net = nn.DataParallel(net)
        net = net.to(torch.device("cuda:0"))


# Creating the Dataset
test_dataset = ImageCaptionsDataset(
    IMAGE_DIR, captions_preprocessing_obj.captions_dict, img_transform=img_transform,
    captions_transform=captions_preprocessing_obj.captions_transform
)

# Define your hyperparameters
NUMBER_OF_EPOCHS = 1
LEARNING_RATE = 1e-1
BATCH_SIZE = 2
NUM_WORKERS = 0 # Parallel threads for dataloading
# Creating the DataLoader for batching purposes
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
import os
if device != "cpu":
    os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
t0 = time()
for batch_idx, sample in enumerate(test_loader):
        image_batch, captions_batch = sample['image'], sample['captions']
        img_features = net.Encoder(image_batch)

# %%
def chaloKuchBakchodiKarteHai():
  return False

# %%
summary(net, (32,3,256,256))

# %%
sum(p.numel() for p in net.parameters())

# %%
z = restore_checkpoint("caption_chkpt_multi.pth")
z['model_state_dict']

# %%
torch.mean(x, dim=0).unsqueeze(0)

# %%
#com gjjgdfgsdfgdfbdf
